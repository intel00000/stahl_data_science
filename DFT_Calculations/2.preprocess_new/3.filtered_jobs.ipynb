# %% [markdown]
# ### <p style="font-family: Arial; color: gold; "> If you want, you can filter down the jobs for open shell and anion jobs by using only the lowest energy conformer for each molecule. This notebook will do that based on the FINISHED DFT results.
#
# ### <p style="font-family: Arial; color: red; ">Requirement: put the finished DFT results for the closed shell species into a subfolders named **3.DFT_log_files**
#
# ### <p style="font-family: Arial; color: red; "> You should have the same naming convention all the folder being used.

# %%
import re, os, sys, shutil, subprocess

# %% [markdown]
# ### <p style="font-family: Arial; color: gold; font-weight: bold;"> define your input and output folders below

# %%
# define your desired folder names here
DFT_log_folder = "1.DFT_log_files"
os.makedirs(DFT_log_folder, exist_ok=True)

filter_anion = True
input_anion_com_folder = "2.anion_com_tom"
anion_com_output = "3.anion_com_tom_filtered"
os.makedirs(anion_com_output, exist_ok=True)
for file in os.listdir(anion_com_output):
    os.remove(os.path.join(anion_com_output, file))

filter_open_shell = True
input_open_shell_com_folder = "1.open_shell_com_tom"
open_shell_com_output = "3.open_shell_com_tom_filtered"
os.makedirs(open_shell_com_output, exist_ok=True)
for file in os.listdir(open_shell_com_output):
    os.remove(os.path.join(open_shell_com_output, file))

file_extension = ".com"

# %%
def parse_goodvibes_output(output: str, temp: float = 298.15) -> dict:
    # This function extracts the desired values from the GoodVibes output
    lines = output.splitlines()
    data = {}
    column_mapping = {
        "E_SPC": "E_spc (Hartree)",
        "E": "E (Hartree)",
        "ZPE": "ZPE(Hartree)",
        "H_SPC": "H_spc(Hartree)",
        "T.S": "T*S",
        "T.qh-S": "T*qh_S",
        "G(T)_SPC": "G(T)_spc(Hartree)",
        "qh-G(T)_SPC": "qh_G(T)_spc(Hartree)",
    }

    # Find the index positions of the two lines of asterisks
    start_index = None
    end_index = None
    header_line = None
    for i, line in enumerate(lines):
        if re.match(r"^\s*\*{12,}\s*$", line):  # Matches lines with 12 or more asterisks
            if start_index is None:
                start_index = i
                header_line = lines[i - 1]  # The header line is the one before the first line of asterisks
            else:
                end_index = i
                break  # We only need the first two lines of asterisks

    # Parse the header line to determine the order of properties
    headers = []
    if header_line:
        headers = re.split(r"\s+", header_line.strip())[1:]  # get rid of the first column, which is the structure column

    # Extract relevant lines between the two asterisk lines
    if start_index is not None and end_index is not None and end_index > start_index:
        for line in lines[start_index + 1 : end_index]:
            if re.match(r"^\s*o", line):  # Matches lines starting with 'o' (with any amount of whitespace before)
                parts = re.split(r"\s+", line.strip())  # Split the line by whitespace
                structure_name = parts[1]  # The structure name is in parts[1]

                # Initialize a dictionary for this structure
                structure_data = {}
                # Populate the structure's data dictionary using headers and corresponding values
                for i, header in enumerate(headers):
                    if header in column_mapping:
                        structure_data[column_mapping[header]] = float(parts[i + 2])  # Offset by 2 for correct column indexing
                    else:
                        structure_data[header] = float(parts[i + 2])

                structure_data["T"] = temp  # Add temperature to each structure's data
                data[structure_name] = structure_data  # Add to the main data dictionary

    return data


def get_goodvibes_e_batch(temp: float = 298.15) -> dict:
    # Construct command-line arguments for GoodVibes
    cmd_args = [
        sys.executable,
        "-m",
        "goodvibes",
        os.path.join(DFT_log_folder, "*.log"),
        "--spc",
        "link",
        "-t",
        str(temp),
    ]
    # Run the GoodVibes command and capture the output
    result = subprocess.run(cmd_args, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    # Parse the output
    parsed_data = parse_goodvibes_output(result.stdout, temp)
    return parsed_data

# %%
# Run the function
result = get_goodvibes_e_batch()
# Sort the result by the structure number
result = {
    k: v
    for k, v in sorted(result.items(), key=lambda x: int(re.search(r"^\D+(\d+)_{1}", x[0]).group(1)))
}

# %%
result
# Out:
# {'pyrd1_conf-1': {'E_spc (Hartree)': -441.215801,
#   'E (Hartree)': -441.305193,
#   'ZPE(Hartree)': 0.163282,
#   'H_spc(Hartree)': -441.043098,
#   'T*S': 0.043006,
#   'T*qh_S': 0.04266,
#   'G(T)_spc(Hartree)': -441.086104,
#   'qh_G(T)_spc(Hartree)': -441.085759,
#   'T': 298.15},
#  'pyrdz1_conf-1': {'E_spc (Hartree)': -303.585861,
#   'E (Hartree)': -303.638581,
#   'ZPE(Hartree)': 0.103728,
#   'H_spc(Hartree)': -303.475215,
#   'T*S': 0.036948,
#   'T*qh_S': 0.036617,
#   'G(T)_spc(Hartree)': -303.512163,
#   'qh_G(T)_spc(Hartree)': -303.511832,
#   'T': 298.15},
#  'pyrmd1_conf-1': {'E_spc (Hartree)': -457.262567,
#   'E (Hartree)': -457.34237,
#   'ZPE(Hartree)': 0.151533,
#   'H_spc(Hartree)': -457.101761,
#   'T*S': 0.04271,
#   'T*qh_S': 0.042452,
#   'G(T)_spc(Hartree)': -457.144471,
#   'qh_G(T)_spc(Hartree)': -457.144213,
#   'T': 298.15},
#  'pyrz1_conf-1': {'E_spc (Hartree)': -457.255348,
#   'E (Hartree)': -457.336221,
#   'ZPE(Hartree)': 0.151285,
#   'H_spc(Hartree)': -457.094752,
#   'T*S': 0.042943,
#   'T*qh_S': 0.042501,
#   'G(T)_spc(Hartree)': -457.137695,
#   'qh_G(T)_spc(Hartree)': -457.137253,
#   'T': 298.15},
#  'pyrd2_conf-1': {'E_spc (Hartree)': -441.212895,
#   'E (Hartree)': -441.302704,
#   'ZPE(Hartree)': 0.163425,
#   'H_spc(Hartree)': -441.040035,
#   'T*S': 0.043108,
#   'T*qh_S': 0.042693,
#   'G(T)_spc(Hartree)': -441.083144,
#   'qh_G(T)_spc(Hartree)': -441.082728,
#   'T': 298.15},
#  'pyrdz2_conf-1': {'E_spc (Hartree)': -303.584349,
#   'E (Hartree)': -303.637264,
#   'ZPE(Hartree)': 0.103775,
#   'H_spc(Hartree)': -303.47355,
#   'T*S': 0.038012,
#   'T*qh_S': 0.037077,
#   'G(T)_spc(Hartree)': -303.511562,
#   'qh_G(T)_spc(Hartree)': -303.510627,
#   'T': 298.15},
#  'pyrmd2_conf-1': {'E_spc (Hartree)': -457.26207,
#   'E (Hartree)': -457.341909,
#   'ZPE(Hartree)': 0.15199,
#   'H_spc(Hartree)': -457.100938,
#   'T*S': 0.042228,
#   'T*qh_S': 0.042146,
#   'G(T)_spc(Hartree)': -457.143166,
#   'qh_G(T)_spc(Hartree)': -457.143085,
#   'T': 298.15},
#  'pyrz2_conf-1': {'E_spc (Hartree)': -496.562505,
#   'E (Hartree)': -496.657687,
#   'ZPE(Hartree)': 0.180043,
#   'H_spc(Hartree)': -496.371904,
#   'T*S': 0.046266,
#   'T*qh_S': 0.04535,
#   'G(T)_spc(Hartree)': -496.41817,
#   'qh_G(T)_spc(Hartree)': -496.417254,
#   'T': 298.15},
#  'pyrz2_conf-2': {'E_spc (Hartree)': -496.562075,
#   'E (Hartree)': -496.657655,
#   'ZPE(Hartree)': 0.180255,
#   'H_spc(Hartree)': -496.371262,
#   'T*S': 0.046808,
#   'T*qh_S': 0.045503,
#   'G(T)_spc(Hartree)': -496.418069,
#   'qh_G(T)_spc(Hartree)': -496.416764,
#   'T': 298.15},
#  'pyrz2_conf-3': {'E_spc (Hartree)': -496.562075,
#   'E (Hartree)': -496.657655,
#   'ZPE(Hartree)': 0.180257,
#   'H_spc(Hartree)': -496.371261,
#   'T*S': 0.046799,
#   'T*qh_S': 0.045497,
#   'G(T)_spc(Hartree)': -496.41806,
#   'qh_G(T)_spc(Hartree)': -496.416758,
#   'T': 298.15},
#  'pyrd3_conf-1': {'E_spc (Hartree)': -441.213933,
#   'E (Hartree)': -441.303413,
#   'ZPE(Hartree)': 0.163893,
#   'H_spc(Hartree)': -441.04084,
#   'T*S': 0.042181,
#   'T*qh_S': 0.042142,
#   'G(T)_spc(Hartree)': -441.08302,
#   'qh_G(T)_spc(Hartree)': -441.082982,
#   'T': 298.15},
#  'pyrdz3_conf-1': {'E_spc (Hartree)': -342.892888,
#   'E (Hartree)': -342.960122,
#   'ZPE(Hartree)': 0.132713,
#   'H_spc(Hartree)': -342.752044,
#   'T*S': 0.040598,
#   'T*qh_S': 0.039684,
#   'G(T)_spc(Hartree)': -342.792642,
#   'qh_G(T)_spc(Hartree)': -342.791728,
#   'T': 298.15},
#  'pyrdz3_conf-2': {'E_spc (Hartree)': -342.892412,
#   'E (Hartree)': -342.959411,
#   'ZPE(Hartree)': 0.13252,
#   'H_spc(Hartree)': -342.751758,
#   'T*S': 0.04045,
#   'T*qh_S': 0.039608,
#   'G(T)_spc(Hartree)': -342.792208,
#   'qh_G(T)_spc(Hartree)': -342.791366,
#   'T': 298.15},
#  'pyrdz3_conf-3': {'E_spc (Hartree)': -342.89201,
#   'E (Hartree)': -342.958782,
#   'ZPE(Hartree)': 0.132648,
#   'H_spc(Hartree)': -342.751259,
#   'T*S': 0.041106,
#   'T*qh_S': 0.03985,
#   'G(T)_spc(Hartree)': -342.792365,
#   'qh_G(T)_spc(Hartree)': -342.791109,
#   'T': 298.15},
#  'pyrmd3_conf-1': {'E_spc (Hartree)': -496.569414,
#   'E (Hartree)': -496.663916,
#   'ZPE(Hartree)': 0.18048,
#   'H_spc(Hartree)': -496.37841,
#   'T*S': 0.046118,
#   'T*qh_S': 0.045192,
#   'G(T)_spc(Hartree)': -496.424528,
#   'qh_G(T)_spc(Hartree)': -496.423602,
#   'T': 298.15},
#  'pyrmd3_conf-2': {'E_spc (Hartree)': -496.569753,
#   'E (Hartree)': -496.664027,
#   'ZPE(Hartree)': 0.180221,
#   'H_spc(Hartree)': -496.378993,
#   'T*S': 0.045962,
#   'T*qh_S': 0.045234,
#   'G(T)_spc(Hartree)': -496.424955,
#   'qh_G(T)_spc(Hartree)': -496.424227,
#   'T': 298.15},
#  'pyrz3_conf-1': {'E_spc (Hartree)': -303.616826,
#   'E (Hartree)': -303.667899,
#   'ZPE(Hartree)': 0.104395,
#   'H_spc(Hartree)': -303.505551,
#   'T*S': 0.037032,
#   'T*qh_S': 0.036574,
#   'G(T)_spc(Hartree)': -303.542583,
#   'qh_G(T)_spc(Hartree)': -303.542126,
#   'T': 298.15},
#  'pyrd4_conf-1': {'E_spc (Hartree)': -441.213784,
#   'E (Hartree)': -441.303006,
#   'ZPE(Hartree)': 0.163746,
#   'H_spc(Hartree)': -441.040797,
#   'T*S': 0.042286,
#   'T*qh_S': 0.04223,
#   'G(T)_spc(Hartree)': -441.083083,
#   'qh_G(T)_spc(Hartree)': -441.083027,
#   'T': 298.15},
#  'pyrmd4_conf-1': {'E_spc (Hartree)': -496.568315,
#   'E (Hartree)': -496.663024,
#   'ZPE(Hartree)': 0.180967,
#   'H_spc(Hartree)': -496.37693,
#   'T*S': 0.045464,
#   'T*qh_S': 0.044937,
#   'G(T)_spc(Hartree)': -496.422395,
#   'qh_G(T)_spc(Hartree)': -496.421867,
#   'T': 298.15},
#  'pyrmd4_conf-2': {'E_spc (Hartree)': -496.568846,
#   'E (Hartree)': -496.663004,
#   'ZPE(Hartree)': 0.180657,
#   'H_spc(Hartree)': -496.377717,
#   'T*S': 0.045601,
#   'T*qh_S': 0.04506,
#   'G(T)_spc(Hartree)': -496.423318,
#   'qh_G(T)_spc(Hartree)': -496.422777,
#   'T': 298.15},
#  'pyrz4_conf-1': {'E_spc (Hartree)': -342.923914,
#   'E (Hartree)': -342.989674,
#   'ZPE(Hartree)': 0.13343,
#   'H_spc(Hartree)': -342.782454,
#   'T*S': 0.040057,
#   'T*qh_S': 0.039378,
#   'G(T)_spc(Hartree)': -342.822511,
#   'qh_G(T)_spc(Hartree)': -342.821832,
#   'T': 298.15},
#  'pyrz4_conf-2': {'E_spc (Hartree)': -342.922859,
#   'E (Hartree)': -342.988179,
#   'ZPE(Hartree)': 0.1334,
#   'H_spc(Hartree)': -342.781484,
#   'T*S': 0.039882,
#   'T*qh_S': 0.03921,
#   'G(T)_spc(Hartree)': -342.821366,
#   'qh_G(T)_spc(Hartree)': -342.820694,
#   'T': 298.15},
#  'pyrd5_conf-1': {'E_spc (Hartree)': -441.213936,
#   'E (Hartree)': -441.303293,
#   'ZPE(Hartree)': 0.163471,
#   'H_spc(Hartree)': -441.041089,
#   'T*S': 0.042774,
#   'T*qh_S': 0.042581,
#   'G(T)_spc(Hartree)': -441.083863,
#   'qh_G(T)_spc(Hartree)': -441.08367,
#   'T': 298.15},
#  'pyrmd5_conf-1': {'E_spc (Hartree)': -303.625303,
#   'E (Hartree)': -303.675314,
#   'ZPE(Hartree)': 0.104379,
#   'H_spc(Hartree)': -303.513954,
#   'T*S': 0.038046,
#   'T*qh_S': 0.03703,
#   'G(T)_spc(Hartree)': -303.552,
#   'qh_G(T)_spc(Hartree)': -303.550984,
#   'T': 298.15},
#  'pyrd6_conf-1': {'E_spc (Hartree)': -441.211694,
#   'E (Hartree)': -441.301315,
#   'ZPE(Hartree)': 0.163955,
#   'H_spc(Hartree)': -441.038524,
#   'T*S': 0.042194,
#   'T*qh_S': 0.042166,
#   'G(T)_spc(Hartree)': -441.080718,
#   'qh_G(T)_spc(Hartree)': -441.080689,
#   'T': 298.15},
#  'pyrmd6_conf-1': {'E_spc (Hartree)': -303.625153,
#   'E (Hartree)': -303.675255,
#   'ZPE(Hartree)': 0.104624,
#   'H_spc(Hartree)': -303.513626,
#   'T*S': 0.037221,
#   'T*qh_S': 0.036653,
#   'G(T)_spc(Hartree)': -303.550847,
#   'qh_G(T)_spc(Hartree)': -303.550278,
#   'T': 298.15},
#  'pyrd7_conf-1': {'E_spc (Hartree)': -480.522848,
#   'E (Hartree)': -480.626623,
#   'ZPE(Hartree)': 0.19201,
#   'H_spc(Hartree)': -480.320158,
#   'T*S': 0.046362,
#   'T*qh_S': 0.045507,
#   'G(T)_spc(Hartree)': -480.366519,
#   'qh_G(T)_spc(Hartree)': -480.365665,
#   'T': 298.15},
#  'pyrd7_conf-2': {'E_spc (Hartree)': -480.522526,
#   'E (Hartree)': -480.626608,
#   'ZPE(Hartree)': 0.192231,
#   'H_spc(Hartree)': -480.319616,
#   'T*S': 0.046863,
#   'T*qh_S': 0.045637,
#   'G(T)_spc(Hartree)': -480.366479,
#   'qh_G(T)_spc(Hartree)': -480.365253,
#   'T': 298.15},
#  'pyrd7_conf-3': {'E_spc (Hartree)': -480.522526,
#   'E (Hartree)': -480.626608,
#   'ZPE(Hartree)': 0.192231,
#   'H_spc(Hartree)': -480.319616,
#   'T*S': 0.046873,
#   'T*qh_S': 0.045642,
#   'G(T)_spc(Hartree)': -480.366488,
#   'qh_G(T)_spc(Hartree)': -480.365258,
#   'T': 298.15},
#  'pyrmd7_conf-1': {'E_spc (Hartree)': -303.62116,
#   'E (Hartree)': -303.671939,
#   'ZPE(Hartree)': 0.104638,
#   'H_spc(Hartree)': -303.509541,
#   'T*S': 0.038041,
#   'T*qh_S': 0.037048,
#   'G(T)_spc(Hartree)': -303.547582,
#   'qh_G(T)_spc(Hartree)': -303.546589,
#   'T': 298.15},
#  'pyrd8_conf-1': {'E_spc (Hartree)': -480.519611,
#   'E (Hartree)': -480.624231,
#   'ZPE(Hartree)': 0.192345,
#   'H_spc(Hartree)': -480.316628,
#   'T*S': 0.046241,
#   'T*qh_S': 0.04535,
#   'G(T)_spc(Hartree)': -480.362869,
#   'qh_G(T)_spc(Hartree)': -480.361978,
#   'T': 298.15},
#  'pyrd8_conf-2': {'E_spc (Hartree)': -480.519501,
#   'E (Hartree)': -480.623392,
#   'ZPE(Hartree)': 0.192373,
#   'H_spc(Hartree)': -480.316541,
#   'T*S': 0.046052,
#   'T*qh_S': 0.045262,
#   'G(T)_spc(Hartree)': -480.362593,
#   'qh_G(T)_spc(Hartree)': -480.361803,
#   'T': 298.15},
#  'pyrmd8_conf-1': {'E_spc (Hartree)': -342.932313,
#   'E (Hartree)': -342.9969,
#   'ZPE(Hartree)': 0.133465,
#   'H_spc(Hartree)': -342.790729,
#   'T*S': 0.041974,
#   'T*qh_S': 0.04031,
#   'G(T)_spc(Hartree)': -342.832703,
#   'qh_G(T)_spc(Hartree)': -342.831038,
#   'T': 298.15},
#  'pyrmd8_conf-2': {'E_spc (Hartree)': -342.932118,
#   'E (Hartree)': -342.996597,
#   'ZPE(Hartree)': 0.133233,
#   'H_spc(Hartree)': -342.7908,
#   'T*S': 0.040398,
#   'T*qh_S': 0.039544,
#   'G(T)_spc(Hartree)': -342.831199,
#   'qh_G(T)_spc(Hartree)': -342.830344,
#   'T': 298.15},
#  'pyrd9_conf-1': {'E_spc (Hartree)': -480.519916,
#   'E (Hartree)': -480.624441,
#   'ZPE(Hartree)': 0.192806,
#   'H_spc(Hartree)': -480.316632,
#   'T*S': 0.045323,
#   'T*qh_S': 0.044986,
#   'G(T)_spc(Hartree)': -480.361955,
#   'qh_G(T)_spc(Hartree)': -480.361618,
#   'T': 298.15},
#  'pyrd9_conf-2': {'E_spc (Hartree)': -480.519987,
#   'E (Hartree)': -480.623611,
#   'ZPE(Hartree)': 0.192787,
#   'H_spc(Hartree)': -480.316756,
#   'T*S': 0.045254,
#   'T*qh_S': 0.044871,
#   'G(T)_spc(Hartree)': -480.362011,
#   'qh_G(T)_spc(Hartree)': -480.361627,
#   'T': 298.15},
#  'pyrmd9_conf-1': {'E_spc (Hartree)': -342.932189,
#   'E (Hartree)': -342.99702,
#   'ZPE(Hartree)': 0.133697,
#   'H_spc(Hartree)': -342.790453,
#   'T*S': 0.040109,
#   'T*qh_S': 0.039411,
#   'G(T)_spc(Hartree)': -342.830563,
#   'qh_G(T)_spc(Hartree)': -342.829864,
#   'T': 298.15},
#  'pyrmd9_conf-2': {'E_spc (Hartree)': -342.931727,
#   'E (Hartree)': -342.996068,
#   'ZPE(Hartree)': 0.133619,
#   'H_spc(Hartree)': -342.790128,
#   'T*S': 0.039812,
#   'T*qh_S': 0.039205,
#   'G(T)_spc(Hartree)': -342.82994,
#   'qh_G(T)_spc(Hartree)': -342.829333,
#   'T': 298.15},
#  'pyrd10_conf-1': {'E_spc (Hartree)': -480.519907,
#   'E (Hartree)': -480.624025,
#   'ZPE(Hartree)': 0.192685,
#   'H_spc(Hartree)': -480.316691,
#   'T*S': 0.045527,
#   'T*qh_S': 0.045073,
#   'G(T)_spc(Hartree)': -480.362218,
#   'qh_G(T)_spc(Hartree)': -480.361764,
#   'T': 298.15},
#  'pyrd10_conf-2': {'E_spc (Hartree)': -480.520348,
#   'E (Hartree)': -480.623925,
#   'ZPE(Hartree)': 0.192424,
#   'H_spc(Hartree)': -480.317349,
#   'T*S': 0.045628,
#   'T*qh_S': 0.04516,
#   'G(T)_spc(Hartree)': -480.362977,
#   'qh_G(T)_spc(Hartree)': -480.362509,
#   'T': 298.15},
#  'pyrmd10_conf-1': {'E_spc (Hartree)': -342.928072,
#   'E (Hartree)': -342.993572,
#   'ZPE(Hartree)': 0.133678,
#   'H_spc(Hartree)': -342.786323,
#   'T*S': 0.040279,
#   'T*qh_S': 0.039524,
#   'G(T)_spc(Hartree)': -342.826603,
#   'qh_G(T)_spc(Hartree)': -342.825848,
#   'T': 298.15},
#  'pyrmd10_conf-2': {'E_spc (Hartree)': -342.927156,
#   'E (Hartree)': -342.992064,
#   'ZPE(Hartree)': 0.13373,
#   'H_spc(Hartree)': -342.785399,
#   'T*S': 0.040524,
#   'T*qh_S': 0.039528,
#   'G(T)_spc(Hartree)': -342.825923,
#   'qh_G(T)_spc(Hartree)': -342.824927,
#   'T': 298.15},
#  'pyrd11_conf-1': {'E_spc (Hartree)': -480.521016,
#   'E (Hartree)': -480.625163,
#   'ZPE(Hartree)': 0.192386,
#   'H_spc(Hartree)': -480.318012,
#   'T*S': 0.046041,
#   'T*qh_S': 0.045268,
#   'G(T)_spc(Hartree)': -480.364052,
#   'qh_G(T)_spc(Hartree)': -480.36328,
#   'T': 298.15},
#  'pyrd12_conf-1': {'E_spc (Hartree)': -480.517722,
#   'E (Hartree)': -480.622341,
#   'ZPE(Hartree)': 0.192841,
#   'H_spc(Hartree)': -480.314382,
#   'T*S': 0.045334,
#   'T*qh_S': 0.045037,
#   'G(T)_spc(Hartree)': -480.359715,
#   'qh_G(T)_spc(Hartree)': -480.359419,
#   'T': 298.15},
#  'pyrd12_conf-2': {'E_spc (Hartree)': -480.517209,
#   'E (Hartree)': -480.620917,
#   'ZPE(Hartree)': 0.192886,
#   'H_spc(Hartree)': -480.313863,
#   'T*S': 0.04528,
#   'T*qh_S': 0.044905,
#   'G(T)_spc(Hartree)': -480.359143,
#   'qh_G(T)_spc(Hartree)': -480.358768,
#   'T': 298.15},
#  'pyrd13_conf-1': {'E_spc (Hartree)': -287.578876,
#   'E (Hartree)': -287.638359,
#   'ZPE(Hartree)': 0.116331,
#   'H_spc(Hartree)': -287.455541,
#   'T*S': 0.037366,
#   'T*qh_S': 0.03678,
#   'G(T)_spc(Hartree)': -287.492907,
#   'qh_G(T)_spc(Hartree)': -287.492322,
#   'T': 298.15},
#  'pyrd14_conf-1': {'E_spc (Hartree)': -287.576157,
#   'E (Hartree)': -287.636242,
#   'ZPE(Hartree)': 0.116447,
#   'H_spc(Hartree)': -287.452703,
#   'T*S': 0.037376,
#   'T*qh_S': 0.036794,
#   'G(T)_spc(Hartree)': -287.490079,
#   'qh_G(T)_spc(Hartree)': -287.489497,
#   'T': 298.15},
#  'pyrd15_conf-1': {'E_spc (Hartree)': -287.577105,
#   'E (Hartree)': -287.637017,
#   'ZPE(Hartree)': 0.116409,
#   'H_spc(Hartree)': -287.453646,
#   'T*S': 0.037882,
#   'T*qh_S': 0.037026,
#   'G(T)_spc(Hartree)': -287.491528,
#   'qh_G(T)_spc(Hartree)': -287.490673,
#   'T': 298.15},
#  'pyrd16_conf-1': {'E_spc (Hartree)': -326.885976,
#   'E (Hartree)': -326.960226,
#   'ZPE(Hartree)': 0.145383,
#   'H_spc(Hartree)': -326.732464,
#   'T*S': 0.040192,
#   'T*qh_S': 0.039501,
#   'G(T)_spc(Hartree)': -326.772656,
#   'qh_G(T)_spc(Hartree)': -326.771966,
#   'T': 298.15},
#  'pyrd16_conf-2': {'E_spc (Hartree)': -326.885975,
#   'E (Hartree)': -326.960226,
#   'ZPE(Hartree)': 0.145382,
#   'H_spc(Hartree)': -326.732465,
#   'T*S': 0.04019,
#   'T*qh_S': 0.0395,
#   'G(T)_spc(Hartree)': -326.772655,
#   'qh_G(T)_spc(Hartree)': -326.771965,
#   'T': 298.15},
#  'pyrd16_conf-3': {'E_spc (Hartree)': -326.885195,
#   'E (Hartree)': -326.958923,
#   'ZPE(Hartree)': 0.145329,
#   'H_spc(Hartree)': -326.73179,
#   'T*S': 0.040001,
#   'T*qh_S': 0.03933,
#   'G(T)_spc(Hartree)': -326.771791,
#   'qh_G(T)_spc(Hartree)': -326.77112,
#   'T': 298.15},
#  'pyrd17_conf-1': {'E_spc (Hartree)': -326.883,
#   'E (Hartree)': -326.95783,
#   'ZPE(Hartree)': 0.145429,
#   'H_spc(Hartree)': -326.729424,
#   'T*S': 0.040296,
#   'T*qh_S': 0.03958,
#   'G(T)_spc(Hartree)': -326.76972,
#   'qh_G(T)_spc(Hartree)': -326.769004,
#   'T': 298.15},
#  'pyrd17_conf-2': {'E_spc (Hartree)': -326.882128,
#   'E (Hartree)': -326.95633,
#   'ZPE(Hartree)': 0.145431,
#   'H_spc(Hartree)': -326.728565,
#   'T*S': 0.040996,
#   'T*qh_S': 0.039812,
#   'G(T)_spc(Hartree)': -326.769561,
#   'qh_G(T)_spc(Hartree)': -326.768378,
#   'T': 298.15},
#  'pyrd17_conf-3': {'E_spc (Hartree)': -326.881867,
#   'E (Hartree)': -326.956078,
#   'ZPE(Hartree)': 0.145503,
#   'H_spc(Hartree)': -326.728274,
#   'T*S': 0.040272,
#   'T*qh_S': 0.03945,
#   'G(T)_spc(Hartree)': -326.768546,
#   'qh_G(T)_spc(Hartree)': -326.767724,
#   'T': 298.15},
#  'pyrd18_conf-1': {'E_spc (Hartree)': -326.883963,
#   'E (Hartree)': -326.958638,
#   'ZPE(Hartree)': 0.14546,
#   'H_spc(Hartree)': -326.73035,
#   'T*S': 0.040399,
#   'T*qh_S': 0.039627,
#   'G(T)_spc(Hartree)': -326.770749,
#   'qh_G(T)_spc(Hartree)': -326.769977,
#   'T': 298.15},
#  'pyrd18_conf-2': {'E_spc (Hartree)': -326.88338,
#   'E (Hartree)': -326.957421,
#   'ZPE(Hartree)': 0.145469,
#   'H_spc(Hartree)': -326.729812,
#   'T*S': 0.040304,
#   'T*qh_S': 0.039483,
#   'G(T)_spc(Hartree)': -326.770116,
#   'qh_G(T)_spc(Hartree)': -326.769294,
#   'T': 298.15}}

# %%
# grouped results by substrates
def group_results_by_substrates(result: dict) -> dict:
    # Initialize a new dictionary to
    result_grouped_by_substrates = {}
    # Regex pattern to capture the substrate name before "_", for example pyrd1_conf-1 -> pyrd1
    substrate_pattern = re.compile(r"^(.+)_")
    for conformer_name, properties in result.items():
        # Extract substrate name using regex
        match = substrate_pattern.match(conformer_name)
        if match:
            substrate_name = match.group(1)

            # Append conformer data to the list for this substrate
            if substrate_name not in result_grouped_by_substrates:
                result_grouped_by_substrates[substrate_name] = []
            result_grouped_by_substrates[substrate_name].append(
                {conformer_name: properties}
            )
    return result_grouped_by_substrates


result_grouped_by_substrates = group_results_by_substrates(result)

# %%
result_grouped_by_substrates
# Out:
# {'pyrd1': [{'pyrd1_conf-1': {'E_spc (Hartree)': -441.215801,
#     'E (Hartree)': -441.305193,
#     'ZPE(Hartree)': 0.163282,
#     'H_spc(Hartree)': -441.043098,
#     'T*S': 0.043006,
#     'T*qh_S': 0.04266,
#     'G(T)_spc(Hartree)': -441.086104,
#     'qh_G(T)_spc(Hartree)': -441.085759,
#     'T': 298.15}}],
#  'pyrdz1': [{'pyrdz1_conf-1': {'E_spc (Hartree)': -303.585861,
#     'E (Hartree)': -303.638581,
#     'ZPE(Hartree)': 0.103728,
#     'H_spc(Hartree)': -303.475215,
#     'T*S': 0.036948,
#     'T*qh_S': 0.036617,
#     'G(T)_spc(Hartree)': -303.512163,
#     'qh_G(T)_spc(Hartree)': -303.511832,
#     'T': 298.15}}],
#  'pyrmd1': [{'pyrmd1_conf-1': {'E_spc (Hartree)': -457.262567,
#     'E (Hartree)': -457.34237,
#     'ZPE(Hartree)': 0.151533,
#     'H_spc(Hartree)': -457.101761,
#     'T*S': 0.04271,
#     'T*qh_S': 0.042452,
#     'G(T)_spc(Hartree)': -457.144471,
#     'qh_G(T)_spc(Hartree)': -457.144213,
#     'T': 298.15}}],
#  'pyrz1': [{'pyrz1_conf-1': {'E_spc (Hartree)': -457.255348,
#     'E (Hartree)': -457.336221,
#     'ZPE(Hartree)': 0.151285,
#     'H_spc(Hartree)': -457.094752,
#     'T*S': 0.042943,
#     'T*qh_S': 0.042501,
#     'G(T)_spc(Hartree)': -457.137695,
#     'qh_G(T)_spc(Hartree)': -457.137253,
#     'T': 298.15}}],
#  'pyrd2': [{'pyrd2_conf-1': {'E_spc (Hartree)': -441.212895,
#     'E (Hartree)': -441.302704,
#     'ZPE(Hartree)': 0.163425,
#     'H_spc(Hartree)': -441.040035,
#     'T*S': 0.043108,
#     'T*qh_S': 0.042693,
#     'G(T)_spc(Hartree)': -441.083144,
#     'qh_G(T)_spc(Hartree)': -441.082728,
#     'T': 298.15}}],
#  'pyrdz2': [{'pyrdz2_conf-1': {'E_spc (Hartree)': -303.584349,
#     'E (Hartree)': -303.637264,
#     'ZPE(Hartree)': 0.103775,
#     'H_spc(Hartree)': -303.47355,
#     'T*S': 0.038012,
#     'T*qh_S': 0.037077,
#     'G(T)_spc(Hartree)': -303.511562,
#     'qh_G(T)_spc(Hartree)': -303.510627,
#     'T': 298.15}}],
#  'pyrmd2': [{'pyrmd2_conf-1': {'E_spc (Hartree)': -457.26207,
#     'E (Hartree)': -457.341909,
#     'ZPE(Hartree)': 0.15199,
#     'H_spc(Hartree)': -457.100938,
#     'T*S': 0.042228,
#     'T*qh_S': 0.042146,
#     'G(T)_spc(Hartree)': -457.143166,
#     'qh_G(T)_spc(Hartree)': -457.143085,
#     'T': 298.15}}],
#  'pyrz2': [{'pyrz2_conf-1': {'E_spc (Hartree)': -496.562505,
#     'E (Hartree)': -496.657687,
#     'ZPE(Hartree)': 0.180043,
#     'H_spc(Hartree)': -496.371904,
#     'T*S': 0.046266,
#     'T*qh_S': 0.04535,
#     'G(T)_spc(Hartree)': -496.41817,
#     'qh_G(T)_spc(Hartree)': -496.417254,
#     'T': 298.15}},
#   {'pyrz2_conf-2': {'E_spc (Hartree)': -496.562075,
#     'E (Hartree)': -496.657655,
#     'ZPE(Hartree)': 0.180255,
#     'H_spc(Hartree)': -496.371262,
#     'T*S': 0.046808,
#     'T*qh_S': 0.045503,
#     'G(T)_spc(Hartree)': -496.418069,
#     'qh_G(T)_spc(Hartree)': -496.416764,
#     'T': 298.15}},
#   {'pyrz2_conf-3': {'E_spc (Hartree)': -496.562075,
#     'E (Hartree)': -496.657655,
#     'ZPE(Hartree)': 0.180257,
#     'H_spc(Hartree)': -496.371261,
#     'T*S': 0.046799,
#     'T*qh_S': 0.045497,
#     'G(T)_spc(Hartree)': -496.41806,
#     'qh_G(T)_spc(Hartree)': -496.416758,
#     'T': 298.15}}],
#  'pyrd3': [{'pyrd3_conf-1': {'E_spc (Hartree)': -441.213933,
#     'E (Hartree)': -441.303413,
#     'ZPE(Hartree)': 0.163893,
#     'H_spc(Hartree)': -441.04084,
#     'T*S': 0.042181,
#     'T*qh_S': 0.042142,
#     'G(T)_spc(Hartree)': -441.08302,
#     'qh_G(T)_spc(Hartree)': -441.082982,
#     'T': 298.15}}],
#  'pyrdz3': [{'pyrdz3_conf-1': {'E_spc (Hartree)': -342.892888,
#     'E (Hartree)': -342.960122,
#     'ZPE(Hartree)': 0.132713,
#     'H_spc(Hartree)': -342.752044,
#     'T*S': 0.040598,
#     'T*qh_S': 0.039684,
#     'G(T)_spc(Hartree)': -342.792642,
#     'qh_G(T)_spc(Hartree)': -342.791728,
#     'T': 298.15}},
#   {'pyrdz3_conf-2': {'E_spc (Hartree)': -342.892412,
#     'E (Hartree)': -342.959411,
#     'ZPE(Hartree)': 0.13252,
#     'H_spc(Hartree)': -342.751758,
#     'T*S': 0.04045,
#     'T*qh_S': 0.039608,
#     'G(T)_spc(Hartree)': -342.792208,
#     'qh_G(T)_spc(Hartree)': -342.791366,
#     'T': 298.15}},
#   {'pyrdz3_conf-3': {'E_spc (Hartree)': -342.89201,
#     'E (Hartree)': -342.958782,
#     'ZPE(Hartree)': 0.132648,
#     'H_spc(Hartree)': -342.751259,
#     'T*S': 0.041106,
#     'T*qh_S': 0.03985,
#     'G(T)_spc(Hartree)': -342.792365,
#     'qh_G(T)_spc(Hartree)': -342.791109,
#     'T': 298.15}}],
#  'pyrmd3': [{'pyrmd3_conf-1': {'E_spc (Hartree)': -496.569414,
#     'E (Hartree)': -496.663916,
#     'ZPE(Hartree)': 0.18048,
#     'H_spc(Hartree)': -496.37841,
#     'T*S': 0.046118,
#     'T*qh_S': 0.045192,
#     'G(T)_spc(Hartree)': -496.424528,
#     'qh_G(T)_spc(Hartree)': -496.423602,
#     'T': 298.15}},
#   {'pyrmd3_conf-2': {'E_spc (Hartree)': -496.569753,
#     'E (Hartree)': -496.664027,
#     'ZPE(Hartree)': 0.180221,
#     'H_spc(Hartree)': -496.378993,
#     'T*S': 0.045962,
#     'T*qh_S': 0.045234,
#     'G(T)_spc(Hartree)': -496.424955,
#     'qh_G(T)_spc(Hartree)': -496.424227,
#     'T': 298.15}}],
#  'pyrz3': [{'pyrz3_conf-1': {'E_spc (Hartree)': -303.616826,
#     'E (Hartree)': -303.667899,
#     'ZPE(Hartree)': 0.104395,
#     'H_spc(Hartree)': -303.505551,
#     'T*S': 0.037032,
#     'T*qh_S': 0.036574,
#     'G(T)_spc(Hartree)': -303.542583,
#     'qh_G(T)_spc(Hartree)': -303.542126,
#     'T': 298.15}}],
#  'pyrd4': [{'pyrd4_conf-1': {'E_spc (Hartree)': -441.213784,
#     'E (Hartree)': -441.303006,
#     'ZPE(Hartree)': 0.163746,
#     'H_spc(Hartree)': -441.040797,
#     'T*S': 0.042286,
#     'T*qh_S': 0.04223,
#     'G(T)_spc(Hartree)': -441.083083,
#     'qh_G(T)_spc(Hartree)': -441.083027,
#     'T': 298.15}}],
#  'pyrmd4': [{'pyrmd4_conf-1': {'E_spc (Hartree)': -496.568315,
#     'E (Hartree)': -496.663024,
#     'ZPE(Hartree)': 0.180967,
#     'H_spc(Hartree)': -496.37693,
#     'T*S': 0.045464,
#     'T*qh_S': 0.044937,
#     'G(T)_spc(Hartree)': -496.422395,
#     'qh_G(T)_spc(Hartree)': -496.421867,
#     'T': 298.15}},
#   {'pyrmd4_conf-2': {'E_spc (Hartree)': -496.568846,
#     'E (Hartree)': -496.663004,
#     'ZPE(Hartree)': 0.180657,
#     'H_spc(Hartree)': -496.377717,
#     'T*S': 0.045601,
#     'T*qh_S': 0.04506,
#     'G(T)_spc(Hartree)': -496.423318,
#     'qh_G(T)_spc(Hartree)': -496.422777,
#     'T': 298.15}}],
#  'pyrz4': [{'pyrz4_conf-1': {'E_spc (Hartree)': -342.923914,
#     'E (Hartree)': -342.989674,
#     'ZPE(Hartree)': 0.13343,
#     'H_spc(Hartree)': -342.782454,
#     'T*S': 0.040057,
#     'T*qh_S': 0.039378,
#     'G(T)_spc(Hartree)': -342.822511,
#     'qh_G(T)_spc(Hartree)': -342.821832,
#     'T': 298.15}},
#   {'pyrz4_conf-2': {'E_spc (Hartree)': -342.922859,
#     'E (Hartree)': -342.988179,
#     'ZPE(Hartree)': 0.1334,
#     'H_spc(Hartree)': -342.781484,
#     'T*S': 0.039882,
#     'T*qh_S': 0.03921,
#     'G(T)_spc(Hartree)': -342.821366,
#     'qh_G(T)_spc(Hartree)': -342.820694,
#     'T': 298.15}}],
#  'pyrd5': [{'pyrd5_conf-1': {'E_spc (Hartree)': -441.213936,
#     'E (Hartree)': -441.303293,
#     'ZPE(Hartree)': 0.163471,
#     'H_spc(Hartree)': -441.041089,
#     'T*S': 0.042774,
#     'T*qh_S': 0.042581,
#     'G(T)_spc(Hartree)': -441.083863,
#     'qh_G(T)_spc(Hartree)': -441.08367,
#     'T': 298.15}}],
#  'pyrmd5': [{'pyrmd5_conf-1': {'E_spc (Hartree)': -303.625303,
#     'E (Hartree)': -303.675314,
#     'ZPE(Hartree)': 0.104379,
#     'H_spc(Hartree)': -303.513954,
#     'T*S': 0.038046,
#     'T*qh_S': 0.03703,
#     'G(T)_spc(Hartree)': -303.552,
#     'qh_G(T)_spc(Hartree)': -303.550984,
#     'T': 298.15}}],
#  'pyrd6': [{'pyrd6_conf-1': {'E_spc (Hartree)': -441.211694,
#     'E (Hartree)': -441.301315,
#     'ZPE(Hartree)': 0.163955,
#     'H_spc(Hartree)': -441.038524,
#     'T*S': 0.042194,
#     'T*qh_S': 0.042166,
#     'G(T)_spc(Hartree)': -441.080718,
#     'qh_G(T)_spc(Hartree)': -441.080689,
#     'T': 298.15}}],
#  'pyrmd6': [{'pyrmd6_conf-1': {'E_spc (Hartree)': -303.625153,
#     'E (Hartree)': -303.675255,
#     'ZPE(Hartree)': 0.104624,
#     'H_spc(Hartree)': -303.513626,
#     'T*S': 0.037221,
#     'T*qh_S': 0.036653,
#     'G(T)_spc(Hartree)': -303.550847,
#     'qh_G(T)_spc(Hartree)': -303.550278,
#     'T': 298.15}}],
#  'pyrd7': [{'pyrd7_conf-1': {'E_spc (Hartree)': -480.522848,
#     'E (Hartree)': -480.626623,
#     'ZPE(Hartree)': 0.19201,
#     'H_spc(Hartree)': -480.320158,
#     'T*S': 0.046362,
#     'T*qh_S': 0.045507,
#     'G(T)_spc(Hartree)': -480.366519,
#     'qh_G(T)_spc(Hartree)': -480.365665,
#     'T': 298.15}},
#   {'pyrd7_conf-2': {'E_spc (Hartree)': -480.522526,
#     'E (Hartree)': -480.626608,
#     'ZPE(Hartree)': 0.192231,
#     'H_spc(Hartree)': -480.319616,
#     'T*S': 0.046863,
#     'T*qh_S': 0.045637,
#     'G(T)_spc(Hartree)': -480.366479,
#     'qh_G(T)_spc(Hartree)': -480.365253,
#     'T': 298.15}},
#   {'pyrd7_conf-3': {'E_spc (Hartree)': -480.522526,
#     'E (Hartree)': -480.626608,
#     'ZPE(Hartree)': 0.192231,
#     'H_spc(Hartree)': -480.319616,
#     'T*S': 0.046873,
#     'T*qh_S': 0.045642,
#     'G(T)_spc(Hartree)': -480.366488,
#     'qh_G(T)_spc(Hartree)': -480.365258,
#     'T': 298.15}}],
#  'pyrmd7': [{'pyrmd7_conf-1': {'E_spc (Hartree)': -303.62116,
#     'E (Hartree)': -303.671939,
#     'ZPE(Hartree)': 0.104638,
#     'H_spc(Hartree)': -303.509541,
#     'T*S': 0.038041,
#     'T*qh_S': 0.037048,
#     'G(T)_spc(Hartree)': -303.547582,
#     'qh_G(T)_spc(Hartree)': -303.546589,
#     'T': 298.15}}],
#  'pyrd8': [{'pyrd8_conf-1': {'E_spc (Hartree)': -480.519611,
#     'E (Hartree)': -480.624231,
#     'ZPE(Hartree)': 0.192345,
#     'H_spc(Hartree)': -480.316628,
#     'T*S': 0.046241,
#     'T*qh_S': 0.04535,
#     'G(T)_spc(Hartree)': -480.362869,
#     'qh_G(T)_spc(Hartree)': -480.361978,
#     'T': 298.15}},
#   {'pyrd8_conf-2': {'E_spc (Hartree)': -480.519501,
#     'E (Hartree)': -480.623392,
#     'ZPE(Hartree)': 0.192373,
#     'H_spc(Hartree)': -480.316541,
#     'T*S': 0.046052,
#     'T*qh_S': 0.045262,
#     'G(T)_spc(Hartree)': -480.362593,
#     'qh_G(T)_spc(Hartree)': -480.361803,
#     'T': 298.15}}],
#  'pyrmd8': [{'pyrmd8_conf-1': {'E_spc (Hartree)': -342.932313,
#     'E (Hartree)': -342.9969,
#     'ZPE(Hartree)': 0.133465,
#     'H_spc(Hartree)': -342.790729,
#     'T*S': 0.041974,
#     'T*qh_S': 0.04031,
#     'G(T)_spc(Hartree)': -342.832703,
#     'qh_G(T)_spc(Hartree)': -342.831038,
#     'T': 298.15}},
#   {'pyrmd8_conf-2': {'E_spc (Hartree)': -342.932118,
#     'E (Hartree)': -342.996597,
#     'ZPE(Hartree)': 0.133233,
#     'H_spc(Hartree)': -342.7908,
#     'T*S': 0.040398,
#     'T*qh_S': 0.039544,
#     'G(T)_spc(Hartree)': -342.831199,
#     'qh_G(T)_spc(Hartree)': -342.830344,
#     'T': 298.15}}],
#  'pyrd9': [{'pyrd9_conf-1': {'E_spc (Hartree)': -480.519916,
#     'E (Hartree)': -480.624441,
#     'ZPE(Hartree)': 0.192806,
#     'H_spc(Hartree)': -480.316632,
#     'T*S': 0.045323,
#     'T*qh_S': 0.044986,
#     'G(T)_spc(Hartree)': -480.361955,
#     'qh_G(T)_spc(Hartree)': -480.361618,
#     'T': 298.15}},
#   {'pyrd9_conf-2': {'E_spc (Hartree)': -480.519987,
#     'E (Hartree)': -480.623611,
#     'ZPE(Hartree)': 0.192787,
#     'H_spc(Hartree)': -480.316756,
#     'T*S': 0.045254,
#     'T*qh_S': 0.044871,
#     'G(T)_spc(Hartree)': -480.362011,
#     'qh_G(T)_spc(Hartree)': -480.361627,
#     'T': 298.15}}],
#  'pyrmd9': [{'pyrmd9_conf-1': {'E_spc (Hartree)': -342.932189,
#     'E (Hartree)': -342.99702,
#     'ZPE(Hartree)': 0.133697,
#     'H_spc(Hartree)': -342.790453,
#     'T*S': 0.040109,
#     'T*qh_S': 0.039411,
#     'G(T)_spc(Hartree)': -342.830563,
#     'qh_G(T)_spc(Hartree)': -342.829864,
#     'T': 298.15}},
#   {'pyrmd9_conf-2': {'E_spc (Hartree)': -342.931727,
#     'E (Hartree)': -342.996068,
#     'ZPE(Hartree)': 0.133619,
#     'H_spc(Hartree)': -342.790128,
#     'T*S': 0.039812,
#     'T*qh_S': 0.039205,
#     'G(T)_spc(Hartree)': -342.82994,
#     'qh_G(T)_spc(Hartree)': -342.829333,
#     'T': 298.15}}],
#  'pyrd10': [{'pyrd10_conf-1': {'E_spc (Hartree)': -480.519907,
#     'E (Hartree)': -480.624025,
#     'ZPE(Hartree)': 0.192685,
#     'H_spc(Hartree)': -480.316691,
#     'T*S': 0.045527,
#     'T*qh_S': 0.045073,
#     'G(T)_spc(Hartree)': -480.362218,
#     'qh_G(T)_spc(Hartree)': -480.361764,
#     'T': 298.15}},
#   {'pyrd10_conf-2': {'E_spc (Hartree)': -480.520348,
#     'E (Hartree)': -480.623925,
#     'ZPE(Hartree)': 0.192424,
#     'H_spc(Hartree)': -480.317349,
#     'T*S': 0.045628,
#     'T*qh_S': 0.04516,
#     'G(T)_spc(Hartree)': -480.362977,
#     'qh_G(T)_spc(Hartree)': -480.362509,
#     'T': 298.15}}],
#  'pyrmd10': [{'pyrmd10_conf-1': {'E_spc (Hartree)': -342.928072,
#     'E (Hartree)': -342.993572,
#     'ZPE(Hartree)': 0.133678,
#     'H_spc(Hartree)': -342.786323,
#     'T*S': 0.040279,
#     'T*qh_S': 0.039524,
#     'G(T)_spc(Hartree)': -342.826603,
#     'qh_G(T)_spc(Hartree)': -342.825848,
#     'T': 298.15}},
#   {'pyrmd10_conf-2': {'E_spc (Hartree)': -342.927156,
#     'E (Hartree)': -342.992064,
#     'ZPE(Hartree)': 0.13373,
#     'H_spc(Hartree)': -342.785399,
#     'T*S': 0.040524,
#     'T*qh_S': 0.039528,
#     'G(T)_spc(Hartree)': -342.825923,
#     'qh_G(T)_spc(Hartree)': -342.824927,
#     'T': 298.15}}],
#  'pyrd11': [{'pyrd11_conf-1': {'E_spc (Hartree)': -480.521016,
#     'E (Hartree)': -480.625163,
#     'ZPE(Hartree)': 0.192386,
#     'H_spc(Hartree)': -480.318012,
#     'T*S': 0.046041,
#     'T*qh_S': 0.045268,
#     'G(T)_spc(Hartree)': -480.364052,
#     'qh_G(T)_spc(Hartree)': -480.36328,
#     'T': 298.15}}],
#  'pyrd12': [{'pyrd12_conf-1': {'E_spc (Hartree)': -480.517722,
#     'E (Hartree)': -480.622341,
#     'ZPE(Hartree)': 0.192841,
#     'H_spc(Hartree)': -480.314382,
#     'T*S': 0.045334,
#     'T*qh_S': 0.045037,
#     'G(T)_spc(Hartree)': -480.359715,
#     'qh_G(T)_spc(Hartree)': -480.359419,
#     'T': 298.15}},
#   {'pyrd12_conf-2': {'E_spc (Hartree)': -480.517209,
#     'E (Hartree)': -480.620917,
#     'ZPE(Hartree)': 0.192886,
#     'H_spc(Hartree)': -480.313863,
#     'T*S': 0.04528,
#     'T*qh_S': 0.044905,
#     'G(T)_spc(Hartree)': -480.359143,
#     'qh_G(T)_spc(Hartree)': -480.358768,
#     'T': 298.15}}],
#  'pyrd13': [{'pyrd13_conf-1': {'E_spc (Hartree)': -287.578876,
#     'E (Hartree)': -287.638359,
#     'ZPE(Hartree)': 0.116331,
#     'H_spc(Hartree)': -287.455541,
#     'T*S': 0.037366,
#     'T*qh_S': 0.03678,
#     'G(T)_spc(Hartree)': -287.492907,
#     'qh_G(T)_spc(Hartree)': -287.492322,
#     'T': 298.15}}],
#  'pyrd14': [{'pyrd14_conf-1': {'E_spc (Hartree)': -287.576157,
#     'E (Hartree)': -287.636242,
#     'ZPE(Hartree)': 0.116447,
#     'H_spc(Hartree)': -287.452703,
#     'T*S': 0.037376,
#     'T*qh_S': 0.036794,
#     'G(T)_spc(Hartree)': -287.490079,
#     'qh_G(T)_spc(Hartree)': -287.489497,
#     'T': 298.15}}],
#  'pyrd15': [{'pyrd15_conf-1': {'E_spc (Hartree)': -287.577105,
#     'E (Hartree)': -287.637017,
#     'ZPE(Hartree)': 0.116409,
#     'H_spc(Hartree)': -287.453646,
#     'T*S': 0.037882,
#     'T*qh_S': 0.037026,
#     'G(T)_spc(Hartree)': -287.491528,
#     'qh_G(T)_spc(Hartree)': -287.490673,
#     'T': 298.15}}],
#  'pyrd16': [{'pyrd16_conf-1': {'E_spc (Hartree)': -326.885976,
#     'E (Hartree)': -326.960226,
#     'ZPE(Hartree)': 0.145383,
#     'H_spc(Hartree)': -326.732464,
#     'T*S': 0.040192,
#     'T*qh_S': 0.039501,
#     'G(T)_spc(Hartree)': -326.772656,
#     'qh_G(T)_spc(Hartree)': -326.771966,
#     'T': 298.15}},
#   {'pyrd16_conf-2': {'E_spc (Hartree)': -326.885975,
#     'E (Hartree)': -326.960226,
#     'ZPE(Hartree)': 0.145382,
#     'H_spc(Hartree)': -326.732465,
#     'T*S': 0.04019,
#     'T*qh_S': 0.0395,
#     'G(T)_spc(Hartree)': -326.772655,
#     'qh_G(T)_spc(Hartree)': -326.771965,
#     'T': 298.15}},
#   {'pyrd16_conf-3': {'E_spc (Hartree)': -326.885195,
#     'E (Hartree)': -326.958923,
#     'ZPE(Hartree)': 0.145329,
#     'H_spc(Hartree)': -326.73179,
#     'T*S': 0.040001,
#     'T*qh_S': 0.03933,
#     'G(T)_spc(Hartree)': -326.771791,
#     'qh_G(T)_spc(Hartree)': -326.77112,
#     'T': 298.15}}],
#  'pyrd17': [{'pyrd17_conf-1': {'E_spc (Hartree)': -326.883,
#     'E (Hartree)': -326.95783,
#     'ZPE(Hartree)': 0.145429,
#     'H_spc(Hartree)': -326.729424,
#     'T*S': 0.040296,
#     'T*qh_S': 0.03958,
#     'G(T)_spc(Hartree)': -326.76972,
#     'qh_G(T)_spc(Hartree)': -326.769004,
#     'T': 298.15}},
#   {'pyrd17_conf-2': {'E_spc (Hartree)': -326.882128,
#     'E (Hartree)': -326.95633,
#     'ZPE(Hartree)': 0.145431,
#     'H_spc(Hartree)': -326.728565,
#     'T*S': 0.040996,
#     'T*qh_S': 0.039812,
#     'G(T)_spc(Hartree)': -326.769561,
#     'qh_G(T)_spc(Hartree)': -326.768378,
#     'T': 298.15}},
#   {'pyrd17_conf-3': {'E_spc (Hartree)': -326.881867,
#     'E (Hartree)': -326.956078,
#     'ZPE(Hartree)': 0.145503,
#     'H_spc(Hartree)': -326.728274,
#     'T*S': 0.040272,
#     'T*qh_S': 0.03945,
#     'G(T)_spc(Hartree)': -326.768546,
#     'qh_G(T)_spc(Hartree)': -326.767724,
#     'T': 298.15}}],
#  'pyrd18': [{'pyrd18_conf-1': {'E_spc (Hartree)': -326.883963,
#     'E (Hartree)': -326.958638,
#     'ZPE(Hartree)': 0.14546,
#     'H_spc(Hartree)': -326.73035,
#     'T*S': 0.040399,
#     'T*qh_S': 0.039627,
#     'G(T)_spc(Hartree)': -326.770749,
#     'qh_G(T)_spc(Hartree)': -326.769977,
#     'T': 298.15}},
#   {'pyrd18_conf-2': {'E_spc (Hartree)': -326.88338,
#     'E (Hartree)': -326.957421,
#     'ZPE(Hartree)': 0.145469,
#     'H_spc(Hartree)': -326.729812,
#     'T*S': 0.040304,
#     'T*qh_S': 0.039483,
#     'G(T)_spc(Hartree)': -326.770116,
#     'qh_G(T)_spc(Hartree)': -326.769294,
#     'T': 298.15}}]}

# %%
# Function to select the conformer with the lowest specified energy property for each substrate
def select_lowest_energy_conformer(substrates: dict, column: str = "E (Hartree)") -> dict:
    print(f"filtering based on {column}")
    result_filtered = {}
    for substrate, conformers in substrates.items():
        print(f"--------------------------------------------------------------")
        print(f"for substrate {substrate}, we have {len(conformers)} conformers")
        for conformer in conformers:
            print(
                f"{list(conformer.keys())[0]} have {column}: {list(conformer.values())[0].get(column, None)}"
            )
        # Find the conformer with the minimum specified energy value
        min_conformer = min(
            conformers, key=lambda x: list(x.values())[0].get(column, float("inf"))
        )
        print(f"lowest energy conformer: {list(min_conformer.keys())[0]}")
        # Add the lowest energy conformer to the result dictionary
        result_filtered[substrate] = min_conformer
    return result_filtered


filtered_result = select_lowest_energy_conformer(
    result_grouped_by_substrates, column="E (Hartree)"
)
# Out:
# filtering based on E (Hartree)
# --------------------------------------------------------------
# for substrate pyrd1, we have 1 conformers
# pyrd1_conf-1 have E (Hartree): -441.305193
# lowest energy conformer: pyrd1_conf-1
# --------------------------------------------------------------
# for substrate pyrdz1, we have 1 conformers
# pyrdz1_conf-1 have E (Hartree): -303.638581
# lowest energy conformer: pyrdz1_conf-1
# --------------------------------------------------------------
# for substrate pyrmd1, we have 1 conformers
# pyrmd1_conf-1 have E (Hartree): -457.34237
# lowest energy conformer: pyrmd1_conf-1
# --------------------------------------------------------------
# for substrate pyrz1, we have 1 conformers
# pyrz1_conf-1 have E (Hartree): -457.336221
# lowest energy conformer: pyrz1_conf-1
# --------------------------------------------------------------
# for substrate pyrd2, we have 1 conformers
# pyrd2_conf-1 have E (Hartree): -441.302704
# lowest energy conformer: pyrd2_conf-1
# --------------------------------------------------------------
# for substrate pyrdz2, we have 1 conformers
# pyrdz2_conf-1 have E (Hartree): -303.637264
# lowest energy conformer: pyrdz2_conf-1
# --------------------------------------------------------------
# for substrate pyrmd2, we have 1 conformers
# pyrmd2_conf-1 have E (Hartree): -457.341909
# lowest energy conformer: pyrmd2_conf-1
# --------------------------------------------------------------
# for substrate pyrz2, we have 3 conformers
# pyrz2_conf-1 have E (Hartree): -496.657687
# pyrz2_conf-2 have E (Hartree): -496.657655
# pyrz2_conf-3 have E (Hartree): -496.657655
# lowest energy conformer: pyrz2_conf-1
# --------------------------------------------------------------
# for substrate pyrd3, we have 1 conformers
# pyrd3_conf-1 have E (Hartree): -441.303413
# lowest energy conformer: pyrd3_conf-1
# --------------------------------------------------------------
# for substrate pyrdz3, we have 3 conformers
# pyrdz3_conf-1 have E (Hartree): -342.960122
# pyrdz3_conf-2 have E (Hartree): -342.959411
# pyrdz3_conf-3 have E (Hartree): -342.958782
# lowest energy conformer: pyrdz3_conf-1
# --------------------------------------------------------------
# for substrate pyrmd3, we have 2 conformers
# pyrmd3_conf-1 have E (Hartree): -496.663916
# pyrmd3_conf-2 have E (Hartree): -496.664027
# lowest energy conformer: pyrmd3_conf-2
# --------------------------------------------------------------
# for substrate pyrz3, we have 1 conformers
# pyrz3_conf-1 have E (Hartree): -303.667899
# lowest energy conformer: pyrz3_conf-1
# --------------------------------------------------------------
# for substrate pyrd4, we have 1 conformers
# pyrd4_conf-1 have E (Hartree): -441.303006
# lowest energy conformer: pyrd4_conf-1
# --------------------------------------------------------------
# for substrate pyrmd4, we have 2 conformers
# pyrmd4_conf-1 have E (Hartree): -496.663024
# pyrmd4_conf-2 have E (Hartree): -496.663004
# lowest energy conformer: pyrmd4_conf-1
# --------------------------------------------------------------
# for substrate pyrz4, we have 2 conformers
# pyrz4_conf-1 have E (Hartree): -342.989674
# pyrz4_conf-2 have E (Hartree): -342.988179
# lowest energy conformer: pyrz4_conf-1
# --------------------------------------------------------------
# for substrate pyrd5, we have 1 conformers
# pyrd5_conf-1 have E (Hartree): -441.303293
# lowest energy conformer: pyrd5_conf-1
# --------------------------------------------------------------
# for substrate pyrmd5, we have 1 conformers
# pyrmd5_conf-1 have E (Hartree): -303.675314
# lowest energy conformer: pyrmd5_conf-1
# --------------------------------------------------------------
# for substrate pyrd6, we have 1 conformers
# pyrd6_conf-1 have E (Hartree): -441.301315
# lowest energy conformer: pyrd6_conf-1
# --------------------------------------------------------------
# for substrate pyrmd6, we have 1 conformers
# pyrmd6_conf-1 have E (Hartree): -303.675255
# lowest energy conformer: pyrmd6_conf-1
# --------------------------------------------------------------
# for substrate pyrd7, we have 3 conformers
# pyrd7_conf-1 have E (Hartree): -480.626623
# pyrd7_conf-2 have E (Hartree): -480.626608
# pyrd7_conf-3 have E (Hartree): -480.626608
# lowest energy conformer: pyrd7_conf-1
# --------------------------------------------------------------
# for substrate pyrmd7, we have 1 conformers
# pyrmd7_conf-1 have E (Hartree): -303.671939
# lowest energy conformer: pyrmd7_conf-1
# --------------------------------------------------------------
# for substrate pyrd8, we have 2 conformers
# pyrd8_conf-1 have E (Hartree): -480.624231
# pyrd8_conf-2 have E (Hartree): -480.623392
# lowest energy conformer: pyrd8_conf-1
# --------------------------------------------------------------
# for substrate pyrmd8, we have 2 conformers
# pyrmd8_conf-1 have E (Hartree): -342.9969
# pyrmd8_conf-2 have E (Hartree): -342.996597
# lowest energy conformer: pyrmd8_conf-1
# --------------------------------------------------------------
# for substrate pyrd9, we have 2 conformers
# pyrd9_conf-1 have E (Hartree): -480.624441
# pyrd9_conf-2 have E (Hartree): -480.623611
# lowest energy conformer: pyrd9_conf-1
# --------------------------------------------------------------
# for substrate pyrmd9, we have 2 conformers
# pyrmd9_conf-1 have E (Hartree): -342.99702
# pyrmd9_conf-2 have E (Hartree): -342.996068
# lowest energy conformer: pyrmd9_conf-1
# --------------------------------------------------------------
# for substrate pyrd10, we have 2 conformers
# pyrd10_conf-1 have E (Hartree): -480.624025
# pyrd10_conf-2 have E (Hartree): -480.623925
# lowest energy conformer: pyrd10_conf-1
# --------------------------------------------------------------
# for substrate pyrmd10, we have 2 conformers
# pyrmd10_conf-1 have E (Hartree): -342.993572
# pyrmd10_conf-2 have E (Hartree): -342.992064
# lowest energy conformer: pyrmd10_conf-1
# --------------------------------------------------------------
# for substrate pyrd11, we have 1 conformers
# pyrd11_conf-1 have E (Hartree): -480.625163
# lowest energy conformer: pyrd11_conf-1
# --------------------------------------------------------------
# for substrate pyrd12, we have 2 conformers
# pyrd12_conf-1 have E (Hartree): -480.622341
# pyrd12_conf-2 have E (Hartree): -480.620917
# lowest energy conformer: pyrd12_conf-1
# --------------------------------------------------------------
# for substrate pyrd13, we have 1 conformers
# pyrd13_conf-1 have E (Hartree): -287.638359
# lowest energy conformer: pyrd13_conf-1
# --------------------------------------------------------------
# for substrate pyrd14, we have 1 conformers
# pyrd14_conf-1 have E (Hartree): -287.636242
# lowest energy conformer: pyrd14_conf-1
# --------------------------------------------------------------
# for substrate pyrd15, we have 1 conformers
# pyrd15_conf-1 have E (Hartree): -287.637017
# lowest energy conformer: pyrd15_conf-1
# --------------------------------------------------------------
# for substrate pyrd16, we have 3 conformers
# pyrd16_conf-1 have E (Hartree): -326.960226
# pyrd16_conf-2 have E (Hartree): -326.960226
# pyrd16_conf-3 have E (Hartree): -326.958923
# lowest energy conformer: pyrd16_conf-1
# --------------------------------------------------------------
# for substrate pyrd17, we have 3 conformers
# pyrd17_conf-1 have E (Hartree): -326.95783
# pyrd17_conf-2 have E (Hartree): -326.95633
# pyrd17_conf-3 have E (Hartree): -326.956078
# lowest energy conformer: pyrd17_conf-1
# --------------------------------------------------------------
# for substrate pyrd18, we have 2 conformers
# pyrd18_conf-1 have E (Hartree): -326.958638
# pyrd18_conf-2 have E (Hartree): -326.957421
# lowest energy conformer: pyrd18_conf-1

# %%
filtered_result_filenames = []
for substrate, conformer in filtered_result.items():
    for conformer_name, properties in conformer.items():
        filtered_result_filenames.append(conformer_name)
print(f"filter down to {len(filtered_result_filenames)} COM files")
# Out:
# filter down to 35 COM files

# %%
if filter_anion:  # Filter anion com files
    print(f"filtering anion com files, save to {anion_com_output} folder")
    for filename in filtered_result_filenames:
        actual_filename = filename + "_anion" + file_extension
        print(
            f"{input_anion_com_folder}{os.sep}{actual_filename} -> {anion_com_output}{os.sep}{actual_filename}"
        )
        shutil.copy(input_anion_com_folder + os.sep + actual_filename, anion_com_output)
# Out:
# filtering anion com files, save to 3.anion_com_tom_filtered folder
# 2.anion_com_tom\pyrd1_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd1_conf-1_anion.com
# 2.anion_com_tom\pyrdz1_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrdz1_conf-1_anion.com
# 2.anion_com_tom\pyrmd1_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd1_conf-1_anion.com
# 2.anion_com_tom\pyrz1_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrz1_conf-1_anion.com
# 2.anion_com_tom\pyrd2_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd2_conf-1_anion.com
# 2.anion_com_tom\pyrdz2_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrdz2_conf-1_anion.com
# 2.anion_com_tom\pyrmd2_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd2_conf-1_anion.com
# 2.anion_com_tom\pyrz2_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrz2_conf-1_anion.com
# 2.anion_com_tom\pyrd3_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd3_conf-1_anion.com
# 2.anion_com_tom\pyrdz3_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrdz3_conf-1_anion.com
# 2.anion_com_tom\pyrmd3_conf-2_anion.com -> 3.anion_com_tom_filtered\pyrmd3_conf-2_anion.com
# 2.anion_com_tom\pyrz3_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrz3_conf-1_anion.com
# 2.anion_com_tom\pyrd4_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd4_conf-1_anion.com
# 2.anion_com_tom\pyrmd4_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd4_conf-1_anion.com
# 2.anion_com_tom\pyrz4_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrz4_conf-1_anion.com
# 2.anion_com_tom\pyrd5_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd5_conf-1_anion.com
# 2.anion_com_tom\pyrmd5_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd5_conf-1_anion.com
# 2.anion_com_tom\pyrd6_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd6_conf-1_anion.com
# 2.anion_com_tom\pyrmd6_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd6_conf-1_anion.com
# 2.anion_com_tom\pyrd7_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd7_conf-1_anion.com
# 2.anion_com_tom\pyrmd7_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd7_conf-1_anion.com
# 2.anion_com_tom\pyrd8_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd8_conf-1_anion.com
# 2.anion_com_tom\pyrmd8_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd8_conf-1_anion.com
# 2.anion_com_tom\pyrd9_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd9_conf-1_anion.com
# 2.anion_com_tom\pyrmd9_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd9_conf-1_anion.com
# 2.anion_com_tom\pyrd10_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd10_conf-1_anion.com
# 2.anion_com_tom\pyrmd10_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrmd10_conf-1_anion.com
# 2.anion_com_tom\pyrd11_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd11_conf-1_anion.com
# 2.anion_com_tom\pyrd12_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd12_conf-1_anion.com
# 2.anion_com_tom\pyrd13_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd13_conf-1_anion.com
# 2.anion_com_tom\pyrd14_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd14_conf-1_anion.com
# 2.anion_com_tom\pyrd15_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd15_conf-1_anion.com
# 2.anion_com_tom\pyrd16_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd16_conf-1_anion.com
# 2.anion_com_tom\pyrd17_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd17_conf-1_anion.com
# 2.anion_com_tom\pyrd18_conf-1_anion.com -> 3.anion_com_tom_filtered\pyrd18_conf-1_anion.com

# %%
if filter_open_shell:  # Filter open shell com files
    print(f"filtering open shell com files")
    for filename in filtered_result_filenames:
        actual_filename = filename + "_openshell" + file_extension
        print(
            f"{input_open_shell_com_folder}{os.sep}{actual_filename} -> {open_shell_com_output}{os.sep}{actual_filename}"
        )
        shutil.copy(input_open_shell_com_folder + os.sep + actual_filename, open_shell_com_output)
# Out:
# filtering open shell com files
# 1.open_shell_com_tom\pyrd1_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd1_conf-1_openshell.com
# 1.open_shell_com_tom\pyrdz1_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrdz1_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd1_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd1_conf-1_openshell.com
# 1.open_shell_com_tom\pyrz1_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrz1_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd2_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd2_conf-1_openshell.com
# 1.open_shell_com_tom\pyrdz2_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrdz2_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd2_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd2_conf-1_openshell.com
# 1.open_shell_com_tom\pyrz2_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrz2_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd3_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd3_conf-1_openshell.com
# 1.open_shell_com_tom\pyrdz3_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrdz3_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd3_conf-2_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd3_conf-2_openshell.com
# 1.open_shell_com_tom\pyrz3_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrz3_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd4_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd4_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd4_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd4_conf-1_openshell.com
# 1.open_shell_com_tom\pyrz4_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrz4_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd5_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd5_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd5_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd5_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd6_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd6_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd6_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd6_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd7_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd7_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd7_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd7_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd8_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd8_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd8_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd8_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd9_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd9_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd9_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd9_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd10_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd10_conf-1_openshell.com
# 1.open_shell_com_tom\pyrmd10_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrmd10_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd11_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd11_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd12_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd12_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd13_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd13_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd14_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd14_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd15_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd15_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd16_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd16_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd17_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd17_conf-1_openshell.com
# 1.open_shell_com_tom\pyrd18_conf-1_openshell.com -> 3.open_shell_com_tom_filtered\pyrd18_conf-1_openshell.com
