# %%
import re, sys, glob, io
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib.colors import ColorConverter

randomstate = 42

from rdkit import Chem
from rdkit.Chem.Draw import IPythonConsole

import ipywidgets as widgets

# %%
# we have to map to their corresponding core structures
common_structure_list = {}

common_structure_chemdraw = glob.glob("*.cdxml")
common_structure_chemdraw

for file in common_structure_chemdraw:
    # get the filename without the extension, we will use it as the prefix
    key = file.split(".")[0]
    substructure = Chem.MolsFromCDXMLFile(file)
    # output to Smarts format
    temp_smarts = Chem.MolToSmarts(substructure[0])
    # reparse the Smarts, this is in case the structure from the cdxml file is not the same as from the SMILES string
    substructure = Chem.MolFromSmarts(temp_smarts)
    # add the substructure to the dictionary
    common_structure_list[key] = substructure

# Prepare the list of molecules and corresponding legends (for display under each molecule)
mols = list(common_structure_list.values())
legends = list(common_structure_list.keys())
# Generate a grid image with a fixed number of columns (4 columns)
img = Chem.Draw.MolsToGridImage(
    mols, molsPerRow=4, subImgSize=(200, 200), legends=legends
)
# Display the grid of images
display(img)

# %%
# load an excel file name smiles.xlsx
df = pd.read_excel('smiles.xlsx')
# use RDKit convert SMILES to mol object, make a dict with id as key and mol object as value
mols = {}
for i, row in df.iterrows():
    mols[row['id']] = Chem.MolFromSmiles(row['SMILES'])

# %%
# display the first 5 molecules
for i, (id, mol) in enumerate(mols.items()):
    if i >= 5:
        break
    display(mol)

# %%
# now attempt to match all common structures to each molecule, and if we find a match, we will store into a mapping from original id to new prefix
# use GetSubstructMatches
mapping = {}
for id, mol in mols.items():
    for key, substructure in common_structure_list.items():
        if mol.HasSubstructMatch(substructure):
            # first check if this id is already in the mapping
            if id in mapping:
                print(f'{id} already in mapping, will not overwrite with {key}')
            else:
                print(f'{id} matches {key}')
                mapping[id] = key
# Out:
# Het001 matches pyrd
# Het002 matches pyrd
# Het003 matches pyrd
# Het004 matches pyrmd
# Het005 matches pyrmd
# Het006 matches pyrz
# Het007 matches pyrd
# Het008 matches pyrd
# Het009 matches pyrd
# Het010 matches pyrd
# Het011 matches pyrd
# Het012 matches pyrd
# Het013 matches pyrmd
# Het014 matches pyrmd
# Het015 matches pyrz
# Het016 matches pyrd
# Het017 matches pyrd
# Het018 matches pyrd
# Het019 matches pyrd
# Het020 matches pyrd
# Het021 matches pyrd
# Het022 matches pyrmd
# Het023 matches pyrmd
# Het024 matches pyrmd
# Het025 matches pyrz
# Het026 matches pyrdz
# Het027 matches pyrdz
# Het028 matches pyrd
# Het029 matches pyrd
# Het030 matches pyrd
# Het031 matches pyrmd
# Het032 matches pyrmd
# Het033 matches pyrmd
# Het034 matches pyrz
# Het035 matches pyrdz

# %%
mapping
# Out:
# {'Het001': 'pyrd',
#  'Het002': 'pyrd',
#  'Het003': 'pyrd',
#  'Het004': 'pyrmd',
#  'Het005': 'pyrmd',
#  'Het006': 'pyrz',
#  'Het007': 'pyrd',
#  'Het008': 'pyrd',
#  'Het009': 'pyrd',
#  'Het010': 'pyrd',
#  'Het011': 'pyrd',
#  'Het012': 'pyrd',
#  'Het013': 'pyrmd',
#  'Het014': 'pyrmd',
#  'Het015': 'pyrz',
#  'Het016': 'pyrd',
#  'Het017': 'pyrd',
#  'Het018': 'pyrd',
#  'Het019': 'pyrd',
#  'Het020': 'pyrd',
#  'Het021': 'pyrd',
#  'Het022': 'pyrmd',
#  'Het023': 'pyrmd',
#  'Het024': 'pyrmd',
#  'Het025': 'pyrz',
#  'Het026': 'pyrdz',
#  'Het027': 'pyrdz',
#  'Het028': 'pyrd',
#  'Het029': 'pyrd',
#  'Het030': 'pyrd',
#  'Het031': 'pyrmd',
#  'Het032': 'pyrmd',
#  'Het033': 'pyrmd',
#  'Het034': 'pyrz',
#  'Het035': 'pyrdz'}

# %%
# now step into to logs folder, rename the files to the new prefix
# the original file is named like Het001_conf-1.log
# the goal is to swap "Het001" to the new prefix pyrd and add a unique number to the end, in this case pyrd1
# maintain four counter starting from 1 for each prefix
# we will use the os module to rename the files

import os
import re
import shutil

final_mapping = {}

# create a new folder to store the renamed files
os.makedirs("renamed_logs", exist_ok=True)

# create a counter for each prefix
counter = {}
for key in common_structure_list.keys():
    counter[key] = 1
    
file_list = glob.glob("logs/*.log")
# sort the file list
file_list.sort()


# loop through the logs folder
for file in file_list:
    # get the filename without the extension
    filename = os.path.basename(file).split(".")[0]
    # get the prefix
    prefix = filename.split("-")[0]
    subprefix = prefix.split("_")[0]
    # store the other part of the filename
    other = filename.split("-")[1]
    # split by - get the first part, check against all key in the final_mapping
    if prefix in final_mapping:
        print(f"{prefix} already in final_mapping, will not overwrite")
        continue
    print(
        f"Processing {filename}, prefix: {prefix}, subprefix: {subprefix}, other: {other}"
    )

    # check if the subprefix is already in the final_mapping
    if subprefix not in final_mapping:
        new_filename = (
            mapping[subprefix]
            + str(counter[mapping[subprefix]])
            + "_conf-"
            + other
            + ".log"
        )
        # this mean we haven't assign a new number to this subprefix
        final_mapping[subprefix] = [new_filename]
        # increment the counter
        counter[mapping[subprefix]] += 1
    else:
        # now this subprefix is already assign a new number, we will reuse the number
        # note we will not use the counter and instead we will use regex to extract the number
        number = int(re.search(r"(\d+)_", final_mapping[subprefix][-1]).group(1))
        print(
            f"New number alreadu assigned: {number}, extract from {final_mapping[subprefix][-1]}"
        )
        new_filename = mapping[subprefix] + str(number) + "_conf-" + other + ".log"
        final_mapping[subprefix].append(new_filename)

    print(f"New filename: {new_filename}")
    print(f"Renaming {filename} to {new_filename}")
    if os.path.exists(f"renamed_logs/{new_filename}"):
        print(f"Warning: {new_filename} already exists, will overwrite")
    print("-----------------------------")
    # check if the file already exists in renamed_logs
    # copy the file with the new prefix to renamed_logs
    shutil.copy(file, f"renamed_logs/{new_filename}")
# Out:
# Processing Het001_conf-1, prefix: Het001_conf, subprefix: Het001, other: 1
# New filename: pyrd1_conf-1.log
# Renaming Het001_conf-1 to pyrd1_conf-1.log
# Warning: pyrd1_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het002_conf-1, prefix: Het002_conf, subprefix: Het002, other: 1
# New filename: pyrd2_conf-1.log
# Renaming Het002_conf-1 to pyrd2_conf-1.log
# Warning: pyrd2_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het003_conf-1, prefix: Het003_conf, subprefix: Het003, other: 1
# New filename: pyrd3_conf-1.log
# Renaming Het003_conf-1 to pyrd3_conf-1.log
# Warning: pyrd3_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het004_conf-1, prefix: Het004_conf, subprefix: Het004, other: 1
# New filename: pyrmd1_conf-1.log
# Renaming Het004_conf-1 to pyrmd1_conf-1.log
# Warning: pyrmd1_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het005_conf-1, prefix: Het005_conf, subprefix: Het005, other: 1
# New filename: pyrmd2_conf-1.log
# Renaming Het005_conf-1 to pyrmd2_conf-1.log
# Warning: pyrmd2_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het006_conf-1, prefix: Het006_conf, subprefix: Het006, other: 1
# New filename: pyrz1_conf-1.log
# Renaming Het006_conf-1 to pyrz1_conf-1.log
# Warning: pyrz1_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het007_conf-1, prefix: Het007_conf, subprefix: Het007, other: 1
# New filename: pyrd4_conf-1.log
# Renaming Het007_conf-1 to pyrd4_conf-1.log
# Warning: pyrd4_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het008_conf-1, prefix: Het008_conf, subprefix: Het008, other: 1
# New filename: pyrd5_conf-1.log
# Renaming Het008_conf-1 to pyrd5_conf-1.log
# Warning: pyrd5_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het009_conf-1, prefix: Het009_conf, subprefix: Het009, other: 1
# New filename: pyrd6_conf-1.log
# Renaming Het009_conf-1 to pyrd6_conf-1.log
# Warning: pyrd6_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het010_conf-1, prefix: Het010_conf, subprefix: Het010, other: 1
# New filename: pyrd7_conf-1.log
# Renaming Het010_conf-1 to pyrd7_conf-1.log
# Warning: pyrd7_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het010_conf-2, prefix: Het010_conf, subprefix: Het010, other: 2
# New number alreadu assigned: 7, extract from pyrd7_conf-1.log
# New filename: pyrd7_conf-2.log
# Renaming Het010_conf-2 to pyrd7_conf-2.log
# Warning: pyrd7_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het010_conf-3, prefix: Het010_conf, subprefix: Het010, other: 3
# New number alreadu assigned: 7, extract from pyrd7_conf-2.log
# New filename: pyrd7_conf-3.log
# Renaming Het010_conf-3 to pyrd7_conf-3.log
# Warning: pyrd7_conf-3.log already exists, will overwrite
# -----------------------------
# Processing Het011_conf-1, prefix: Het011_conf, subprefix: Het011, other: 1
# New filename: pyrd8_conf-1.log
# Renaming Het011_conf-1 to pyrd8_conf-1.log
# Warning: pyrd8_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het011_conf-2, prefix: Het011_conf, subprefix: Het011, other: 2
# New number alreadu assigned: 8, extract from pyrd8_conf-1.log
# New filename: pyrd8_conf-2.log
# Renaming Het011_conf-2 to pyrd8_conf-2.log
# Warning: pyrd8_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het012_conf-1, prefix: Het012_conf, subprefix: Het012, other: 1
# New filename: pyrd9_conf-1.log
# Renaming Het012_conf-1 to pyrd9_conf-1.log
# Warning: pyrd9_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het012_conf-2, prefix: Het012_conf, subprefix: Het012, other: 2
# New number alreadu assigned: 9, extract from pyrd9_conf-1.log
# New filename: pyrd9_conf-2.log
# Renaming Het012_conf-2 to pyrd9_conf-2.log
# Warning: pyrd9_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het013_conf-1, prefix: Het013_conf, subprefix: Het013, other: 1
# New filename: pyrmd3_conf-1.log
# Renaming Het013_conf-1 to pyrmd3_conf-1.log
# Warning: pyrmd3_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het013_conf-2, prefix: Het013_conf, subprefix: Het013, other: 2
# New number alreadu assigned: 3, extract from pyrmd3_conf-1.log
# New filename: pyrmd3_conf-2.log
# Renaming Het013_conf-2 to pyrmd3_conf-2.log
# Warning: pyrmd3_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het014_conf-1, prefix: Het014_conf, subprefix: Het014, other: 1
# New filename: pyrmd4_conf-1.log
# Renaming Het014_conf-1 to pyrmd4_conf-1.log
# Warning: pyrmd4_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het014_conf-2, prefix: Het014_conf, subprefix: Het014, other: 2
# New number alreadu assigned: 4, extract from pyrmd4_conf-1.log
# New filename: pyrmd4_conf-2.log
# Renaming Het014_conf-2 to pyrmd4_conf-2.log
# Warning: pyrmd4_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het015_conf-1, prefix: Het015_conf, subprefix: Het015, other: 1
# New filename: pyrz2_conf-1.log
# Renaming Het015_conf-1 to pyrz2_conf-1.log
# Warning: pyrz2_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het015_conf-2, prefix: Het015_conf, subprefix: Het015, other: 2
# New number alreadu assigned: 2, extract from pyrz2_conf-1.log
# New filename: pyrz2_conf-2.log
# Renaming Het015_conf-2 to pyrz2_conf-2.log
# Warning: pyrz2_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het015_conf-3, prefix: Het015_conf, subprefix: Het015, other: 3
# New number alreadu assigned: 2, extract from pyrz2_conf-2.log
# New filename: pyrz2_conf-3.log
# Renaming Het015_conf-3 to pyrz2_conf-3.log
# Warning: pyrz2_conf-3.log already exists, will overwrite
# -----------------------------
# Processing Het016_conf-1, prefix: Het016_conf, subprefix: Het016, other: 1
# New filename: pyrd10_conf-1.log
# Renaming Het016_conf-1 to pyrd10_conf-1.log
# Warning: pyrd10_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het016_conf-2, prefix: Het016_conf, subprefix: Het016, other: 2
# New number alreadu assigned: 10, extract from pyrd10_conf-1.log
# New filename: pyrd10_conf-2.log
# Renaming Het016_conf-2 to pyrd10_conf-2.log
# Warning: pyrd10_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het017_conf-1, prefix: Het017_conf, subprefix: Het017, other: 1
# New filename: pyrd11_conf-1.log
# Renaming Het017_conf-1 to pyrd11_conf-1.log
# Warning: pyrd11_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het018_conf-1, prefix: Het018_conf, subprefix: Het018, other: 1
# New filename: pyrd12_conf-1.log
# Renaming Het018_conf-1 to pyrd12_conf-1.log
# Warning: pyrd12_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het018_conf-2, prefix: Het018_conf, subprefix: Het018, other: 2
# New number alreadu assigned: 12, extract from pyrd12_conf-1.log
# New filename: pyrd12_conf-2.log
# Renaming Het018_conf-2 to pyrd12_conf-2.log
# Warning: pyrd12_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het019_conf-1, prefix: Het019_conf, subprefix: Het019, other: 1
# New filename: pyrd13_conf-1.log
# Renaming Het019_conf-1 to pyrd13_conf-1.log
# Warning: pyrd13_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het020_conf-1, prefix: Het020_conf, subprefix: Het020, other: 1
# New filename: pyrd14_conf-1.log
# Renaming Het020_conf-1 to pyrd14_conf-1.log
# Warning: pyrd14_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het021_conf-1, prefix: Het021_conf, subprefix: Het021, other: 1
# New filename: pyrd15_conf-1.log
# Renaming Het021_conf-1 to pyrd15_conf-1.log
# Warning: pyrd15_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het022_conf-1, prefix: Het022_conf, subprefix: Het022, other: 1
# New filename: pyrmd5_conf-1.log
# Renaming Het022_conf-1 to pyrmd5_conf-1.log
# Warning: pyrmd5_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het023_conf-1, prefix: Het023_conf, subprefix: Het023, other: 1
# New filename: pyrmd6_conf-1.log
# Renaming Het023_conf-1 to pyrmd6_conf-1.log
# Warning: pyrmd6_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het024_conf-1, prefix: Het024_conf, subprefix: Het024, other: 1
# New filename: pyrmd7_conf-1.log
# Renaming Het024_conf-1 to pyrmd7_conf-1.log
# Warning: pyrmd7_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het025_conf-1, prefix: Het025_conf, subprefix: Het025, other: 1
# New filename: pyrz3_conf-1.log
# Renaming Het025_conf-1 to pyrz3_conf-1.log
# Warning: pyrz3_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het026_conf-1, prefix: Het026_conf, subprefix: Het026, other: 1
# New filename: pyrdz1_conf-1.log
# Renaming Het026_conf-1 to pyrdz1_conf-1.log
# Warning: pyrdz1_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het027_conf-1, prefix: Het027_conf, subprefix: Het027, other: 1
# New filename: pyrdz2_conf-1.log
# Renaming Het027_conf-1 to pyrdz2_conf-1.log
# Warning: pyrdz2_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het028_conf-1, prefix: Het028_conf, subprefix: Het028, other: 1
# New filename: pyrd16_conf-1.log
# Renaming Het028_conf-1 to pyrd16_conf-1.log
# Warning: pyrd16_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het028_conf-2, prefix: Het028_conf, subprefix: Het028, other: 2
# New number alreadu assigned: 16, extract from pyrd16_conf-1.log
# New filename: pyrd16_conf-2.log
# Renaming Het028_conf-2 to pyrd16_conf-2.log
# Warning: pyrd16_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het028_conf-3, prefix: Het028_conf, subprefix: Het028, other: 3
# New number alreadu assigned: 16, extract from pyrd16_conf-2.log
# New filename: pyrd16_conf-3.log
# Renaming Het028_conf-3 to pyrd16_conf-3.log
# Warning: pyrd16_conf-3.log already exists, will overwrite
# -----------------------------
# Processing Het029_conf-1, prefix: Het029_conf, subprefix: Het029, other: 1
# New filename: pyrd17_conf-1.log
# Renaming Het029_conf-1 to pyrd17_conf-1.log
# Warning: pyrd17_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het029_conf-2, prefix: Het029_conf, subprefix: Het029, other: 2
# New number alreadu assigned: 17, extract from pyrd17_conf-1.log
# New filename: pyrd17_conf-2.log
# Renaming Het029_conf-2 to pyrd17_conf-2.log
# Warning: pyrd17_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het029_conf-3, prefix: Het029_conf, subprefix: Het029, other: 3
# New number alreadu assigned: 17, extract from pyrd17_conf-2.log
# New filename: pyrd17_conf-3.log
# Renaming Het029_conf-3 to pyrd17_conf-3.log
# Warning: pyrd17_conf-3.log already exists, will overwrite
# -----------------------------
# Processing Het030_conf-1, prefix: Het030_conf, subprefix: Het030, other: 1
# New filename: pyrd18_conf-1.log
# Renaming Het030_conf-1 to pyrd18_conf-1.log
# Warning: pyrd18_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het030_conf-2, prefix: Het030_conf, subprefix: Het030, other: 2
# New number alreadu assigned: 18, extract from pyrd18_conf-1.log
# New filename: pyrd18_conf-2.log
# Renaming Het030_conf-2 to pyrd18_conf-2.log
# Warning: pyrd18_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het031_conf-1, prefix: Het031_conf, subprefix: Het031, other: 1
# New filename: pyrmd8_conf-1.log
# Renaming Het031_conf-1 to pyrmd8_conf-1.log
# Warning: pyrmd8_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het031_conf-2, prefix: Het031_conf, subprefix: Het031, other: 2
# New number alreadu assigned: 8, extract from pyrmd8_conf-1.log
# New filename: pyrmd8_conf-2.log
# Renaming Het031_conf-2 to pyrmd8_conf-2.log
# Warning: pyrmd8_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het032_conf-1, prefix: Het032_conf, subprefix: Het032, other: 1
# New filename: pyrmd9_conf-1.log
# Renaming Het032_conf-1 to pyrmd9_conf-1.log
# Warning: pyrmd9_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het032_conf-2, prefix: Het032_conf, subprefix: Het032, other: 2
# New number alreadu assigned: 9, extract from pyrmd9_conf-1.log
# New filename: pyrmd9_conf-2.log
# Renaming Het032_conf-2 to pyrmd9_conf-2.log
# Warning: pyrmd9_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het033_conf-1, prefix: Het033_conf, subprefix: Het033, other: 1
# New filename: pyrmd10_conf-1.log
# Renaming Het033_conf-1 to pyrmd10_conf-1.log
# Warning: pyrmd10_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het033_conf-2, prefix: Het033_conf, subprefix: Het033, other: 2
# New number alreadu assigned: 10, extract from pyrmd10_conf-1.log
# New filename: pyrmd10_conf-2.log
# Renaming Het033_conf-2 to pyrmd10_conf-2.log
# Warning: pyrmd10_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het034_conf-1, prefix: Het034_conf, subprefix: Het034, other: 1
# New filename: pyrz4_conf-1.log
# Renaming Het034_conf-1 to pyrz4_conf-1.log
# Warning: pyrz4_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het034_conf-2, prefix: Het034_conf, subprefix: Het034, other: 2
# New number alreadu assigned: 4, extract from pyrz4_conf-1.log
# New filename: pyrz4_conf-2.log
# Renaming Het034_conf-2 to pyrz4_conf-2.log
# Warning: pyrz4_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het035_conf-1, prefix: Het035_conf, subprefix: Het035, other: 1
# New filename: pyrdz3_conf-1.log
# Renaming Het035_conf-1 to pyrdz3_conf-1.log
# Warning: pyrdz3_conf-1.log already exists, will overwrite
# -----------------------------
# Processing Het035_conf-2, prefix: Het035_conf, subprefix: Het035, other: 2
# New number alreadu assigned: 3, extract from pyrdz3_conf-1.log
# New filename: pyrdz3_conf-2.log
# Renaming Het035_conf-2 to pyrdz3_conf-2.log
# Warning: pyrdz3_conf-2.log already exists, will overwrite
# -----------------------------
# Processing Het035_conf-3, prefix: Het035_conf, subprefix: Het035, other: 3
# New number alreadu assigned: 3, extract from pyrdz3_conf-2.log
# New filename: pyrdz3_conf-3.log
# Renaming Het035_conf-3 to pyrdz3_conf-3.log
# Warning: pyrdz3_conf-3.log already exists, will overwrite
# -----------------------------

# %%
final_mapping
# Out:
# {'Het001': ['pyrd1_conf-1.log'],
#  'Het002': ['pyrd2_conf-1.log'],
#  'Het003': ['pyrd3_conf-1.log'],
#  'Het004': ['pyrmd1_conf-1.log'],
#  'Het005': ['pyrmd2_conf-1.log'],
#  'Het006': ['pyrz1_conf-1.log'],
#  'Het007': ['pyrd4_conf-1.log'],
#  'Het008': ['pyrd5_conf-1.log'],
#  'Het009': ['pyrd6_conf-1.log'],
#  'Het010': ['pyrd7_conf-1.log', 'pyrd7_conf-2.log', 'pyrd7_conf-3.log'],
#  'Het011': ['pyrd8_conf-1.log', 'pyrd8_conf-2.log'],
#  'Het012': ['pyrd9_conf-1.log', 'pyrd9_conf-2.log'],
#  'Het013': ['pyrmd3_conf-1.log', 'pyrmd3_conf-2.log'],
#  'Het014': ['pyrmd4_conf-1.log', 'pyrmd4_conf-2.log'],
#  'Het015': ['pyrz2_conf-1.log', 'pyrz2_conf-2.log', 'pyrz2_conf-3.log'],
#  'Het016': ['pyrd10_conf-1.log', 'pyrd10_conf-2.log'],
#  'Het017': ['pyrd11_conf-1.log'],
#  'Het018': ['pyrd12_conf-1.log', 'pyrd12_conf-2.log'],
#  'Het019': ['pyrd13_conf-1.log'],
#  'Het020': ['pyrd14_conf-1.log'],
#  'Het021': ['pyrd15_conf-1.log'],
#  'Het022': ['pyrmd5_conf-1.log'],
#  'Het023': ['pyrmd6_conf-1.log'],
#  'Het024': ['pyrmd7_conf-1.log'],
#  'Het025': ['pyrz3_conf-1.log'],
#  'Het026': ['pyrdz1_conf-1.log'],
#  'Het027': ['pyrdz2_conf-1.log'],
#  'Het028': ['pyrd16_conf-1.log', 'pyrd16_conf-2.log', 'pyrd16_conf-3.log'],
#  'Het029': ['pyrd17_conf-1.log', 'pyrd17_conf-2.log', 'pyrd17_conf-3.log'],
#  'Het030': ['pyrd18_conf-1.log', 'pyrd18_conf-2.log'],
#  'Het031': ['pyrmd8_conf-1.log', 'pyrmd8_conf-2.log'],
#  'Het032': ['pyrmd9_conf-1.log', 'pyrmd9_conf-2.log'],
#  'Het033': ['pyrmd10_conf-1.log', 'pyrmd10_conf-2.log'],
#  'Het034': ['pyrz4_conf-1.log', 'pyrz4_conf-2.log'],
#  'Het035': ['pyrdz3_conf-1.log', 'pyrdz3_conf-2.log', 'pyrdz3_conf-3.log']}

# %%
# sort the final_mapping by the key, use the number in the prefix, format is Het008, split by Het and get the numerical part and turn it into integer
sorted_mapping = dict(
    sorted(final_mapping.items(), key=lambda x: int(x[0].split("Het")[1]))
)

# %%
sorted_mapping
# Out:
# {'Het001': ['pyrd1_conf-1.log'],
#  'Het002': ['pyrd2_conf-1.log'],
#  'Het003': ['pyrd3_conf-1.log'],
#  'Het004': ['pyrmd1_conf-1.log'],
#  'Het005': ['pyrmd2_conf-1.log'],
#  'Het006': ['pyrz1_conf-1.log'],
#  'Het007': ['pyrd4_conf-1.log'],
#  'Het008': ['pyrd5_conf-1.log'],
#  'Het009': ['pyrd6_conf-1.log'],
#  'Het010': ['pyrd7_conf-1.log', 'pyrd7_conf-2.log', 'pyrd7_conf-3.log'],
#  'Het011': ['pyrd8_conf-1.log', 'pyrd8_conf-2.log'],
#  'Het012': ['pyrd9_conf-1.log', 'pyrd9_conf-2.log'],
#  'Het013': ['pyrmd3_conf-1.log', 'pyrmd3_conf-2.log'],
#  'Het014': ['pyrmd4_conf-1.log', 'pyrmd4_conf-2.log'],
#  'Het015': ['pyrz2_conf-1.log', 'pyrz2_conf-2.log', 'pyrz2_conf-3.log'],
#  'Het016': ['pyrd10_conf-1.log', 'pyrd10_conf-2.log'],
#  'Het017': ['pyrd11_conf-1.log'],
#  'Het018': ['pyrd12_conf-1.log', 'pyrd12_conf-2.log'],
#  'Het019': ['pyrd13_conf-1.log'],
#  'Het020': ['pyrd14_conf-1.log'],
#  'Het021': ['pyrd15_conf-1.log'],
#  'Het022': ['pyrmd5_conf-1.log'],
#  'Het023': ['pyrmd6_conf-1.log'],
#  'Het024': ['pyrmd7_conf-1.log'],
#  'Het025': ['pyrz3_conf-1.log'],
#  'Het026': ['pyrdz1_conf-1.log'],
#  'Het027': ['pyrdz2_conf-1.log'],
#  'Het028': ['pyrd16_conf-1.log', 'pyrd16_conf-2.log', 'pyrd16_conf-3.log'],
#  'Het029': ['pyrd17_conf-1.log', 'pyrd17_conf-2.log', 'pyrd17_conf-3.log'],
#  'Het030': ['pyrd18_conf-1.log', 'pyrd18_conf-2.log'],
#  'Het031': ['pyrmd8_conf-1.log', 'pyrmd8_conf-2.log'],
#  'Het032': ['pyrmd9_conf-1.log', 'pyrmd9_conf-2.log'],
#  'Het033': ['pyrmd10_conf-1.log', 'pyrmd10_conf-2.log'],
#  'Het034': ['pyrz4_conf-1.log', 'pyrz4_conf-2.log'],
#  'Het035': ['pyrdz3_conf-1.log', 'pyrdz3_conf-2.log', 'pyrdz3_conf-3.log']}

# %%
mapping
# Out:
# {'Het001': 'pyrd',
#  'Het002': 'pyrd',
#  'Het003': 'pyrd',
#  'Het004': 'pyrmd',
#  'Het005': 'pyrmd',
#  'Het006': 'pyrz',
#  'Het007': 'pyrd',
#  'Het008': 'pyrd',
#  'Het009': 'pyrd',
#  'Het010': 'pyrd',
#  'Het011': 'pyrd',
#  'Het012': 'pyrd',
#  'Het013': 'pyrmd',
#  'Het014': 'pyrmd',
#  'Het015': 'pyrz',
#  'Het016': 'pyrd',
#  'Het017': 'pyrd',
#  'Het018': 'pyrd',
#  'Het019': 'pyrd',
#  'Het020': 'pyrd',
#  'Het021': 'pyrd',
#  'Het022': 'pyrmd',
#  'Het023': 'pyrmd',
#  'Het024': 'pyrmd',
#  'Het025': 'pyrz',
#  'Het026': 'pyrdz',
#  'Het027': 'pyrdz',
#  'Het028': 'pyrd',
#  'Het029': 'pyrd',
#  'Het030': 'pyrd',
#  'Het031': 'pyrmd',
#  'Het032': 'pyrmd',
#  'Het033': 'pyrmd',
#  'Het034': 'pyrz',
#  'Het035': 'pyrdz'}

# %%
# inverse the mapping so that key is the new prefix and value is the original prefix, there are multiple same key in the mapping
inverse_mapping = {}
for key, value in mapping.items():
    if value in inverse_mapping:
        inverse_mapping[value].append(key)
    else:
        inverse_mapping[value] = [key]
        
inverse_mapping
# Out:
# {'pyrd': ['Het001',
#   'Het002',
#   'Het003',
#   'Het007',
#   'Het008',
#   'Het009',
#   'Het010',
#   'Het011',
#   'Het012',
#   'Het016',
#   'Het017',
#   'Het018',
#   'Het019',
#   'Het020',
#   'Het021',
#   'Het028',
#   'Het029',
#   'Het030'],
#  'pyrmd': ['Het004',
#   'Het005',
#   'Het013',
#   'Het014',
#   'Het022',
#   'Het023',
#   'Het024',
#   'Het031',
#   'Het032',
#   'Het033'],
#  'pyrz': ['Het006', 'Het015', 'Het025', 'Het034'],
#  'pyrdz': ['Het026', 'Het027', 'Het035']}

# %%
mols
# Out:
# {'Het001': <rdkit.Chem.rdchem.Mol at 0x1d6ab038b30>,
#  'Het002': <rdkit.Chem.rdchem.Mol at 0x1d6ab038660>,
#  'Het003': <rdkit.Chem.rdchem.Mol at 0x1d6ab038350>,
#  'Het004': <rdkit.Chem.rdchem.Mol at 0x1d6ab039150>,
#  'Het005': <rdkit.Chem.rdchem.Mol at 0x1d6ab0390e0>,
#  'Het006': <rdkit.Chem.rdchem.Mol at 0x1d6ab038820>,
#  'Het007': <rdkit.Chem.rdchem.Mol at 0x1d6ab038ac0>,
#  'Het008': <rdkit.Chem.rdchem.Mol at 0x1d6ab0389e0>,
#  'Het009': <rdkit.Chem.rdchem.Mol at 0x1d6ab038970>,
#  'Het010': <rdkit.Chem.rdchem.Mol at 0x1d6ab038900>,
#  'Het011': <rdkit.Chem.rdchem.Mol at 0x1d6ab038740>,
#  'Het012': <rdkit.Chem.rdchem.Mol at 0x1d6ab0386d0>,
#  'Het013': <rdkit.Chem.rdchem.Mol at 0x1d6ab038510>,
#  'Het014': <rdkit.Chem.rdchem.Mol at 0x1d6ab0383c0>,
#  'Het015': <rdkit.Chem.rdchem.Mol at 0x1d6ab0384a0>,
#  'Het016': <rdkit.Chem.rdchem.Mol at 0x1d6ab038430>,
#  'Het017': <rdkit.Chem.rdchem.Mol at 0x1d6ab038580>,
#  'Het018': <rdkit.Chem.rdchem.Mol at 0x1d6ab038dd0>,
#  'Het019': <rdkit.Chem.rdchem.Mol at 0x1d6ab038eb0>,
#  'Het020': <rdkit.Chem.rdchem.Mol at 0x1d6ab038f20>,
#  'Het021': <rdkit.Chem.rdchem.Mol at 0x1d6ab039000>,
#  'Het022': <rdkit.Chem.rdchem.Mol at 0x1d6ab0382e0>,
#  'Het023': <rdkit.Chem.rdchem.Mol at 0x1d6ab038cf0>,
#  'Het024': <rdkit.Chem.rdchem.Mol at 0x1d6ab038c10>,
#  'Het025': <rdkit.Chem.rdchem.Mol at 0x1d6ab038ba0>,
#  'Het026': <rdkit.Chem.rdchem.Mol at 0x1d6ab038a50>,
#  'Het027': <rdkit.Chem.rdchem.Mol at 0x1d6ab038890>,
#  'Het028': <rdkit.Chem.rdchem.Mol at 0x1d6ab0387b0>,
#  'Het029': <rdkit.Chem.rdchem.Mol at 0x1d6ab0385f0>,
#  'Het030': <rdkit.Chem.rdchem.Mol at 0x1d6ab038f90>,
#  'Het031': <rdkit.Chem.rdchem.Mol at 0x1d6ab038e40>,
#  'Het032': <rdkit.Chem.rdchem.Mol at 0x1d6ab0391c0>,
#  'Het033': <rdkit.Chem.rdchem.Mol at 0x1d6ab039230>,
#  'Het034': <rdkit.Chem.rdchem.Mol at 0x1d6ab0392a0>,
#  'Het035': <rdkit.Chem.rdchem.Mol at 0x1d6ab039310>}

# %%
# display the molecules in a grid images group by the imverse_mapping key
for key, value in inverse_mapping.items():
    # get the molecules name
    print(f"Processing {key} with molecules {value}")
    mols_ = [mols[id] for id in value]
    legends_ = value
    
    # Generate a grid image with a fixed number of columns (4 columns)
    img = Chem.Draw.MolsToGridImage(
        mols_, molsPerRow=3, subImgSize=(150, 150), legends=legends_
    )
    # Display the grid of images
    display(img)
# Out:
# Processing pyrd with molecules ['Het001', 'Het002', 'Het003', 'Het007', 'Het008', 'Het009', 'Het010', 'Het011', 'Het012', 'Het016', 'Het017', 'Het018', 'Het019', 'Het020', 'Het021', 'Het028', 'Het029', 'Het030']
# Processing pyrmd with molecules ['Het004', 'Het005', 'Het013', 'Het014', 'Het022', 'Het023', 'Het024', 'Het031', 'Het032', 'Het033']
# Processing pyrz with molecules ['Het006', 'Het015', 'Het025', 'Het034']
# Processing pyrdz with molecules ['Het026', 'Het027', 'Het035']

# %%
# output this to json
import json

with open("name_mapping.json", "w") as f:
    json.dump(final_mapping, f, sort_keys=True, indent=4)
