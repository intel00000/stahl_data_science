# %% [markdown]
# ### <p style="font-family: Arial; color: gold; font-weight: bold;">this notebook convert the Gaussian com input file from open shell to anion
#
# ### <p style="font-family: Arial; color: red; font-weight: bold;">Requirement: put all the open shell com files into subfolder named **open_shell_tom**

# %% [markdown]
# ##### for each file, use regex to search for string "0 2" and replaced it to "-1 1" <br>the original .chk file is named like pyrd1_conf-1_openshell.chk, swap the suffix from openshell to anion

# %%
# define your input and output folders here
origin_folder = "open_shell_tom"
new_folder = "anion_tom"

# %%
# grep all com files in the current directory
import os, re

# list all files in the origin_tom subdirectory
files = [f for f in os.listdir(origin_folder) if os.path.isfile(os.path.join(origin_folder, f)) and f.endswith(".com")]
# sort the list by this regex int(re.search(r"^\D+(\d+)_{1}", x).group(1))
files.sort(key=lambda x: int(re.search(r"^\D+(\d+)_{1}", x).group(1)))
files
# Out:
# ['pyrd1_conf-1_openshell.com',
#  'pyrdz1_conf-1_openshell.com',
#  'pyrmd1_conf-1_openshell.com',
#  'pyrz1_conf-1_openshell.com',
#  'pyrd2_conf-1_openshell.com',
#  'pyrdz2_conf-1_openshell.com',
#  'pyrmd2_conf-1_openshell.com',
#  'pyrz2_conf-1_openshell.com',
#  'pyrz2_conf-2_openshell.com',
#  'pyrz2_conf-3_openshell.com',
#  'pyrd3_conf-1_openshell.com',
#  'pyrdz3_conf-1_openshell.com',
#  'pyrdz3_conf-2_openshell.com',
#  'pyrdz3_conf-3_openshell.com',
#  'pyrmd3_conf-1_openshell.com',
#  'pyrmd3_conf-2_openshell.com',
#  'pyrz3_conf-1_openshell.com',
#  'pyrd4_conf-1_openshell.com',
#  'pyrmd4_conf-1_openshell.com',
#  'pyrmd4_conf-2_openshell.com',
#  'pyrz4_conf-1_openshell.com',
#  'pyrz4_conf-2_openshell.com',
#  'pyrd5_conf-1_openshell.com',
#  'pyrmd5_conf-1_openshell.com',
#  'pyrd6_conf-1_openshell.com',
#  'pyrmd6_conf-1_openshell.com',
#  'pyrd7_conf-1_openshell.com',
#  'pyrd7_conf-2_openshell.com',
#  'pyrd7_conf-3_openshell.com',
#  'pyrmd7_conf-1_openshell.com',
#  'pyrd8_conf-1_openshell.com',
#  'pyrd8_conf-2_openshell.com',
#  'pyrmd8_conf-1_openshell.com',
#  'pyrmd8_conf-2_openshell.com',
#  'pyrd9_conf-1_openshell.com',
#  'pyrd9_conf-2_openshell.com',
#  'pyrmd9_conf-1_openshell.com',
#  'pyrmd9_conf-2_openshell.com',
#  'pyrd10_conf-1_openshell.com',
#  'pyrd10_conf-2_openshell.com',
#  'pyrmd10_conf-1_openshell.com',
#  'pyrmd10_conf-2_openshell.com',
#  'pyrd11_conf-1_openshell.com',
#  'pyrd12_conf-1_openshell.com',
#  'pyrd12_conf-2_openshell.com',
#  'pyrd13_conf-1_openshell.com',
#  'pyrd14_conf-1_openshell.com',
#  'pyrd15_conf-1_openshell.com',
#  'pyrd16_conf-1_openshell.com',
#  'pyrd16_conf-2_openshell.com',
#  'pyrd16_conf-3_openshell.com',
#  'pyrd17_conf-1_openshell.com',
#  'pyrd17_conf-2_openshell.com',
#  'pyrd17_conf-3_openshell.com',
#  'pyrd18_conf-1_openshell.com',
#  'pyrd18_conf-2_openshell.com']

# %%
# for each file, use regex to search for string "0 2" and replaced it to "-1 1"
# the original .chk file is named like pyrd1_conf-1_openshell.chk
# swap the suffix from openshell to anion
os.makedirs(new_folder, exist_ok=True)

for file in files:
    with open(os.path.join(origin_folder, file), "r") as f:
        lines = f.readlines()
        print(f"---------------------------------------------")
        print(f"reading file {file}")
        for index, line in enumerate(lines):
            keystring = "0 2"
            replacestring = "-1 1"
            
            if keystring in line:
                print(f"found {keystring} at index {index}, replacing with {replacestring}")
                # replace the string
                lines[index] = line.replace(keystring, replacestring)
                
            # use _([a-zA-Z]+)\.chk to match the chk file name
            # replace the chk file name with anion
            match = re.search(r"_([a-zA-Z]+)\.chk", line)
            if match:
                filename = re.search(r"=(\S+)$", line).group(1)
                print(f"found chk file name {filename} at index {index}", end=", ")
                lines[index] = line.replace(match.group(1), "anion")
                filename = re.search(r"=(\S+)$", lines[index]).group(1)
                print(f"replacing to {filename}")
                
    # save the new file into regular_preprocessed folder with the same name
    with open(os.path.join(new_folder, file), "w") as f:
        f.writelines(lines)
        print(f"writing new file {file} into regular_preprocessed folder")
# Out:
# ---------------------------------------------
# reading file pyrd1_conf-1_openshell.com
# found chk file name pyrd1_conf-1_openshell.chk at index 2, replacing to pyrd1_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd1_conf-1_openshell.chk at index 31, replacing to pyrd1_conf-1_anion.chk
# found 0 2 at index 36, replacing with -1 1
# writing new file pyrd1_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrdz1_conf-1_openshell.com
# found chk file name pyrdz1_conf-1_openshell.chk at index 2, replacing to pyrdz1_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrdz1_conf-1_openshell.chk at index 24, replacing to pyrdz1_conf-1_anion.chk
# found 0 2 at index 29, replacing with -1 1
# writing new file pyrdz1_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd1_conf-1_openshell.com
# found chk file name pyrmd1_conf-1_openshell.chk at index 2, replacing to pyrmd1_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd1_conf-1_openshell.chk at index 30, replacing to pyrmd1_conf-1_anion.chk
# found 0 2 at index 35, replacing with -1 1
# writing new file pyrmd1_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrz1_conf-1_openshell.com
# found chk file name pyrz1_conf-1_openshell.chk at index 2, replacing to pyrz1_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrz1_conf-1_openshell.chk at index 30, replacing to pyrz1_conf-1_anion.chk
# found 0 2 at index 35, replacing with -1 1
# writing new file pyrz1_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd2_conf-1_openshell.com
# found chk file name pyrd2_conf-1_openshell.chk at index 2, replacing to pyrd2_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd2_conf-1_openshell.chk at index 31, replacing to pyrd2_conf-1_anion.chk
# found 0 2 at index 36, replacing with -1 1
# writing new file pyrd2_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrdz2_conf-1_openshell.com
# found chk file name pyrdz2_conf-1_openshell.chk at index 2, replacing to pyrdz2_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrdz2_conf-1_openshell.chk at index 24, replacing to pyrdz2_conf-1_anion.chk
# found 0 2 at index 29, replacing with -1 1
# writing new file pyrdz2_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd2_conf-1_openshell.com
# found chk file name pyrmd2_conf-1_openshell.chk at index 2, replacing to pyrmd2_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd2_conf-1_openshell.chk at index 30, replacing to pyrmd2_conf-1_anion.chk
# found 0 2 at index 35, replacing with -1 1
# writing new file pyrmd2_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrz2_conf-1_openshell.com
# found chk file name pyrz2_conf-1_openshell.chk at index 2, replacing to pyrz2_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrz2_conf-1_openshell.chk at index 33, replacing to pyrz2_conf-1_anion.chk
# found 0 2 at index 38, replacing with -1 1
# writing new file pyrz2_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrz2_conf-2_openshell.com
# found chk file name pyrz2_conf-2_openshell.chk at index 2, replacing to pyrz2_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrz2_conf-2_openshell.chk at index 33, replacing to pyrz2_conf-2_anion.chk
# found 0 2 at index 38, replacing with -1 1
# writing new file pyrz2_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrz2_conf-3_openshell.com
# found chk file name pyrz2_conf-3_openshell.chk at index 2, replacing to pyrz2_conf-3_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrz2_conf-3_openshell.chk at index 33, replacing to pyrz2_conf-3_anion.chk
# found 0 2 at index 38, replacing with -1 1
# writing new file pyrz2_conf-3_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd3_conf-1_openshell.com
# found chk file name pyrd3_conf-1_openshell.chk at index 2, replacing to pyrd3_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd3_conf-1_openshell.chk at index 31, replacing to pyrd3_conf-1_anion.chk
# found 0 2 at index 36, replacing with -1 1
# writing new file pyrd3_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrdz3_conf-1_openshell.com
# found chk file name pyrdz3_conf-1_openshell.chk at index 2, replacing to pyrdz3_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrdz3_conf-1_openshell.chk at index 27, replacing to pyrdz3_conf-1_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrdz3_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrdz3_conf-2_openshell.com
# found chk file name pyrdz3_conf-2_openshell.chk at index 2, replacing to pyrdz3_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrdz3_conf-2_openshell.chk at index 27, replacing to pyrdz3_conf-2_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrdz3_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrdz3_conf-3_openshell.com
# found chk file name pyrdz3_conf-3_openshell.chk at index 2, replacing to pyrdz3_conf-3_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrdz3_conf-3_openshell.chk at index 27, replacing to pyrdz3_conf-3_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrdz3_conf-3_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd3_conf-1_openshell.com
# found chk file name pyrmd3_conf-1_openshell.chk at index 2, replacing to pyrmd3_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd3_conf-1_openshell.chk at index 33, replacing to pyrmd3_conf-1_anion.chk
# found 0 2 at index 38, replacing with -1 1
# writing new file pyrmd3_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd3_conf-2_openshell.com
# found chk file name pyrmd3_conf-2_openshell.chk at index 2, replacing to pyrmd3_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd3_conf-2_openshell.chk at index 33, replacing to pyrmd3_conf-2_anion.chk
# found 0 2 at index 38, replacing with -1 1
# writing new file pyrmd3_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrz3_conf-1_openshell.com
# found chk file name pyrz3_conf-1_openshell.chk at index 2, replacing to pyrz3_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrz3_conf-1_openshell.chk at index 24, replacing to pyrz3_conf-1_anion.chk
# found 0 2 at index 29, replacing with -1 1
# writing new file pyrz3_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd4_conf-1_openshell.com
# found chk file name pyrd4_conf-1_openshell.chk at index 2, replacing to pyrd4_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd4_conf-1_openshell.chk at index 31, replacing to pyrd4_conf-1_anion.chk
# found 0 2 at index 36, replacing with -1 1
# writing new file pyrd4_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd4_conf-1_openshell.com
# found chk file name pyrmd4_conf-1_openshell.chk at index 2, replacing to pyrmd4_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd4_conf-1_openshell.chk at index 33, replacing to pyrmd4_conf-1_anion.chk
# found 0 2 at index 38, replacing with -1 1
# writing new file pyrmd4_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd4_conf-2_openshell.com
# found chk file name pyrmd4_conf-2_openshell.chk at index 2, replacing to pyrmd4_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd4_conf-2_openshell.chk at index 33, replacing to pyrmd4_conf-2_anion.chk
# found 0 2 at index 38, replacing with -1 1
# writing new file pyrmd4_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrz4_conf-1_openshell.com
# found chk file name pyrz4_conf-1_openshell.chk at index 2, replacing to pyrz4_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrz4_conf-1_openshell.chk at index 27, replacing to pyrz4_conf-1_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrz4_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrz4_conf-2_openshell.com
# found chk file name pyrz4_conf-2_openshell.chk at index 2, replacing to pyrz4_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrz4_conf-2_openshell.chk at index 27, replacing to pyrz4_conf-2_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrz4_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd5_conf-1_openshell.com
# found chk file name pyrd5_conf-1_openshell.chk at index 2, replacing to pyrd5_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd5_conf-1_openshell.chk at index 31, replacing to pyrd5_conf-1_anion.chk
# found 0 2 at index 36, replacing with -1 1
# writing new file pyrd5_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd5_conf-1_openshell.com
# found chk file name pyrmd5_conf-1_openshell.chk at index 2, replacing to pyrmd5_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd5_conf-1_openshell.chk at index 24, replacing to pyrmd5_conf-1_anion.chk
# found 0 2 at index 29, replacing with -1 1
# writing new file pyrmd5_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd6_conf-1_openshell.com
# found chk file name pyrd6_conf-1_openshell.chk at index 2, replacing to pyrd6_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd6_conf-1_openshell.chk at index 31, replacing to pyrd6_conf-1_anion.chk
# found 0 2 at index 36, replacing with -1 1
# writing new file pyrd6_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd6_conf-1_openshell.com
# found chk file name pyrmd6_conf-1_openshell.chk at index 2, replacing to pyrmd6_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd6_conf-1_openshell.chk at index 24, replacing to pyrmd6_conf-1_anion.chk
# found 0 2 at index 29, replacing with -1 1
# writing new file pyrmd6_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd7_conf-1_openshell.com
# found chk file name pyrd7_conf-1_openshell.chk at index 2, replacing to pyrd7_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd7_conf-1_openshell.chk at index 34, replacing to pyrd7_conf-1_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd7_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd7_conf-2_openshell.com
# found chk file name pyrd7_conf-2_openshell.chk at index 2, replacing to pyrd7_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd7_conf-2_openshell.chk at index 34, replacing to pyrd7_conf-2_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd7_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd7_conf-3_openshell.com
# found chk file name pyrd7_conf-3_openshell.chk at index 2, replacing to pyrd7_conf-3_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd7_conf-3_openshell.chk at index 34, replacing to pyrd7_conf-3_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd7_conf-3_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd7_conf-1_openshell.com
# found chk file name pyrmd7_conf-1_openshell.chk at index 2, replacing to pyrmd7_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd7_conf-1_openshell.chk at index 24, replacing to pyrmd7_conf-1_anion.chk
# found 0 2 at index 29, replacing with -1 1
# writing new file pyrmd7_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd8_conf-1_openshell.com
# found chk file name pyrd8_conf-1_openshell.chk at index 2, replacing to pyrd8_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd8_conf-1_openshell.chk at index 34, replacing to pyrd8_conf-1_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd8_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd8_conf-2_openshell.com
# found chk file name pyrd8_conf-2_openshell.chk at index 2, replacing to pyrd8_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd8_conf-2_openshell.chk at index 34, replacing to pyrd8_conf-2_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd8_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd8_conf-1_openshell.com
# found chk file name pyrmd8_conf-1_openshell.chk at index 2, replacing to pyrmd8_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd8_conf-1_openshell.chk at index 27, replacing to pyrmd8_conf-1_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrmd8_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd8_conf-2_openshell.com
# found chk file name pyrmd8_conf-2_openshell.chk at index 2, replacing to pyrmd8_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd8_conf-2_openshell.chk at index 27, replacing to pyrmd8_conf-2_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrmd8_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd9_conf-1_openshell.com
# found chk file name pyrd9_conf-1_openshell.chk at index 2, replacing to pyrd9_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd9_conf-1_openshell.chk at index 34, replacing to pyrd9_conf-1_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd9_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd9_conf-2_openshell.com
# found chk file name pyrd9_conf-2_openshell.chk at index 2, replacing to pyrd9_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd9_conf-2_openshell.chk at index 34, replacing to pyrd9_conf-2_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd9_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd9_conf-1_openshell.com
# found chk file name pyrmd9_conf-1_openshell.chk at index 2, replacing to pyrmd9_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd9_conf-1_openshell.chk at index 27, replacing to pyrmd9_conf-1_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrmd9_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd9_conf-2_openshell.com
# found chk file name pyrmd9_conf-2_openshell.chk at index 2, replacing to pyrmd9_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd9_conf-2_openshell.chk at index 27, replacing to pyrmd9_conf-2_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrmd9_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd10_conf-1_openshell.com
# found chk file name pyrd10_conf-1_openshell.chk at index 2, replacing to pyrd10_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd10_conf-1_openshell.chk at index 34, replacing to pyrd10_conf-1_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd10_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd10_conf-2_openshell.com
# found chk file name pyrd10_conf-2_openshell.chk at index 2, replacing to pyrd10_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd10_conf-2_openshell.chk at index 34, replacing to pyrd10_conf-2_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd10_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd10_conf-1_openshell.com
# found chk file name pyrmd10_conf-1_openshell.chk at index 2, replacing to pyrmd10_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd10_conf-1_openshell.chk at index 27, replacing to pyrmd10_conf-1_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrmd10_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrmd10_conf-2_openshell.com
# found chk file name pyrmd10_conf-2_openshell.chk at index 2, replacing to pyrmd10_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrmd10_conf-2_openshell.chk at index 27, replacing to pyrmd10_conf-2_anion.chk
# found 0 2 at index 32, replacing with -1 1
# writing new file pyrmd10_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd11_conf-1_openshell.com
# found chk file name pyrd11_conf-1_openshell.chk at index 2, replacing to pyrd11_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd11_conf-1_openshell.chk at index 34, replacing to pyrd11_conf-1_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd11_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd12_conf-1_openshell.com
# found chk file name pyrd12_conf-1_openshell.chk at index 2, replacing to pyrd12_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd12_conf-1_openshell.chk at index 34, replacing to pyrd12_conf-1_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd12_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd12_conf-2_openshell.com
# found chk file name pyrd12_conf-2_openshell.chk at index 2, replacing to pyrd12_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd12_conf-2_openshell.chk at index 34, replacing to pyrd12_conf-2_anion.chk
# found 0 2 at index 39, replacing with -1 1
# writing new file pyrd12_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd13_conf-1_openshell.com
# found chk file name pyrd13_conf-1_openshell.chk at index 2, replacing to pyrd13_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd13_conf-1_openshell.chk at index 25, replacing to pyrd13_conf-1_anion.chk
# found 0 2 at index 30, replacing with -1 1
# writing new file pyrd13_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd14_conf-1_openshell.com
# found chk file name pyrd14_conf-1_openshell.chk at index 2, replacing to pyrd14_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd14_conf-1_openshell.chk at index 25, replacing to pyrd14_conf-1_anion.chk
# found 0 2 at index 30, replacing with -1 1
# writing new file pyrd14_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd15_conf-1_openshell.com
# found chk file name pyrd15_conf-1_openshell.chk at index 2, replacing to pyrd15_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd15_conf-1_openshell.chk at index 25, replacing to pyrd15_conf-1_anion.chk
# found 0 2 at index 30, replacing with -1 1
# writing new file pyrd15_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd16_conf-1_openshell.com
# found chk file name pyrd16_conf-1_openshell.chk at index 2, replacing to pyrd16_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd16_conf-1_openshell.chk at index 28, replacing to pyrd16_conf-1_anion.chk
# found 0 2 at index 33, replacing with -1 1
# writing new file pyrd16_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd16_conf-2_openshell.com
# found chk file name pyrd16_conf-2_openshell.chk at index 2, replacing to pyrd16_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd16_conf-2_openshell.chk at index 28, replacing to pyrd16_conf-2_anion.chk
# found 0 2 at index 33, replacing with -1 1
# writing new file pyrd16_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd16_conf-3_openshell.com
# found chk file name pyrd16_conf-3_openshell.chk at index 2, replacing to pyrd16_conf-3_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd16_conf-3_openshell.chk at index 28, replacing to pyrd16_conf-3_anion.chk
# found 0 2 at index 33, replacing with -1 1
# writing new file pyrd16_conf-3_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd17_conf-1_openshell.com
# found chk file name pyrd17_conf-1_openshell.chk at index 2, replacing to pyrd17_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd17_conf-1_openshell.chk at index 28, replacing to pyrd17_conf-1_anion.chk
# found 0 2 at index 33, replacing with -1 1
# writing new file pyrd17_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd17_conf-2_openshell.com
# found chk file name pyrd17_conf-2_openshell.chk at index 2, replacing to pyrd17_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd17_conf-2_openshell.chk at index 28, replacing to pyrd17_conf-2_anion.chk
# found 0 2 at index 33, replacing with -1 1
# writing new file pyrd17_conf-2_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd17_conf-3_openshell.com
# found chk file name pyrd17_conf-3_openshell.chk at index 2, replacing to pyrd17_conf-3_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd17_conf-3_openshell.chk at index 28, replacing to pyrd17_conf-3_anion.chk
# found 0 2 at index 33, replacing with -1 1
# writing new file pyrd17_conf-3_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd18_conf-1_openshell.com
# found chk file name pyrd18_conf-1_openshell.chk at index 2, replacing to pyrd18_conf-1_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd18_conf-1_openshell.chk at index 28, replacing to pyrd18_conf-1_anion.chk
# found 0 2 at index 33, replacing with -1 1
# writing new file pyrd18_conf-1_openshell.com into regular_preprocessed folder
# ---------------------------------------------
# reading file pyrd18_conf-2_openshell.com
# found chk file name pyrd18_conf-2_openshell.chk at index 2, replacing to pyrd18_conf-2_anion.chk
# found 0 2 at index 7, replacing with -1 1
# found chk file name pyrd18_conf-2_openshell.chk at index 28, replacing to pyrd18_conf-2_anion.chk
# found 0 2 at index 33, replacing with -1 1
# writing new file pyrd18_conf-2_openshell.com into regular_preprocessed folder
