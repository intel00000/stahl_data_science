# %%
import os
import pandas as pd
import numpy as np
import plotly.express as px

# Display the updated DataFrame in the notebook
from IPython.display import display

random_seed = 42
data_folder = "data"

# %% [markdown]
# ### Load the data

# %%
file_path = os.path.join(
    data_folder, "Summary_Properties_all_species_published_252mols.xlsx"
)

# Load sheets "Select_Properties" and "Yields"
select_properties_df = pd.read_excel(file_path, sheet_name="Properties")
select_properties_df = select_properties_df.fillna(0)
assert not select_properties_df.isnull().values.any()
select_properties_df.to_pickle(os.path.join(data_folder, "Select_properties.pkl"))
yields_df = df = pd.read_excel(file_path, sheet_name="Yields")
yields_df = yields_df.fillna(0)
assert not yields_df.isnull().values.any()
yields_df.to_pickle(os.path.join(data_folder, "yields.pkl"))
robussness_df = pd.read_excel(file_path, sheet_name="Robustness_screen")
robussness_df = robussness_df.fillna(0)
assert not robussness_df.isnull().values.any()
robussness_df.to_pickle(os.path.join(data_folder, "robustness_screen.pkl"))

# Display a preview of both DataFrames
display(select_properties_df.head(3))
display(yields_df.head(3))
display(robussness_df.head(3))
# Out:
#   Compound_Name  BDE (kcal/mol)  BDFE (kcal/mol)  E_spc (Hartree)  \
# 0        Het036       90.912876        83.109802     -3014.810670
# 1        Het037       91.034613        83.325038      -716.522879
# 2        Het038       91.467594        83.692758     -1197.852061
#
#    E_spc (Hartree)_anion  E_spc (Hartree)_openshell  H_spc(Hartree)  \
# 0           -3014.225740               -3014.156362    -3014.646485
# 1            -715.951137                -715.868367     -716.328927
# 2           -1197.276752               -1197.197092    -1197.699107
#
#    H_spc(Hartree)_anion  H_spc(Hartree)_openshell  qh_G(T)_spc(Hartree)  ...  \
# 0          -3014.076477              -3014.005828          -3014.693505  ...
# 1           -715.772602               -715.688076           -716.380591  ...
# 2          -1197.138324              -1197.057566          -1197.750542  ...
#
#    Sterimol_L_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# 0                                        8.900579
# 1                                        8.871687
# 2                                        8.947646
#
#    Sterimol_L_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# 0                                           8.783913
# 1                                           8.774516
# 2                                           8.762297
#
#    Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz  \
# 0                                   1.966938
# 1                                   1.974611
# 2                                   1.979748
#
#    Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# 0                                         1.736366
# 1                                         1.755033
# 2                                         1.845110
#
#    Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# 0                                           1.735037
# 1                                           1.752779
# 2                                           1.838265
#
#    Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz  \
# 0                                   5.920017
# 1                                   6.797259
# 2                                   6.361003
#
#    Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# 0                                         5.885243
# 1                                         6.771417
# 2                                         6.182154
#
#    Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# 0                                           5.946735
# 1                                           6.903904
# 2                                           6.404913
#
#    pyramidalization_Gavrish_C1(deg)_Boltz  \
# 0                                5.895945
# 1                                5.935005
# 2                                5.882007
#
#    pyramidalization_Agranat-Radhakrishnan_C1_Boltz
# 0                                         0.798319
# 1                                         0.802330
# 2                                         0.796915
#
# [3 rows x 76 columns]
#                       SMILES                                        Name  \
# 0        Cc1ccc2cccc(Br)c2n1                  8-bromo-2-methyl-quinoline
# 1  Cc1ccc2ccc(F)c(B(O)O)c2n1  (7-fluoro-2-methyl-8-quinolyl)boronic acid
# 2     Cc1cc(Cl)c2ccc(I)cc2n1          4-chloro-7-iodo-2-methyl-quinoline
#
#   screening_id      id       HTE Heteroaromatic_scaffold Informer_Library  \
# 0        INF36  Het036  Selected               Quinoline            Fused
# 1        INF37  Het037  Selected               Quinoline            Fused
# 2        INF38  Het038  Selected               Quinoline            Fused
#
#      Britton  Maity Stahl 2AP  Maity Stahl 4AP     DeLuca  Golden Stahl  \
# 0  11.064759        16.616248        18.157002  20.925286     27.389265
# 1  20.914884         6.897721        31.601265  70.746624     29.475752
# 2  39.067826        78.611392        28.557671  32.555724     31.541641
#
#      Newkome  Li Xu  Schreiner
# 0   9.284346  12.02  23.471340
# 1   0.697700  13.34  24.785947
# 2  21.070600  47.37  56.752826
#   Additive_smiles Additive_name   Britton   Maity Stahl (2AP)  \
# 0    FC1=CC=CC=C1          ADT1  20.615155           1.800241
# 1   ClC1=CC=CC=C1          ADT2  23.015253           1.422139
# 2   BrC1=CC=CC=C1          ADT3  24.801006           4.924011
#
#    Maity Stahl (4AP)  Golden Stahl     DeLuca   Newkome     Li Xu  Schreiner  \
# 0          26.916542      9.264748   0.977556  0.939578  2.711945   0.571018
# 1          31.109814      5.548014   8.991435  1.553725  2.403315   2.308031
# 2          30.250697      6.665015  14.006317  4.089579  2.409219   1.981927
#
#    % Change LCAP in Chlorination Method
# 0                                   0.0
# 1                                   0.0
# 2                                   0.0

# %%
# Prepare data for the grid plot
# Extract yield columns (ignoring the first few metadata columns like id, SMILES, and captions)
yield_columns = yields_df.select_dtypes(include=[np.number]).columns
yield_data_df = yields_df[yield_columns]
display(yield_data_df.head(3))
# dump the yield dataframes to pickle files
yield_data_df.to_pickle(os.path.join(data_folder, "yield_data_df.pkl"))

# Same for the select properties
select_properties_data_columns = select_properties_df.select_dtypes(include=[np.number]).columns
select_properties_data_df = select_properties_df[select_properties_data_columns]
display(select_properties_data_df.head(3))
select_properties_data_df.to_pickle(os.path.join(data_folder, "select_properties_data_df.pkl"))
# Out:
#      Britton  Maity Stahl 2AP  Maity Stahl 4AP     DeLuca  Golden Stahl  \
# 0  11.064759        16.616248        18.157002  20.925286     27.389265
# 1  20.914884         6.897721        31.601265  70.746624     29.475752
# 2  39.067826        78.611392        28.557671  32.555724     31.541641
#
#      Newkome  Li Xu  Schreiner
# 0   9.284346  12.02  23.471340
# 1   0.697700  13.34  24.785947
# 2  21.070600  47.37  56.752826
#    BDE (kcal/mol)  BDFE (kcal/mol)  E_spc (Hartree)  E_spc (Hartree)_anion  \
# 0       90.912876        83.109802     -3014.810670           -3014.225740
# 1       91.034613        83.325038      -716.522879            -715.951137
# 2       91.467594        83.692758     -1197.852061           -1197.276752
#
#    E_spc (Hartree)_openshell  H_spc(Hartree)  H_spc(Hartree)_anion  \
# 0               -3014.156362    -3014.646485          -3014.076477
# 1                -715.868367     -716.328927           -715.772602
# 2               -1197.197092    -1197.699107          -1197.138324
#
#    H_spc(Hartree)_openshell  qh_G(T)_spc(Hartree)  qh_G(T)_spc(Hartree)_anion  \
# 0              -3014.005828          -3014.693505                -3014.122552
# 1               -715.688076           -716.380591                 -715.822869
# 2              -1197.057566          -1197.750542                -1197.188905
#
#    ...  Sterimol_L_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# 0  ...                                        8.900579
# 1  ...                                        8.871687
# 2  ...                                        8.947646
#
#    Sterimol_L_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# 0                                           8.783913
# 1                                           8.774516
# 2                                           8.762297
#
#    Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz  \
# 0                                   1.966938
# 1                                   1.974611
# 2                                   1.979748
#
#    Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# 0                                         1.736366
# 1                                         1.755033
# 2                                         1.845110
#
#    Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# 0                                           1.735037
# 1                                           1.752779
# 2                                           1.838265
#
#    Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz  \
# 0                                   5.920017
# 1                                   6.797259
# 2                                   6.361003
#
#    Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# 0                                         5.885243
# 1                                         6.771417
# 2                                         6.182154
#
#    Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# 0                                           5.946735
# 1                                           6.903904
# 2                                           6.404913
#
#    pyramidalization_Gavrish_C1(deg)_Boltz  \
# 0                                5.895945
# 1                                5.935005
# 2                                5.882007
#
#    pyramidalization_Agranat-Radhakrishnan_C1_Boltz
# 0                                         0.798319
# 1                                         0.802330
# 2                                         0.796915
#
# [3 rows x 75 columns]

# %% [markdown]
# ### Remove highly correlated features

# %%
# remove highly correlated columns from the properties dataframe
corr_matrix = select_properties_data_df.corr().abs()

# %%
# plot the correlation matrix
fig = px.imshow(
    corr_matrix.abs().values,
    labels=dict(x="Property", y="Property", color="Correlation"),
    x=corr_matrix.columns,
    y=corr_matrix.columns,
    color_continuous_scale="Viridis",
    title="Correlation Matrix of Select Properties",
)

fig.update_layout(
    height=len(select_properties_data_columns) * 30,
    width=len(select_properties_data_columns) * 30,
    xaxis=dict(tickangle=30),
    template="plotly",
    font=dict(size=12, family="Arial", color="black", weight="bold"),
)

fig.update_coloraxes(
    colorbar_len=0.8,
    colorbar_title="Correlation",
)

fig.show()
# save to html and open in browser
fig.write_html("temp.html", auto_open=False)

# %%
# plot the correlation matrix, only plot from the first column to "SASA_surface_area(amstrong^2)_Boltz"
# get the index of the column "SASA_surface_area(amstrong^2)_Boltz"
column_cutoff_index = select_properties_data_df.columns.get_loc(
    "SASA_sphericity_Boltz_openshell"
)
fig = px.imshow(
    corr_matrix.iloc[:column_cutoff_index, :column_cutoff_index].abs().values,
    labels=dict(x="Property", y="Property", color="Correlation"),
    x=corr_matrix.columns[:column_cutoff_index],
    y=corr_matrix.columns[:column_cutoff_index],
    color_continuous_scale="Viridis",
    title="Correlation Matrix of Select Properties",
)

fig.update_layout(
    height=column_cutoff_index * 25,
    width=column_cutoff_index * 25,
    xaxis=dict(tickangle=30),
    # increase font size
    font=dict(size=11, family="Arial", color="black", weight="bold"),
)

fig.update_coloraxes(
    colorbar_len=0.7,
    colorbar_title="Correlation",
    colorbar_title_font_size=9,
    colorbar_tickfont_size=9,
)

fig.show()
# save to html and open in browser
fig.write_html("temp.html", auto_open=False)

# %%
# plot the correlation matrix, only starting from the "SASA_surface_area(amstrong^2)_Boltz" column
# get the index of the column "SASA_surface_area(amstrong^2)_Boltz"
column_cutoff_index = select_properties_data_df.columns.get_loc(
    "SASA_sphericity_Boltz_openshell"
)
fig = px.imshow(
    corr_matrix.iloc[column_cutoff_index:, column_cutoff_index:].abs().values,
    labels=dict(x="Property", y="Property", color="Correlation"),
    x=corr_matrix.columns[column_cutoff_index:],
    y=corr_matrix.columns[column_cutoff_index:],
    color_continuous_scale="Viridis",
    title="Correlation Matrix of Select Properties",
)

fig.update_layout(
    height=column_cutoff_index * 25,
    width=column_cutoff_index * 25,
    xaxis=dict(tickangle=30),
    # increase font size
    font=dict(size=11, family="Arial", color="black", weight="bold"),
)

fig.update_coloraxes(
    colorbar_len=0.6,
    colorbar_title="Correlation",
    colorbar_title_font_size=10,
    colorbar_tickfont_size=10,
)

fig.show()
# save to html and open in browser
fig.write_html("temp.html", auto_open=False)

# %%
# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper
# Out:
#                                                     BDE (kcal/mol)  \
# BDE (kcal/mol)                                                 NaN
# BDFE (kcal/mol)                                                NaN
# E_spc (Hartree)                                                NaN
# E_spc (Hartree)_anion                                          NaN
# E_spc (Hartree)_openshell                                      NaN
# ...                                                            ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                      NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...             NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                         NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                NaN
#
#                                                     BDFE (kcal/mol)  \
# BDE (kcal/mol)                                             0.989422
# BDFE (kcal/mol)                                                 NaN
# E_spc (Hartree)                                                 NaN
# E_spc (Hartree)_anion                                           NaN
# E_spc (Hartree)_openshell                                       NaN
# ...                                                             ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                       NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                 NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...              NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                          NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                 NaN
#
#                                                     E_spc (Hartree)  \
# BDE (kcal/mol)                                             0.022494
# BDFE (kcal/mol)                                            0.021528
# E_spc (Hartree)                                                 NaN
# E_spc (Hartree)_anion                                           NaN
# E_spc (Hartree)_openshell                                       NaN
# ...                                                             ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                       NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                 NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...              NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                          NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                 NaN
#
#                                                     E_spc (Hartree)_anion  \
# BDE (kcal/mol)                                                   0.022495
# BDFE (kcal/mol)                                                  0.021528
# E_spc (Hartree)                                                  1.000000
# E_spc (Hartree)_anion                                                 NaN
# E_spc (Hartree)_openshell                                             NaN
# ...                                                                   ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                             NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                       NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                    NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                       NaN
#
#                                                     E_spc (Hartree)_openshell  \
# BDE (kcal/mol)                                                       0.022499
# BDFE (kcal/mol)                                                      0.021532
# E_spc (Hartree)                                                      1.000000
# E_spc (Hartree)_anion                                                1.000000
# E_spc (Hartree)_openshell                                                 NaN
# ...                                                                       ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                 NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                           NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                        NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                    NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                           NaN
#
#                                                     H_spc(Hartree)  \
# BDE (kcal/mol)                                            0.022484
# BDFE (kcal/mol)                                           0.021515
# E_spc (Hartree)                                           1.000000
# E_spc (Hartree)_anion                                     1.000000
# E_spc (Hartree)_openshell                                 1.000000
# ...                                                            ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                      NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...             NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                         NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                NaN
#
#                                                     H_spc(Hartree)_anion  \
# BDE (kcal/mol)                                                  0.022484
# BDFE (kcal/mol)                                                 0.021515
# E_spc (Hartree)                                                 1.000000
# E_spc (Hartree)_anion                                           1.000000
# E_spc (Hartree)_openshell                                       1.000000
# ...                                                                  ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                            NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                      NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                   NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                               NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                      NaN
#
#                                                     H_spc(Hartree)_openshell  \
# BDE (kcal/mol)                                                      0.022488
# BDFE (kcal/mol)                                                     0.021519
# E_spc (Hartree)                                                     1.000000
# E_spc (Hartree)_anion                                               1.000000
# E_spc (Hartree)_openshell                                           1.000000
# ...                                                                      ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                          NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                       NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                   NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                          NaN
#
#                                                     qh_G(T)_spc(Hartree)  \
# BDE (kcal/mol)                                                  0.022484
# BDFE (kcal/mol)                                                 0.021515
# E_spc (Hartree)                                                 1.000000
# E_spc (Hartree)_anion                                           1.000000
# E_spc (Hartree)_openshell                                       1.000000
# ...                                                                  ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                            NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                      NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                   NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                               NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                      NaN
#
#                                                     qh_G(T)_spc(Hartree)_anion  \
# BDE (kcal/mol)                                                        0.022485
# BDFE (kcal/mol)                                                       0.021516
# E_spc (Hartree)                                                       1.000000
# E_spc (Hartree)_anion                                                 1.000000
# E_spc (Hartree)_openshell                                             1.000000
# ...                                                                        ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                  NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                            NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                         NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                     NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                            NaN
#
#                                                     ...  \
# BDE (kcal/mol)                                      ...
# BDFE (kcal/mol)                                     ...
# E_spc (Hartree)                                     ...
# E_spc (Hartree)_anion                               ...
# E_spc (Hartree)_openshell                           ...
# ...                                                 ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz           ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion     ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...  ...
# pyramidalization_Gavrish_C1(deg)_Boltz              ...
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz     ...
#
#                                                     Sterimol_L_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# BDE (kcal/mol)                                                                            0.117698
# BDFE (kcal/mol)                                                                           0.136076
# E_spc (Hartree)                                                                           0.050612
# E_spc (Hartree)_anion                                                                     0.050614
# E_spc (Hartree)_openshell                                                                 0.050611
# ...                                                                                            ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                      NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                                NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                             NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                                         NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                                NaN
#
#                                                     Sterimol_L_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# BDE (kcal/mol)                                                                               0.110716
# BDFE (kcal/mol)                                                                              0.128492
# E_spc (Hartree)                                                                              0.048870
# E_spc (Hartree)_anion                                                                        0.048873
# E_spc (Hartree)_openshell                                                                    0.048869
# ...                                                                                               ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                         NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                                   NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                                NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                                            NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                                   NaN
#
#                                                     Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz  \
# BDE (kcal/mol)                                                                       0.211905
# BDFE (kcal/mol)                                                                      0.240856
# E_spc (Hartree)                                                                      0.041753
# E_spc (Hartree)_anion                                                                0.041753
# E_spc (Hartree)_openshell                                                            0.041754
# ...                                                                                       ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                 NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                           NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                        NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                                    NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                           NaN
#
#                                                     Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# BDE (kcal/mol)                                                                             0.097188
# BDFE (kcal/mol)                                                                            0.119547
# E_spc (Hartree)                                                                            0.079013
# E_spc (Hartree)_anion                                                                      0.079013
# E_spc (Hartree)_openshell                                                                  0.079013
# ...                                                                                             ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                       NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                                 NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                              NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                                          NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                                 NaN
#
#                                                     Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# BDE (kcal/mol)                                                                               0.126565
# BDFE (kcal/mol)                                                                              0.145535
# E_spc (Hartree)                                                                              0.070255
# E_spc (Hartree)_anion                                                                        0.070256
# E_spc (Hartree)_openshell                                                                    0.070255
# ...                                                                                               ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                         NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                                   NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                                NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                                            NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                                   NaN
#
#                                                     Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz  \
# BDE (kcal/mol)                                                                       0.008586
# BDFE (kcal/mol)                                                                      0.011969
# E_spc (Hartree)                                                                      0.096561
# E_spc (Hartree)_anion                                                                0.096563
# E_spc (Hartree)_openshell                                                            0.096561
# ...                                                                                       ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                 NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                           NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                        NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                                    NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                           NaN
#
#                                                     Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion  \
# BDE (kcal/mol)                                                                             0.053980
# BDFE (kcal/mol)                                                                            0.046833
# E_spc (Hartree)                                                                            0.096137
# E_spc (Hartree)_anion                                                                      0.096138
# E_spc (Hartree)_openshell                                                                  0.096136
# ...                                                                                             ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                  0.952445
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                                 NaN
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                              NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                                          NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                                 NaN
#
#                                                     Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_openshell  \
# BDE (kcal/mol)                                                                               0.079321
# BDFE (kcal/mol)                                                                              0.075162
# E_spc (Hartree)                                                                              0.091882
# E_spc (Hartree)_anion                                                                        0.091883
# E_spc (Hartree)_openshell                                                                    0.091882
# ...                                                                                               ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                    0.952478
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                              0.985590
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                                NaN
# pyramidalization_Gavrish_C1(deg)_Boltz                                                            NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                                   NaN
#
#                                                     pyramidalization_Gavrish_C1(deg)_Boltz  \
# BDE (kcal/mol)                                                                    0.462053
# BDFE (kcal/mol)                                                                   0.378906
# E_spc (Hartree)                                                                   0.077245
# E_spc (Hartree)_anion                                                             0.077246
# E_spc (Hartree)_openshell                                                         0.077247
# ...                                                                                    ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                         0.054935
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                   0.055207
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                0.073628
# pyramidalization_Gavrish_C1(deg)_Boltz                                                 NaN
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                        NaN
#
#                                                     pyramidalization_Agranat-Radhakrishnan_C1_Boltz
# BDE (kcal/mol)                                                                             0.472088
# BDFE (kcal/mol)                                                                            0.389287
# E_spc (Hartree)                                                                            0.075914
# E_spc (Hartree)_anion                                                                      0.075916
# E_spc (Hartree)_openshell                                                                  0.075917
# ...                                                                                             ...
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz                                                  0.050398
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion                                            0.050915
# Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_opens...                                         0.070451
# pyramidalization_Gavrish_C1(deg)_Boltz                                                     0.999201
# pyramidalization_Agranat-Radhakrishnan_C1_Boltz                                                 NaN
#
# [75 rows x 75 columns]

# %%
# Find index of feature columns with correlation greater than the cutoff
corr_cutoff = 0.8
to_drop = [column for column in upper.columns if any(upper[column].abs() > corr_cutoff)]
# display the columns to drop
print(f"Columns to drop: {to_drop}")
# Drop the highly correlated features
select_properties_data_removed_highlycorr_df = select_properties_data_df.drop(columns=to_drop)
print(f"Number of columns to drop: {len(to_drop)}, remaining columns: {len(select_properties_data_removed_highlycorr_df.columns)}")
# dump the yield dataframes to pickle files
select_properties_data_removed_highlycorr_df.to_pickle(os.path.join(data_folder, "select_properties_data_removed_highlycorr_df.pkl"))
# Out:
# Columns to drop: ['BDFE (kcal/mol)', 'E_spc (Hartree)_anion', 'E_spc (Hartree)_openshell', 'H_spc(Hartree)', 'H_spc(Hartree)_anion', 'H_spc(Hartree)_openshell', 'qh_G(T)_spc(Hartree)', 'qh_G(T)_spc(Hartree)_anion', 'qh_G(T)_spc(Hartree)_openshell', 'LUMO_Boltz_openshell', 'mu_Boltz', 'mu_Boltz_anion', 'mu_Boltz_openshell', 'omega_Boltz', 'omega_Boltz_anion', 'omega_Boltz_openshell', 'polar_iso(Debye)_Boltz_anion', 'polar_iso(Debye)_Boltz_openshell', 'polar_aniso(Debye)_Boltz_openshell', 'dipole(Debye)_Boltz_openshell', 'volume(Bohr_radius^3/mol)_Boltz', 'volume(Bohr_radius^3/mol)_Boltz_anion', 'volume(Bohr_radius^3/mol)_Boltz_openshell', 'SASA_surface_area(Amgstrom^3)_Boltz', 'SASA_surface_area(Amgstrom^3)_Boltz_anion', 'SASA_surface_area(Amgstrom^3)_Boltz_openshell', 'SASA_volume(Amgstrom^3)_Boltz', 'SASA_volume(Amgstrom^3)_Boltz_anion', 'SASA_volume(Amgstrom^3)_Boltz_openshell', 'SASA_sphericity_Boltz', 'SASA_sphericity_Boltz_anion', 'SASA_sphericity_Boltz_openshell', 'NBO_charge_C1_Boltz_anion', 'NBO_charge_C2_Boltz_anion', 'NBO_charge_C2_Boltz_openshell', 'NMR_shift_C2_Boltz', '%Vbur_C1_2.0Amgstrom_Boltz', '%Vbur_C1_2.0Amgstrom_Boltz_anion', '%Vbur_C1_2.0Amgstrom_Boltz_openshell', '%Vbur_C2_2.0Amgstrom_Boltz_anion', '%Vbur_C2_2.0Amgstrom_Boltz_openshell', 'Sterimol_L_C1_C2(Amgstrom)_morfeus_Boltz_anion', 'Sterimol_L_C1_C2(Amgstrom)_morfeus_Boltz_openshell', 'Sterimol_B1_C1_C2(Amgstrom)_morfeus_Boltz_openshell', 'Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_anion', 'Sterimol_B5_C1_C2(Amgstrom)_morfeus_Boltz_openshell', 'pyramidalization_Agranat-Radhakrishnan_C1_Boltz']
# Number of columns to drop: 47, remaining columns: 28
