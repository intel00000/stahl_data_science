# %%
import os
import pandas as pd
import numpy as np
from tabulate import tabulate

# %%
# load all xls files in this directory, read the Summary_Properties sheet, and concatenate them into a single dataframe, skip those that don't have the sheet
# list all files in the current directory
files = [f for f in os.listdir() if f.endswith('.xls') or f.endswith('.xlsx')]
files.remove('smiles.xlsx')

print(f"Found {len(files)} files")
files
# Out:
# Found 4 files
# ['pyrdz_properties_postprocessed_for_pyrdz1_to_pyrdz1.xlsx',
#  'pyrd_properties_postprocessed_for_pyrd1_to_pyrd13.xlsx',
#  'pyrmd_properties_postprocessed_for_pyrmd1_to_pyrmd7.xlsx',
#  'pyrz_properties_postprocessed_for_pyrz1_to_pyrz3.xlsx']

# %%
files = ['pyrd_properties_postprocessed_for_pyrd1_to_pyrd13.xlsx']

# %%
# read the smiles.xlsx file, keep the first two columns
smiles = pd.read_excel('smiles.xlsx')
smiles.rename(columns={'SMILES': 'smiles'}, inplace=True)
smiles = smiles.iloc[:, :2]
smiles
# Out:
#                                                smiles      id
# 0                               BrC1=C2C(OCCC2)=CN=C1   pyrd1
# 1                                      ClC1=NC=CC=C1C   pyrd2
# 2                                    BrC1=CC(C)=NC=C1   pyrd3
# 3   O=C(NC1=NC=CC(C2CC2)=C1)C3=CC=C(B4OC(C)(C)C(C)...   pyrd4
# 4                          ClC1=NC(C(F)(F)F)=CC(C)=C1   pyrd5
# 5                   BrC1=CC(C)=CC(NC(OC(C)(C)C)=O)=N1   pyrd6
# 6       FC(F)(C1=CC(C(F)(F)F)=CC(C2=CN=CC(C)=C2)=C1)F   pyrd7
# 7                         BrC1=NC(C2=CN=CS2)=CC(C)=C1   pyrd8
# 8                              CC1=NC(Cl)=CC2=C1C=NN2   pyrd9
# 9                                    BrCCCC1=CN=CC=C1  pyrd10
# 10                          ClC1=C(C)C(C(OC)=O)=NC=C1  pyrd11
# 11                          COC1=C(CCC(N2)=O)C2=NC=C1  pyrd12
# 12                             O=CC1=CC=C(CCCN2)C2=N1  pyrd13
# 13                          ClC1=C(C)N=C(C(OC)=O)C=N1   pyrz1
# 14                       ClC1=C(C)N=C(C(OC)=O)C(N)=N1   pyrz2
# 15                              CC1=NC=C(C(OC)=O)N=C1   pyrz3
# 16                          NC1=NC(C)=C(C(OCC)=O)C=N1  pyrmd1
# 17                    ClC1=CC(Cl)=NC(CC2=CC=CC=C2)=N1  pyrmd2
# 18                                  ClC1=NC=C(CC)C=N1  pyrmd3
# 19                              ClC1=NC(C#N)=NC(C)=C1  pyrmd4
# 20                     O=CC(C=N1)=C(C)N=C1C2=CC=CC=C2  pyrmd5
# 21                                   CC1=CN=C(Cl)N=C1  pyrmd6
# 22                               ClC1=NC=C(C)C(OC)=N1  pyrmd7
# 23                  CC(C)C1=NN=C(C2=CC=C(I)C=C2F)C=C1  pyrdz1

# %%
dict = {}

# combine columns that have the same name
for file in files:
    temp = pd.read_excel(file, sheet_name="Summary_Properties", header=0)
    temp.rename(columns={'Compound_Name': 'id'}, inplace=True)
    # based on the Compound_Name, append a new column with the respective smiles
    temp = temp.merge(smiles, on='id', how='left')
    display(temp)
    # add it to the dictionary
    dict[file] = temp
# Out:
#         id  HOMO_Boltz  HOMO_Boltz_stdev  HOMO_min  HOMO_max  HOMO_range  \
# 0    pyrd1   -0.290880          0.000000  -0.29088  -0.29088     0.00000
# 1    pyrd2   -0.310000          0.000000  -0.31000  -0.31000     0.00000
# 2    pyrd3   -0.321620          0.000000  -0.32162  -0.32162     0.00000
# 3    pyrd4   -0.283680          0.000052  -0.28569  -0.28364     0.00205
# 4    pyrd5   -0.334030          0.000000  -0.33403  -0.33403     0.00000
# 5    pyrd6   -0.288716          0.000161  -0.29521  -0.28870     0.00651
# 6    pyrd7   -0.310806          0.000170  -0.31093  -0.31069     0.00024
# 7    pyrd8   -0.288150          0.000481  -0.28849  -0.28781     0.00068
# 8    pyrd9   -0.292800          0.000000  -0.29280  -0.29280     0.00000
# 9   pyrd10   -0.312966          0.001518  -0.31572  -0.30007     0.01565
# 10  pyrd11   -0.326991          0.000374  -0.32814  -0.32693     0.00121
# 11  pyrd12   -0.286530          0.000000  -0.28653  -0.28653     0.00000
# 12  pyrd13   -0.265820          0.000000  -0.26582  -0.26582     0.00000
#
#     HOMO_low_E  HOMO_Vbur_min  LUMO_Boltz  LUMO_Boltz_stdev  ...  \
# 0     -0.29088       -0.29088   -0.005530          0.000000  ...
# 1     -0.31000       -0.31000   -0.007480          0.000000  ...
# 2     -0.32162       -0.32162   -0.011380          0.000000  ...
# 3     -0.28364       -0.28364   -0.032606          0.000022  ...
# 4     -0.33403       -0.33403   -0.030230          0.000000  ...
# 5     -0.28870       -0.29521   -0.004725          0.000447  ...
# 6     -0.31069       -0.31069   -0.043408          0.000085  ...
# 7     -0.28849       -0.28849   -0.043430          0.000240  ...
# 8     -0.29280       -0.29280   -0.025450          0.000000  ...
# 9     -0.31210       -0.31568   -0.003239          0.002187  ...
# 10    -0.32693       -0.32693   -0.033003          0.002498  ...
# 11    -0.28653       -0.28653    0.003120          0.000000  ...
# 12    -0.26582       -0.26582   -0.034060          0.000000  ...
#
#     NBO_LP_occupancy_N1_low_E  NBO_LP_occupancy_N1_Vbur_min  \
# 0                     1.90959                       1.90959
# 1                     1.89792                       1.89792
# 2                     1.91612                       1.91612
# 3                     1.91279                       1.91279
# 4                     1.89430                       1.89430
# 5                     1.89384                       1.88823
# 6                     1.91468                       1.91468
# 7                     1.89506                       1.89506
# 8                     1.89837                       1.89837
# 9                     1.91714                       1.91761
# 10                    1.91113                       1.91113
# 11                    1.91075                       1.91075
# 12                    1.91112                       1.91112
#
#     NBO_LP_energy_N1_Boltz  NBO_LP_energy_N1_Boltz_stdev  \
# 0                -0.384890                      0.000000
# 1                -0.387160                      0.000000
# 2                -0.384230                      0.000000
# 3                -0.383852                      0.000087
# 4                -0.407920                      0.000000
# 5                -0.392468                      0.000175
# 6                -0.390319                      0.000057
# 7                -0.394048                      0.002008
# 8                -0.384380                      0.000000
# 9                -0.380174                      0.001563
# 10               -0.391940                      0.000059
# 11               -0.387740                      0.000000
# 12               -0.386340                      0.000000
#
#     NBO_LP_energy_N1_min  NBO_LP_energy_N1_max  NBO_LP_energy_N1_range  \
# 0               -0.38489              -0.38489                 0.00000
# 1               -0.38716              -0.38716                 0.00000
# 2               -0.38423              -0.38423                 0.00000
# 3               -0.38392              -0.36897                 0.01495
# 4               -0.40792              -0.40792                 0.00000
# 5               -0.39362              -0.38993                 0.00369
# 6               -0.39036              -0.39028                 0.00008
# 7               -0.39547              -0.39263                 0.00284
# 8               -0.38438              -0.38438                 0.00000
# 9               -0.38336              -0.37270                 0.01066
# 10              -0.39195              -0.39176                 0.00019
# 11              -0.38774              -0.38774                 0.00000
# 12              -0.38634              -0.38634                 0.00000
#
#     NBO_LP_energy_N1_low_E  NBO_LP_energy_N1_Vbur_min  \
# 0                 -0.38489                   -0.38489
# 1                 -0.38716                   -0.38716
# 2                 -0.38423                   -0.38423
# 3                 -0.38391                   -0.38391
# 4                 -0.40792                   -0.40792
# 5                 -0.39245                   -0.38993
# 6                 -0.39028                   -0.39028
# 7                 -0.39263                   -0.39263
# 8                 -0.38438                   -0.38438
# 9                 -0.37962                   -0.38014
# 10                -0.39195                   -0.39195
# 11                -0.38774                   -0.38774
# 12                -0.38634                   -0.38634
#
#                                                smiles
# 0                               BrC1=C2C(OCCC2)=CN=C1
# 1                                      ClC1=NC=CC=C1C
# 2                                    BrC1=CC(C)=NC=C1
# 3   O=C(NC1=NC=CC(C2CC2)=C1)C3=CC=C(B4OC(C)(C)C(C)...
# 4                          ClC1=NC(C(F)(F)F)=CC(C)=C1
# 5                   BrC1=CC(C)=CC(NC(OC(C)(C)C)=O)=N1
# 6       FC(F)(C1=CC(C(F)(F)F)=CC(C2=CN=CC(C)=C2)=C1)F
# 7                         BrC1=NC(C2=CN=CS2)=CC(C)=C1
# 8                              CC1=NC(Cl)=CC2=C1C=NN2
# 9                                    BrCCCC1=CN=CC=C1
# 10                          ClC1=C(C)C(C(OC)=O)=NC=C1
# 11                          COC1=C(CCC(N2)=O)C2=NC=C1
# 12                             O=CC1=CC=C(CCCN2)C2=N1
#
# [13 rows x 695 columns]

# %%
# drop columns that are not present in all dataframes
columns = set.intersection(*[set(d.columns) for d in dict.values()])
print(f"Columns: {columns}, number of columns: {len(columns)}")
for key in dict.keys():
    dict[key] = dict[key][list(columns)]
    
# concatenate all dataframes
df = pd.concat(dict.values(), ignore_index=True)
df
# Out:
# Columns: {'Sterimol_B1_N1_C1(Å)_dbstep_Vbur_min', 'pyramidalization_Agranat-Radhakrishnan_C2_Vbur_min', 'NMR_shift_N1_low_E', 'η_range', 'μ_low_E', 'pyramidalization_Gavrish_C3(°)_low_E', '%Vbur_C3_3.5Å_max', '%Vbur_C5_4.0Å_min', 'Buried_Sterimol_B1_N1_C5_5.0(Å)_Vbur_min', '%Vbur_C3_3.0Å_max', '%Vbur_C4_3.5Å_Vbur_min', 'μ_max', 'NBO_charge_C2_Boltz_stdev', 'NMR_shift_N1_Vbur_min', 'NBO_LP_occupancy_N1_min', 'μ_Boltz_stdev', '%Vbur_C1_2.5Å_Boltz_stdev', 'Sterimol_B5_N1_C5(Å)_dbstep_max', 'Buried_Sterimol_L_N1_C1_5.0(Å)_Boltz', 'angle_C5_N1_C1(°)_low_E', 'Sterimol_B1_N1_C5(Å)_morfeus_range', 'dihedral_C4_C5_N1_C1(°)_max', '%Vbur_C1_2.0Å_Boltz', 'SASA_sphericity_Vbur_min', 'distance_N1_C5(Å)_Boltz_stdev', 'NBO_LP_energy_N1_Boltz_stdev', '%Vbur_C1_2.0Å_min', '%Vbur_C1_3.5Å_min', 'Sterimol_Bmax_N1_C5_0.0Å(Å)_Boltz_stdev', 'pyramidalization_Gavrish_C4(°)_Vbur_min', 'NMR_shift_C2_range', '%Vbur_N1_3.5Å_Boltz', 'polar_aniso(Debye)_Boltz', 'Sterimol_Bmin_N1_C1_1.0Å(Å)_Boltz_stdev', 'Buried_Sterimol_B5_N1_C1_5.0(Å)_Boltz_stdev', 'NBO_charge_C1_Boltz_stdev', '%Vbur_C3_3.5Å_Vbur_min', 'Sterimol_B5_N1_C1(Å)_morfeus_min', 'NMR_shift_N1_Boltz', '%Vbur_C5_3.0Å_range', '%Vbur_N1_2.5Å_max', 'dihedral_C4_C5_N1_C1(°)_low_E', '%Vbur_N1_4.0Å_range', '%Vbur_C2_4.0Å_range', 'LUMO_range', '%Vbur_C4_2.5Å_min', 'Sterimol_B1_N1_C1(Å)_morfeus_max', 'LUMO_min', 'Sterimol_B1_N1_C5(Å)_dbstep_range', '%Vbur_C3_3.0Å_range', 'pyramidalization_Gavrish_C3(°)_range', '%Vbur_C2_4.0Å_Vbur_min', 'dihedral_C2_C1_N1_C5(°)_range', 'Sterimol_L_N1_C1(Å)_morfeus_Vbur_min', 'Sterimol_B5_N1_C1(Å)_morfeus_low_E', 'Sterimol_L_N1_C5(Å)_dbstep_Boltz_stdev', 'pyramidalization_Gavrish_C5(°)_min', 'pyramidalization_Gavrish_C3(°)_min', 'NMR_shift_C1_Boltz_stdev', 'NBO_LP_energy_N1_Boltz', 'Sterimol_Bmin_N1_C5_1.0Å(Å)_Boltz', 'pyramidalization_Agranat-Radhakrishnan_C5_range', '%Vbur_C3_2.0Å_Vbur_min', '%Vbur_N1_2.0Å_Boltz_stdev', 'Sterimol_B5_N1_C1(Å)_dbstep_Boltz', 'Sterimol_B5_N1_C5(Å)_dbstep_range', 'NBO_charge_C1_max', 'volume(Bohr_radius³/mol)_range', '%Vbur_C5_3.0Å_max', 'Buried_Sterimol_B5_N1_C1_5.0(Å)_max', 'Sterimol_L_N1_C5(Å)_morfeus_max', 'SASA_sphericity_max', 'dihedral_C2_C1_N1_C5(°)_Boltz', '%Vbur_C4_2.5Å_low_E', '%Vbur_C2_2.0Å_Boltz', 'Sterimol_B5_N1_C5(Å)_dbstep_Boltz', 'Sterimol_Bmax_N1_C1_0.0Å(Å)_min', 'pyramidalization_Gavrish_C5(°)_max', 'NBO_charge_C2_Vbur_min', 'dihedral_C2_C1_N1_C5(°)_Boltz_stdev', 'Buried_Sterimol_B5_N1_C5_5.0(Å)_range', 'id', 'pyramidalization_Agranat-Radhakrishnan_N1_Boltz', '%Vbur_C5_4.0Å_Vbur_min', '%Vbur_C2_3.5Å_Vbur_min', '%Vbur_N1_3.5Å_range', '%Vbur_N1_4.0Å_max', 'Sterimol_Bmax_N1_C5_0.0Å(Å)_Boltz', 'SASA_volume(Å³)_Boltz', '%Vbur_C2_3.0Å_range', '%Vbur_C2_3.0Å_min', '%Vbur_C4_3.0Å_Vbur_min', 'pyramidalization_Agranat-Radhakrishnan_C2_range', 'pyramidalization_Gavrish_C5(°)_Boltz_stdev', 'ω_Boltz', '%Vbur_C5_3.0Å_Boltz', '%Vbur_C1_3.5Å_low_E', '%Vbur_C3_4.0Å_Boltz_stdev', 'pyramidalization_Agranat-Radhakrishnan_C1_min', '%Vbur_C3_2.5Å_low_E', 'Sterimol_Bmax_N1_C1_1.0Å(Å)_range', '%Vbur_C2_2.0Å_range', 'HOMO_Vbur_min', 'NBO_charge_N1_max', 'volume(Bohr_radius³/mol)_Vbur_min', 'SASA_surface_area(Å²)_min', '%Vbur_C2_2.5Å_Boltz', 'pyramidalization_Gavrish_N1(°)_Boltz_stdev', 'Sterimol_Bmax_N1_C5_0.0Å(Å)_range', 'Sterimol_Bmax_N1_C1_1.0Å(Å)_low_E', 'distance_N1_C1(Å)_low_E', '%Vbur_C5_3.5Å_Boltz', 'NBO_charge_C2_max', 'Sterimol_Bmax_N1_C5_1.0Å(Å)_Boltz_stdev', '%Vbur_C5_3.0Å_Boltz_stdev', 'Buried_Sterimol_B5_N1_C5_5.0(Å)_low_E', 'pyramidalization_Agranat-Radhakrishnan_N1_range', 'Sterimol_Bmax_N1_C5_0.0Å(Å)_min', 'dipole(Debye)_Boltz', 'dipole(Debye)_max', '%Vbur_C3_2.0Å_Boltz', '%Vbur_C3_2.0Å_range', 'Sterimol_Bmin_N1_C1_0.0Å(Å)_max', '%Vbur_N1_2.5Å_Boltz', 'Sterimol_Bmin_N1_C1_0.0Å(Å)_range', 'Sterimol_L_N1_C5(Å)_dbstep_low_E', '%Vbur_C2_2.5Å_max', 'Sterimol_B1_N1_C1(Å)_morfeus_Boltz', '%Vbur_N1_4.0Å_Vbur_min', 'Sterimol_B1_N1_C5(Å)_morfeus_Vbur_min', 'Sterimol_B5_N1_C1(Å)_dbstep_min', 'Sterimol_B5_N1_C5(Å)_morfeus_Boltz', 'Sterimol_B5_N1 ...
#     Sterimol_B1_N1_C1(Å)_dbstep_Vbur_min  \
# 0                               1.678700
# 1                               1.902733
# 2                               1.919161
# 3                               2.810193
# 4                               2.300057
# 5                               2.045036
# 6                               1.678700
# 7                               1.818733
# 8                               1.858054
# 9                               1.950000
# 10                              1.941230
# 11                              1.944234
# 12                              2.256192
#
#     pyramidalization_Agranat-Radhakrishnan_C2_Vbur_min  NMR_shift_N1_low_E  \
# 0                                        1.262264e-02            -152.6619
# 1                                        2.217330e-11            -136.0998
# 2                                        6.620001e-07            -142.7935
# 3                                        5.380573e-03             -87.0908
# 4                                        7.990694e-06            -119.6215
# 5                                        1.617399e-02             -83.5707
# 6                                        5.864158e-03            -157.3613
# 7                                        4.243139e-04            -115.3763
# 8                                        5.359846e-06            -106.6853
# 9                                        2.126168e-12            -155.3219
# 10                                       8.243269e-03            -147.0971
# 11                                       3.014662e-02             -69.9651
# 12                                       7.736921e-03             -81.0900
#
#     η_range   μ_low_E  pyramidalization_Gavrish_C3(°)_low_E  \
# 0   0.00000 -0.148205                              0.070941
# 1   0.00000 -0.158740                              0.000000
# 2   0.00000 -0.166500                              0.000028
# 3   0.00580 -0.158135                              0.009002
# 4   0.00000 -0.182130                              0.000512
# 5   0.00191 -0.146690                              0.102502
# 6   0.00012 -0.177020                              0.130686
# 7   0.00102 -0.165875                              0.023674
# 8   0.00000 -0.159125                              0.000182
# 9   0.00982 -0.157100                              0.022973
# 10  0.00929 -0.180170                              0.036256
# 11  0.00000 -0.141705                              0.052214
# 12  0.00000 -0.149940                              0.016439
#
#     %Vbur_C3_3.5Å_max  %Vbur_C5_4.0Å_min  \
# 0           71.657193          41.624511
# 1           52.435473          35.784557
# 2           60.471604          37.010816
# 3           66.609206          36.890944
# 4           60.095392          52.661613
# 5           60.441903          47.222395
# 6           60.906634          44.884706
# 7           60.212449          48.427317
# 8           60.618943          44.781128
# 9           61.665463          34.717351
# 10          63.820816          37.543449
# 11          65.425829          37.639656
# 12          52.962519          46.090016
#
#     Buried_Sterimol_B1_N1_C5_5.0(Å)_Vbur_min  %Vbur_C3_3.0Å_max  ...  \
# 0                                   1.700000          81.114981  ...
# 1                                   1.700000          63.720761  ...
# 2                                   1.700000          74.493445  ...
# 3                                   1.700000          78.563580  ...
# 4                                   2.345237          74.617290  ...
# 5                                   1.994585          74.787694  ...
# 6                                   1.700000          69.782665  ...
# 7                                   1.873574          74.678747  ...
# 8                                   1.863661          72.997058  ...
# 9                                   1.700000          71.193385  ...
# 10                                  1.728841          76.381853  ...
# 11                                  1.700000          76.495456  ...
# 12                                  1.924688          63.680721  ...
#
#     %Vbur_C5_3.5Å_low_E  Buried_Sterimol_B1_N1_C1_5.0(Å)_range  \
# 0             50.091432                               0.000000
# 1             45.218156                               0.000000
# 2             45.674734                               0.000000
# 3             45.640957                               0.641758
# 4             65.056606                               0.000000
# 5             60.351635                               0.265141
# 6             53.392308                               0.000000
# 7             59.642890                               0.039266
# 8             57.343692                               0.000000
# 9             44.899599                               0.278176
# 10            45.997368                               0.257810
# 11            45.876817                               0.000000
# 12            58.882897                               0.000000
#
#     Sterimol_L_N1_C5(Å)_morfeus_Boltz  NBO_charge_C4_low_E  \
# 0                            6.231718             -0.09579
# 1                            4.676141             -0.25681
# 2                            4.703910             -0.29592
# 3                            5.154963             -0.28309
# 4                            5.190009             -0.23877
# 5                            7.693055             -0.30027
# 6                            9.633156             -0.09367
# 7                            5.245081             -0.28553
# 8                            4.744074             -0.31004
# 9                            7.451562             -0.25013
# 10                           4.729373             -0.25193
# 11                           5.629110             -0.37539
# 12                           5.096951             -0.24998
#
#     NBO_LP_energy_N1_max  NBO_charge_C4_Boltz  \
# 0               -0.38489            -0.095790
# 1               -0.38716            -0.256810
# 2               -0.38423            -0.295920
# 3               -0.36897            -0.288895
# 4               -0.40792            -0.238770
# 5               -0.38993            -0.300469
# 6               -0.39028            -0.093728
# 7               -0.39263            -0.263249
# 8               -0.38438            -0.310040
# 9               -0.37270            -0.094883
# 10              -0.39176            -0.241672
# 11              -0.38774            -0.375390
# 12              -0.38634            -0.249980
#
#     pyramidalization_Agranat-Radhakrishnan_C2_min  %Vbur_C4_4.0Å_Boltz  \
# 0                                    1.262264e-02            52.881572
# 1                                    2.217330e-11            36.456846
# 2                                    6.620001e-07            41.864642
# 3                                    4.817690e-03            44.947271
# 4                                    7.990694e-06            51.486174
# 5                                    1.145209e-03            51.728743
# 6                                    5.767447e-03            54.903879
# 7                                    4.243139e-04            49.761201
# 8                                    5.359846e-06            45.306390
# 9                                    2.126168e-12            50.550643
# 10                                   4.585906e-03            42.666975
# 11                                   3.014662e-02            45.525961
# 12                                   7.736921e-03            43.669310
#
#     pyramidalization_Agranat-Radhakrishnan_C4_max  %Vbur_C5_4.0Å_range
# 0                                    8.571091e-04             0.000000
# 1                                    8.160089e-11             0.000000
# 2                                    3.086916e-07             0.000000
# 3                                    1.947814e-03             3.157005
# 4                                    2.843578e-05             0.000000
# 5                                    3.469078e-03             7.197722
# 6                                    4.408980e-03             0.114828
# 7                                    1.882305e-03             6.439700
# 8                                    8.777287e-06             0.000000
# 9                                    2.845040e-02            16.506191
# 10                                   1.874841e-02            18.055211
# 11                                   9.607423e-03             0.000000
# 12                                   1.482994e-03             0.000000
#
# [13 rows x 695 columns]

# %%
# drop column that match one capital letter followed by a number in any place
df = df[df.columns.drop(list(df.filter(regex='[C][2-9]')))]
df
# Out:
#     Sterimol_B1_N1_C1(Å)_dbstep_Vbur_min  NMR_shift_N1_low_E  η_range  \
# 0                               1.678700           -152.6619  0.00000
# 1                               1.902733           -136.0998  0.00000
# 2                               1.919161           -142.7935  0.00000
# 3                               2.810193            -87.0908  0.00580
# 4                               2.300057           -119.6215  0.00000
# 5                               2.045036            -83.5707  0.00191
# 6                               1.678700           -157.3613  0.00012
# 7                               1.818733           -115.3763  0.00102
# 8                               1.858054           -106.6853  0.00000
# 9                               1.950000           -155.3219  0.00982
# 10                              1.941230           -147.0971  0.00929
# 11                              1.944234            -69.9651  0.00000
# 12                              2.256192            -81.0900  0.00000
#
#      μ_low_E     μ_max  NMR_shift_N1_Vbur_min  NBO_LP_occupancy_N1_min  \
# 0  -0.148205 -0.148205              -152.6619                  1.90959
# 1  -0.158740 -0.158740              -136.0998                  1.89792
# 2  -0.166500 -0.166500              -142.7935                  1.91612
# 3  -0.158135 -0.157120               -87.0908                  1.90871
# 4  -0.182130 -0.182130              -119.6215                  1.89430
# 5  -0.146690 -0.146690               -97.5078                  1.88823
# 6  -0.177020 -0.177020              -157.3613                  1.91467
# 7  -0.165875 -0.165705              -115.3763                  1.89323
# 8  -0.159125 -0.159125              -106.6853                  1.89837
# 9  -0.157100 -0.148095              -155.5752                  1.91605
# 10 -0.180170 -0.176735              -147.0971                  1.91113
# 11 -0.141705 -0.141705               -69.9651                  1.91075
# 12 -0.149940 -0.149940               -81.0900                  1.91112
#
#     μ_Boltz_stdev  %Vbur_C1_2.5Å_Boltz_stdev  \
# 0        0.000000                   0.000000
# 1        0.000000                   0.000000
# 2        0.000000                   0.000000
# 3        0.000017                   0.042330
# 4        0.000000                   0.000000
# 5        0.000304                   0.148577
# 6        0.000127                   0.026457
# 7        0.000120                   0.805727
# 8        0.000000                   0.000000
# 9        0.001810                   1.131357
# 10       0.001062                   4.128217
# 11       0.000000                   0.000000
# 12       0.000000                   0.000000
#
#     Buried_Sterimol_L_N1_C1_5.0(Å)_Boltz  ...  NBO_charge_C1_Boltz  \
# 0                               6.315951  ...            -0.007730
# 1                               5.740440  ...             0.204740
# 2                               4.677361  ...             0.226010
# 3                               6.053364  ...             0.364875
# 4                               4.847387  ...             0.208320
# 5                               4.799928  ...             0.184721
# 6                               5.730348  ...             0.036010
# 7                               5.337227  ...             0.178518
# 8                               5.803871  ...             0.286410
# 9                               5.012735  ...             0.024168
# 10                              5.693642  ...             0.088105
# 11                              6.637396  ...             0.379350
# 12                              6.701697  ...             0.376930
#
#     Sterimol_B1_N1_C1(Å)_dbstep_range  SASA_volume(Å³)_Boltz_stdev  \
# 0                            0.000000                     0.000000
# 1                            0.000000                     0.000000
# 2                            0.000000                     0.000000
# 3                            0.165456                     0.300843
# 4                            0.000000                     0.000000
# 5                            0.748284                     0.838528
# 6                            0.000000                     0.217000
# 7                            0.025064                     0.004898
# 8                            0.000000                     0.000000
# 9                            0.300000                     5.836909
# 10                           0.250210                     0.625846
# 11                           0.000000                     0.000000
# 12                           0.000000                     0.000000
#
#     SASA_volume(Å³)_low_E  distance_N1_C1(Å)_max  NMR_shift_C1_Boltz  \
# 0              481.283655                1.33171           24.352100
# 1              389.546728                1.31767            3.032300
# 2              406.872695                1.34382           -2.658000
# 3             1050.322955                1.34199           10.473907
# 4              493.760497                1.31594            2.358100
# 5              712.496262                1.34529            4.844362
# 6              743.328356                1.33775            9.704503
# 7              576.026799                1.35300            6.168314
# 8              464.536762                1.33291            7.058100
# 9              504.392277                1.34032           12.192396
# 10             518.649983                1.34013           11.216520
# 11             522.020246                1.33812           10.616900
# 12             499.855392                1.33839            8.288800
#
#     Buried_Sterimol_L_N1_C1_5.0(Å)_range  Sterimol_Bmax_N1_C1_0.0Å(Å)_range  \
# 0                               0.000000                           0.000000
# 1                               0.000000                           0.000000
# 2                               0.000000                           0.000000
# 3                               0.632022                           1.088059
# 4                               0.000000                           0.000000
# 5                               2.918696                           1.412308
# 6                               0.000041                           0.208993
# 7                               1.131644                           0.258775
# 8                               0.000000                           0.000000
# 9                               3.213990                           4.470544
# 10                              1.068272                           0.092303
# 11                              0.000000                           0.000000
# 12                              0.000000                           0.000000
#
#     Buried_Sterimol_B1_N1_C1_5.0(Å)_range  NBO_LP_energy_N1_max
# 0                                0.000000              -0.38489
# 1                                0.000000              -0.38716
# 2                                0.000000              -0.38423
# 3                                0.641758              -0.36897
# 4                                0.000000              -0.40792
# 5                                0.265141              -0.38993
# 6                                0.000000              -0.39028
# 7                                0.039266              -0.39263
# 8                                0.000000              -0.38438
# 9                                0.278176              -0.37270
# 10                               0.257810              -0.39176
# 11                               0.000000              -0.38774
# 12                               0.000000              -0.38634
#
# [13 rows x 324 columns]

# %%
# move coloumn "id" and "SMILES" to first position, order the rest of the columns alphabetically
cols = list(df.columns)
cols.remove("id")
cols.remove("smiles")
cols.sort()
cols.insert(0, "id")
cols.insert(1, "smiles")
df = df[cols]

# remove columns that contain any cell with value = 0
columns_with_zeros = df.columns[(df == 0).any()]
df = df.drop(columns=columns_with_zeros)
display(df)
# Out:
#         id                                             smiles  \
# 0    pyrd1                              BrC1=C2C(OCCC2)=CN=C1
# 1    pyrd2                                     ClC1=NC=CC=C1C
# 2    pyrd3                                   BrC1=CC(C)=NC=C1
# 3    pyrd4  O=C(NC1=NC=CC(C2CC2)=C1)C3=CC=C(B4OC(C)(C)C(C)...
# 4    pyrd5                         ClC1=NC(C(F)(F)F)=CC(C)=C1
# 5    pyrd6                  BrC1=CC(C)=CC(NC(OC(C)(C)C)=O)=N1
# 6    pyrd7      FC(F)(C1=CC(C(F)(F)F)=CC(C2=CN=CC(C)=C2)=C1)F
# 7    pyrd8                        BrC1=NC(C2=CN=CS2)=CC(C)=C1
# 8    pyrd9                             CC1=NC(Cl)=CC2=C1C=NN2
# 9   pyrd10                                   BrCCCC1=CN=CC=C1
# 10  pyrd11                          ClC1=C(C)C(C(OC)=O)=NC=C1
# 11  pyrd12                          COC1=C(CCC(N2)=O)C2=NC=C1
# 12  pyrd13                             O=CC1=CC=C(CCCN2)C2=N1
#
#     %Vbur_C1_2.0Å_Boltz  %Vbur_C1_2.0Å_Vbur_min  %Vbur_C1_2.0Å_low_E  \
# 0             90.705708               90.705708            90.705708
# 1             95.180139               95.180139            95.180139
# 2             95.716038               95.716038            95.716038
# 3             94.741043               94.731405            94.731405
# 4             95.276989               95.276989            95.276989
# 5             95.147784               94.957386            95.154313
# 6             90.977815               91.002712            91.002712
# 7             95.543657               95.858084            95.858084
# 8             95.699897               95.699897            95.699897
# 9             90.734536               91.160899            90.902634
# 10            95.398145               95.645015            95.645015
# 11            94.805656               94.805656            94.805656
# 12            94.741090               94.741090            94.741090
#
#     %Vbur_C1_2.0Å_max  %Vbur_C1_2.0Å_min  %Vbur_C1_2.5Å_Boltz  \
# 0           90.705708          90.705708            74.778617
# 1           95.180139          95.180139            85.671962
# 2           95.716038          95.716038            85.748470
# 3           94.976756          94.731405            84.651442
# 4           95.276989          95.276989            85.032231
# 5           95.154313          94.724948            85.525035
# 6           91.002712          90.951059            75.694937
# 7           95.858084          95.228564            86.068125
# 8           95.699897          95.699897            85.989387
# 9           92.252066          90.625000            74.209673
# 10          95.645015          90.737991            86.357696
# 11          94.805656          94.805656            85.108738
# 12          94.741090          94.741090            85.149434
#
#     %Vbur_C1_2.5Å_Vbur_min  %Vbur_C1_2.5Å_low_E  ...   μ_Boltz  μ_Vbur_min  \
# 0                74.778617            74.778617  ... -0.148205   -0.148205
# 1                85.671962            85.671962  ... -0.158740   -0.158740
# 2                85.748470            85.748470  ... -0.166500   -0.166500
# 3                84.703412            84.703412  ... -0.158143   -0.158135
# 4                85.032231            85.032231  ... -0.182130   -0.182130
# 5                85.614989            85.540109  ... -0.146721   -0.153625
# 6                75.712983            75.712983  ... -0.177107   -0.177020
# 7                86.637257            86.637257  ... -0.165790   -0.165875
# 8                85.989387            85.989387  ... -0.159125   -0.159125
# 9                77.646829            76.258302  ... -0.158102   -0.160415
# 10               87.029561            87.029561  ... -0.179997   -0.180170
# 11               85.108738            85.108738  ... -0.141705   -0.141705
# 12               85.149434            85.149434  ... -0.149940   -0.149940
#
#      μ_low_E     μ_max     μ_min   ω_Boltz  ω_Vbur_min  ω_low_E    ω_max  \
# 0  -0.148205 -0.148205 -0.148205  0.038490     0.03849  0.03849  0.03849
# 1  -0.158740 -0.158740 -0.158740  0.041650     0.04165  0.04165  0.04165
# 2  -0.166500 -0.166500 -0.166500  0.044680     0.04468  0.04468  0.04468
# 3  -0.158135 -0.157120 -0.158165  0.049803     0.04981  0.04981  0.04981
# 4  -0.182130 -0.182130 -0.182130  0.054590     0.05459  0.05459  0.05459
# 5  -0.146690 -0.146690 -0.153625  0.037900     0.04167  0.03788  0.04167
# 6  -0.177020 -0.177020 -0.177200  0.058653     0.05861  0.05861  0.05870
# 7  -0.165875 -0.165705 -0.165875  0.056160     0.05610  0.05610  0.05622
# 8  -0.159125 -0.159125 -0.159125  0.047360     0.04736  0.04736  0.04736
# 9  -0.157100 -0.148095 -0.162225  0.040361     0.04143  0.03981  0.04286
# 10 -0.180170 -0.176735 -0.180170  0.055113     0.05530  0.05530  0.05530
# 11 -0.141705 -0.141705 -0.141705  0.034660     0.03466  0.03466  0.03466
# 12 -0.149940 -0.149940 -0.149940  0.048500     0.04850  0.04850  0.04850
#
#       ω_min
# 0   0.03849
# 1   0.04165
# 2   0.04468
# 3   0.04817
# 4   0.05459
# 5   0.03788
# 6   0.05861
# 7   0.05610
# 8   0.04736
# 9   0.03604
# 10  0.05158
# 11  0.03466
# 12  0.04850
#
# [13 rows x 229 columns]

# %%
# export to csv
df.to_csv("combined.csv", index=False)
