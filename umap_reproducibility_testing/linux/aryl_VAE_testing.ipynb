# %%
# package imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from rdkit import Chem
from rdkit.Chem import Draw

# scikit learn!
import sklearn
from sklearn.decomposition import PCA, KernelPCA
from sklearn.manifold import TSNE
from sklearn.preprocessing import scale
from sklearn import preprocessing
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.metrics import silhouette_score
from sklearn.neighbors import NearestCentroid
from sklearn.metrics import pairwise_distances_argmin_min
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster, fclusterdata
from scipy.spatial.distance import cdist

# umap for dimensionality reduction
import umap

# nice plotting
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns; sns.set()

import torch
from torch import nn, optim
import torch.nn.functional as F
from torch.utils.data import DataLoader, TensorDataset

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# cleaned aryl X dataset
# We kept parameters for the low energy conformer (removing those for min/max and Bolztmann average, which are highly correlated)
arylx = pd.read_csv('arylx.csv')
arylx.head()
# Out:
#         id                    smiles  HOMO_low_E  LUMO_low_E  η_low_E  \
# 0  arbr141   Cc1[nH]nc(C(F)(F)F)c1Br    -0.30770     0.01581  0.32351
# 1  arbr142  Cc1[nH]nc(-c2ccccc2)c1Br    -0.27821     0.00248  0.28069
# 2  arbr143  Cc1cc(C(C)(C)C)cc(C)c1Br    -0.28384     0.01480  0.29864
# 3  arbr145           Cc1cccc(Cl)c1Br    -0.30209    -0.00082  0.30127
# 4  arbr146            Cc1cccc(F)c1Br    -0.30220     0.00107  0.30327
#
#     μ_low_E  ω_low_E  polar_aniso(Debye)_low_E  polar_iso(Debye)_low_E  \
# 0 -0.145945  0.03292                   43.1852                 89.2019
# 1 -0.137865  0.03386                  102.7150                147.4390
# 2 -0.134520  0.03030                   86.5084                162.0250
# 3 -0.151455  0.03807                   69.3040                110.6700
# 4 -0.150565  0.03738                   62.0065                 98.2669
#
#    dipole(Debye)_low_E  ...  %Vbur_Br_2.5Å_low_E  %Vbur_C_3.0Å_low_E  \
# 0               5.5518  ...            34.132048           78.811271
# 1               2.8706  ...            36.231931           77.875447
# 2               1.8175  ...            36.599818           79.910980
# 3               2.6224  ...            36.397968           79.426773
# 4               2.6395  ...            34.662716           78.545888
#
#    %Vbur_Br_3.0Å_low_E  %Vbur_C_3.5Å_low_E  %Vbur_Br_3.5Å_low_E  \
# 0            33.014563           68.080856            31.508572
# 1            34.498845           67.397153            32.274390
# 2            35.651631           70.185543            33.763511
# 3            35.005401           69.397596            32.937127
# 4            33.005252           67.583512            30.757315
#
#    %Vbur_C_4.0Å_low_E  %Vbur_Br_4.0Å_low_E  Sterimol_B1_C_Br(Å)_morfeus_low_E  \
# 0           56.128189            29.409255                           2.277507
# 1           55.776721            29.634644                           2.077762
# 2           58.853811            30.847713                           2.968765
# 3           57.807554            30.127708                           1.868018
# 4           55.012104            27.829201                           1.850000
#
#    Sterimol_B5_C_Br(Å)_morfeus_low_E  Sterimol_L_C_Br(Å)_morfeus_low_E
# 0                           4.841637                          4.126049
# 1                           7.508006                          4.136710
# 2                           4.479852                          4.170312
# 3                           4.498470                          4.153900
# 4                           4.454212                          4.152511
#
# [5 rows x 34 columns]

# %%
# the molecular descriptors
X = arylx.select_dtypes(include=['number'])

# set dtype to float64
X = X.astype('float32')

# trim significant figures to 3
X = X.round(3)

# Feature scaling through standardization (or Z-score normalization) is an important preprocessing step 
# for many machine learning algorithms. Standardization involves rescaling the features such that they 
# have the properties of a standard normal distribution with a mean of zero and a standard deviation of one. 

X_scaled=pd.DataFrame(scale(X),index=X.index, columns=X.columns)

# drop zero-variance features
zero_std_cols = X_scaled.columns[X_scaled.std() == 0]
X_scaled=X_scaled[X_scaled.columns.difference(zero_std_cols)]
print (f"Dropping {len(zero_std_cols)} features {zero_std_cols}")

# drop highly correlated features
corr = X_scaled.corr().abs()
upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
X_scaled = X_scaled.drop(to_drop, axis=1)
print (f"Dropping {len(to_drop)} features {to_drop}")
# Out:
# Dropping 0 features Index([], dtype='object')
# Dropping 10 features ['ω_low_E', 'SASA_surface_area(Å²)_low_E', 'SASA_volume(Å³)_low_E', 'pyramidalization_Gavrish_C(°)_low_E', '%Vbur_Br_2.5Å_low_E', '%Vbur_Br_3.0Å_low_E', '%Vbur_C_3.5Å_low_E', '%Vbur_Br_3.5Å_low_E', '%Vbur_C_4.0Å_low_E', '%Vbur_Br_4.0Å_low_E']
# /home/intel00000/stahl_data_science/venv/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:261: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn(
# /home/intel00000/stahl_data_science/venv/lib/python3.12/site-packages/sklearn/preprocessing/_data.py:280: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn(

# %%
X_scaled
# Out:
#       HOMO_low_E  LUMO_low_E   η_low_E   μ_low_E  polar_aniso(Debye)_low_E  \
# 0      -0.678474    1.672894  2.252083  0.751543                 -1.580533
# 1       0.937642    1.076414  0.384873  1.202188                  0.167396
# 2       0.614418    1.630288  1.166496  1.371179                 -0.308476
# 3      -0.355250    0.948597  1.253343  0.469891                 -0.813623
# 4      -0.355250    1.033808  1.340190  0.469891                 -1.027908
# ...          ...         ...       ...       ...                       ...
# 5041    1.530217   -0.244362 -1.482336  0.638882                  1.681749
# 5042    1.153124   -0.372179 -1.308642  0.357229                  3.030501
# 5043    0.668289   -0.329573 -0.874407  0.131907                  1.680047
# 5044    1.422476    0.394723 -0.744137  1.033196                  0.468887
# 5045    0.345066   -0.116545 -0.440173  0.075576                  1.370599
#
#       polar_iso(Debye)_low_E  dipole(Debye)_low_E  \
# 0                  -1.507735             1.917315
# 1                  -0.007780             0.020992
# 2                   0.367897            -0.723816
# 3                  -0.954804            -0.155131
# 4                  -1.274257            -0.142399
# ...                      ...                  ...
# 5041                1.608798            -0.573864
# 5042                2.417950            -0.041252
# 5043                0.298510             0.382432
# 5044                1.555045            -1.218232
# 5045                0.228351            -0.568205
#
#       volume(Bohr_radius³/mol)_low_E  SASA_sphericity_low_E  \
# 0                          -0.849583               1.123424
# 1                           0.195476               0.093161
# 2                           1.000580               0.056367
# 3                          -0.935549               1.528171
# 4                          -0.932373               1.712147
# ...                              ...                    ...
# 5041                        1.571986              -0.826715
# 5042                        1.698710              -1.599413
# 5043                        0.257995               0.019572
# 5044                        0.945473              -0.495559
# 5045                        0.071350               0.056367
#
#       NBO_charge_Br_low_E  ...  \
# 0                1.346344  ...
# 1                0.094426  ...
# 2               -1.822574  ...
# 3                0.133548  ...
# 4                0.055303  ...
# ...                   ...  ...
# 5041            -0.883635  ...
# 5042            -0.883635  ...
# 5043            -0.805390  ...
# 5044            -0.844513  ...
# 5045            -0.648901  ...
#
#       pyramidalization_Agranat-Radhakrishnan_C_low_E  NBO_LP_energy_Br_low_E  \
# 0                                          -0.453525               -0.513093
# 1                                           4.298754                0.386669
# 2                                          -0.453525                1.398903
# 3                                          -0.453525                0.386669
# 4                                          -0.453525                0.386669
# ...                                              ...                     ...
# 5041                                       -0.453525                0.836552
# 5042                                        0.074506                0.949021
# 5043                                        0.074506                0.949021
# 5044                                       -0.057502                0.611610
# 5045                                       -0.453525                0.386669
#
#       NBO_LP_occupancy_Br_low_E  %Vbur_C_2.0Å_low_E  %Vbur_Br_2.0Å_low_E  \
# 0                      1.226132           -0.139070             0.656542
# 1                      1.945188           -0.208346             2.074224
# 2                      0.363259            0.209503             1.640863
# 3                     -0.643415            0.174849             1.879682
# 4                     -0.068178            0.356709             1.036189
# ...                         ...                 ...                  ...
# 5041                   0.363259            0.300433            -0.768396
# 5042                   0.363259            0.328580            -0.793803
# 5043                   0.075640            0.343726            -0.681289
# 5044                   0.363259            0.462803            -0.742265
# 5045                   0.219458            0.246305            -0.766220
#
#       %Vbur_C_2.5Å_low_E  %Vbur_C_3.0Å_low_E  \
# 0               0.887134            1.480228
# 1               0.358493            1.058018
# 2               1.057912            1.976420
# 3               0.973486            1.758097
# 4               0.817099            1.360692
# ...                  ...                 ...
# 5041           -0.041584           -0.375970
# 5042           -0.053091           -0.389502
# 5043           -0.063646           -0.394915
# 5044            1.247875            0.961938
# 5045           -0.043502           -0.379577
#
#       Sterimol_B1_C_Br(Å)_morfeus_low_E  Sterimol_B5_C_Br(Å)_morfeus_low_E  \
# 0                              1.197531                          -0.633539
# 1                              0.368943                           1.087855
# 2                              4.060303                          -0.867276
# 3                             -0.501075                          -0.855654
# 4                             -0.575648                          -0.884064
# ...                                 ...                                ...
# 5041                           1.354962                          -0.098267
# 5042                           0.373085                           1.062674
# 5043                          -0.509361                          -1.547182
# 5044                           0.870238                           0.889630
# 5045                           0.393801                          -1.662114
#
#       Sterimol_L_C_Br(Å)_morfeus_low_E
# 0                            -0.255508
# 1                            -0.205884
# 2                            -0.057016
# 3                            -0.129196
# 4                            -0.133707
# ...                                ...
# 5041                         -0.097618
# 5042                         -0.102129
# 5043                         -0.102129
# 5044                         -0.102129
# 5045                         -0.106639
#
# [5046 rows x 22 columns]

# %%
# Define the VAE architecture
class VAE(nn.Module):
    def __init__(self, input_dim, hidden_dim, latent_dim):
        super(VAE, self).__init__()
        # Encoder
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.fc21 = nn.Linear(hidden_dim, latent_dim)  # Mean of the latent space
        self.fc22 = nn.Linear(hidden_dim, latent_dim)  # Log-variance of the latent space
        # Decoder
        self.fc3 = nn.Linear(latent_dim, hidden_dim)
        self.fc4 = nn.Linear(hidden_dim, input_dim)

    def encode(self, x):
        h1 = F.relu(self.fc1(x))
        return self.fc21(h1), self.fc22(h1)

    def reparameterize(self, mu, logvar):
        std = torch.exp(0.5 * logvar)
        eps = torch.randn_like(std)
        return mu + eps * std

    def decode(self, z):
        h3 = F.relu(self.fc3(z))
        return torch.sigmoid(self.fc4(h3))

    def forward(self, x):
        mu, logvar = self.encode(x)
        z = self.reparameterize(mu, logvar)
        return self.decode(z), mu, logvar

# %%
# Define the loss function
def loss_function(recon_x, x, mu, logvar):
    BCE = F.binary_cross_entropy(recon_x, x, reduction='sum')
    # KLD is the Kullback-Leibler divergence between the learned latent distribution and a unit Gaussian
    KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + KLD

# Training the VAE
def train_vae(model, data_loader, optimizer, epochs=10):
    model.train()
    for epoch in range(epochs):
        train_loss = 0
        for batch in data_loader:
            batch = batch[0].to(device)
            optimizer.zero_grad()
            recon_batch, mu, logvar = model(batch)
            loss = loss_function(recon_batch, batch, mu, logvar)
            loss.backward()
            train_loss += loss.item()
            optimizer.step()
        print(f"Epoch {epoch + 1}, Loss: {train_loss / len(data_loader.dataset):.4f}")

# %%
# Data preparation
X_tensor = torch.tensor(X_scaled.values, dtype=torch.float32)  # Assuming X_scaled is your input data
dataset = TensorDataset(X_tensor)
data_loader = DataLoader(dataset, batch_size=64, shuffle=False)

for batch in data_loader:
    print(batch)
    break

# Define the dimensions
input_dim = X_scaled.shape[1]
hidden_dim = 128  # Size of the hidden layer
latent_dim = 2  # Choose the latent dimension (2 or 3)

# Initialize the model, optimizer
vae = VAE(input_dim, hidden_dim, latent_dim).to(device)
optimizer = optim.Adam(vae.parameters(), lr=1e-3)

# Train the model
train_vae(vae, data_loader, optimizer, epochs=50)

# After training, extract the low-dimensional representations
vae.eval()
with torch.no_grad():
    X_tensor = X_tensor.to(device)
    mu, _ = vae.encode(X_tensor)
    reduced_data = mu.cpu().numpy()  # Use mu (the mean) as the reduced representation
# Out:
# [tensor([[-0.6785,  1.6729,  2.2521,  ...,  1.1975, -0.6335, -0.2555],
#         [ 0.9376,  1.0764,  0.3849,  ...,  0.3689,  1.0879, -0.2059],
#         [ 0.6144,  1.6303,  1.1665,  ...,  4.0603, -0.8673, -0.0570],
#         ...,
#         [-0.1398,  1.1190,  1.2533,  ..., -0.5756,  1.1563, -0.0886],
#         [ 0.0218,  1.1190,  1.1231,  ..., -0.4058, -0.8640, -0.1021],
#         [ 0.9915, -0.1165, -0.9178,  ..., -0.5756,  0.4538, -0.3232]])]
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [32,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [33,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [34,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [35,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [36,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [37,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [41,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [44,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [45,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [46,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [48,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [52,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [53,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [58,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [59,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [60,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [61,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [63,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [96,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [98,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [100,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [101,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [102,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [103,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [105,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [106,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [108,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [109,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [110,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [111,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [112,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [113,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [114,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [117,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [118,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [119,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [120,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [121,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [122,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [123,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [125,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [32,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [33,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [35,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [36,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [38,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [39,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [40,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [42,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [44,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [45,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [47,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [48,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [49,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [50,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [51,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [52,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [53,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [55,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [56,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [58,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [60,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [61,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [62,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [63,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [0,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [2,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [3,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [4,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [5,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [6,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [7,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [8,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [9,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [13,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [14,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [15,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [16,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [17,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [20,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [21,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [22,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [24,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [25,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [26,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [27,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [29,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [30,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [31,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [0,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [2,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [3,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [4,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [5,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [6,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [7,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [8,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [10,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [11,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [14,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [15,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [17,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [18,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [19,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [20,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [21,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [22,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [25,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [26,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [27,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [29,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [30,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [31,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [64,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [65,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [66,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [67,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [69,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [71,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [72,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [73,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [74,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [75,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [76,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [77,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [79,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [80,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [81,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [82,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [83,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [85,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [86,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [88,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [89,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [92,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [93,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [94,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [95,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [0,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [1,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [2,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [3,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [5,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [8,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [9,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [10,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [12,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [14,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [15,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [16,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [17,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [18,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [19,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [20,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [21,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [22,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [23,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [24,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [25,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [26,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [27,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [28,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [29,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [30,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [96,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [97,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [98,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [100,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [101,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [102,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [104,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [106,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [107,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [108,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [109,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [111,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [112,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [113,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [115,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [116,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [117,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [118,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [119,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [120,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [121,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [122,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [123,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [124,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [126,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [127,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [96,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [97,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [98,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [99,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [100,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [101,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [102,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [103,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [104,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [105,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [107,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [108,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [109,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [110,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [112,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [113,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [114,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [115,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [116,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [117,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [118,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [119,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [122,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [124,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [125,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [2,0,0], thread: [127,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [32,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [33,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [35,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [36,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [37,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [38,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [40,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [41,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [42,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [43,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [45,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [46,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [47,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [50,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [51,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [52,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [53,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [54,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [55,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [56,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [57,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [58,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [59,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [60,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [61,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [62,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [63,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [64,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [65,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [66,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [67,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [68,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [69,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [71,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [73,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [74,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [75,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [76,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [77,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [78,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [79,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [80,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [81,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [82,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [83,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [84,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [85,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [87,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [88,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [89,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [91,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [93,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [94,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [0,0,0], thread: [95,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [64,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [65,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [66,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [67,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [68,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [69,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [70,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [71,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [72,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [73,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [74,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [75,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [76,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [77,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [78,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [79,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [80,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [81,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [82,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [84,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [85,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [86,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [87,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [89,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [90,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [91,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [92,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [93,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [94,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ../aten/src/ATen/native/cuda/Loss.cu:95: operator(): block: [1,0,0], thread: [95,0,0] Assertion `target_val >= zero && target_val <= one` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[7], line 20
#      17 optimizer = optim.Adam(vae.parameters(), lr=1e-3)
#      19 # Train the model
# ---> 20 train_vae(vae, data_loader, optimizer, epochs=50)
#      22 # After training, extract the low-dimensional representations
#      23 vae.eval()
#
# Cell In[6], line 17, in train_vae(model, data_loader, optimizer, epochs)
#      15 optimizer.zero_grad()
#      16 recon_batch, mu, logvar = model(batch)
# ---> 17 loss = loss_function(recon_batch, batch, mu, logvar)
#      18 loss.backward()
#      19 train_loss += loss.item()
#
# Cell In[6], line 3, in loss_function(recon_x, x, mu, logvar)
#       2 def loss_function(recon_x, x, mu, logvar):
# ----> 3     BCE = F.binary_cross_entropy(recon_x, x, reduction='sum')
#       4     # KLD is the Kullback-Leibler divergence between the learned latent distribution and a unit Gaussian
#       5     KLD = -0.5 * torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
#
# File ~/stahl_data_science/venv/lib/python3.12/site-packages/torch/nn/functional.py:3172, in binary_cross_entropy(input, target, weight, size_average, reduce, reduction)
#    3169     new_size = _infer_size(target.size(), weight.size())
#    3170     weight = weight.expand(new_size)
# -> 3172 return torch._C._nn.binary_cross_entropy(input, target, weight, reduction_enum)
#
# RuntimeError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
# define the dimensionalities of the reduced representation to study
# We will compare the performance of clustering based on reduced dimensionality representations of size 3 and 2 dimensions
# Because tSNE cannot convert high dimension data, we only use size 3 and 3 dimensions
dims = [3, 2]

# dictionary to store data at different levels of dimensionality reduction
dfs={}

np.random.seed(42)

# UMAP
n_neighbors = int(np.sqrt(X_scaled.shape[1]))
for dim in dims:
    key = f"umap{dim}"
    dfs[key] = pd.DataFrame(umap.UMAP(n_epochs=100, n_components=2, n_neighbors=2, 
                                      random_state=np.random.RandomState(42), 
                                      init="pca", verbose=False, n_jobs=1
                                      ).fit_transform(X_scaled), index=X_scaled.index)
